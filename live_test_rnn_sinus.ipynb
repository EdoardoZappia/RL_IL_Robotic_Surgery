# %%
import mujoco
import glfw
import numpy as np
import time
from PIL import Image
import torch
from actor_critic_rnn import ActorCriticRNN
from ConvAutoencoder import Encoder, Decoder
import matplotlib.pyplot as plt

# %%
XML_FILE_PATH = "/Users/edoardozappia/Desktop/Tesi_Magistrale/irregular_shape_2D.xml"

def save_image_to_array(rgb_buffer, width, height, target_size):
    """
    Salva un'immagine dalla simulazione in un array ridimensionato alla dimensione target_size.
    """
    # Converti il buffer in un'immagine
    img = np.frombuffer(rgb_buffer, dtype=np.uint8).reshape(height, width, 3)
    img = Image.fromarray(img)

    # Ridimensiona l'immagine
    img_resized = img.resize(target_size, Image.LANCZOS)

    # Converti l'immagine ridimensionata in un array numpy
    return np.array(img_resized)

def visualize_frames(real_frame, predicted_frame, frame_count):
    """
    Visualizza i frame reali e predetti.
    """
    plt.figure(figsize=(10, 5))

    # Frame reale
    plt.subplot(1, 2, 1)
    plt.imshow(real_frame)
    plt.title(f"Real Frame - {frame_count}")
    plt.axis('off')

    # Frame predetto
    plt.subplot(1, 2, 2)
    plt.imshow(predicted_frame)
    plt.title(f"Predicted Frame - {frame_count}")
    plt.axis('off')

    plt.show()

def main():
    # Parametri del movimento sinusoidale
    freq_x = 0.5  # Frequenza della sinusoide lungo x
    freq_y = 0.3  # Frequenza della sinusoide lungo y
    freq_phi = 0.1  # Frequenza della sinusoide per la rotazione
    amp_x = 5000.0  # Ampiezza della sinusoide lungo x
    amp_y = 5000.0  # Ampiezza della sinusoide lungo y
    amp_phi = 1.0  # Ampiezza della sinusoide per la rotazione
    R = 0.2  # Raggio massimo della circonferenza
    dt = 0.01  # Timestep fisso
    noise = 0.0  # Rumore bianco gaussiano

    # Parametri del modello
    latent_dim = 8192  # Modifica in base al tuo modello
    action_dim = 8192  # Modifica in base al tuo modello

    # Inizializza il modello
    actor_critic_rnn = ActorCriticRNN(latent_dim, action_dim)

    # Carica i pesi salvati
    actor_critic_rnn.load_state_dict(torch.load("actor_critic_rnn.pth"))
    actor_critic_rnn.eval()  # Imposta il modello in modalità valutazione

    # Encoder pre-addestrato
    encoder = Encoder()
    encoder.load_state_dict(torch.load('encoder.pth'))
    encoder.eval()

    # Decoder pre-addestrato
    decoder = Decoder()
    decoder.load_state_dict(torch.load('decoder.pth'))
    decoder.eval()  

    if not glfw.init():
        print("Impossibile inizializzare GLFW")
        return

    glfw.window_hint(glfw.VISIBLE, glfw.TRUE)
    window = glfw.create_window(800, 800, "MuJoCo Viewer", None, None)
    if not window:
        print("Errore durante la creazione della finestra GLFW")
        glfw.terminate()
        return

    glfw.make_context_current(window)

    model = mujoco.MjModel.from_xml_path(XML_FILE_PATH)
    data = mujoco.MjData(model)

    # Configura la telecamera
    camera = mujoco.MjvCamera()
    camera.type = mujoco.mjtCamera.mjCAMERA_FREE
    camera.lookat = np.array([0, 0, 0])
    camera.distance = 2.0
    camera.azimuth = 90
    camera.elevation = -90

    # Renderer per visualizzare la finestra
    scene = mujoco.MjvScene(model, maxgeom=1000)
    context = mujoco.MjrContext(model, mujoco.mjtFontScale.mjFONTSCALE_150)

    t = 0  # Tempo iniziale

    frame_count = 0

    # Ottieni dimensioni del viewport
    viewport_width, viewport_height = glfw.get_framebuffer_size(window)

    # Prealloca buffer per RGB e profondità
    rgb_buffer = np.zeros((viewport_height, viewport_width, 3), dtype=np.uint8)
    depth_buffer = np.zeros((viewport_height, viewport_width), dtype=np.float32)

    while not glfw.window_should_close(window):
        # Aggiorna il tempo
        t += dt

        # Forze sinusoidali
        force_x = amp_x * np.sin(2 * np.pi * freq_x * t) + noise * np.random.randn()
        force_y = amp_y * np.cos(2 * np.pi * freq_y * t) + noise * np.random.randn()

        # Momento sinusoidale
        torque_phi = amp_phi * np.sin(2 * np.pi * freq_phi * t) + noise * np.random.randn()

        # Controlla che l'oggetto rimanga dentro la circonferenza
        distance = np.sqrt(data.qpos[0] ** 2 + data.qpos[1] ** 2)
        if distance >= R:
            # Forza di rimbalzo verso il centro
            direction_x = -data.qpos[0] / distance
            direction_y = -data.qpos[1] / distance
            force_x += direction_x * 1000.0
            force_y += direction_y * 1000.0

        # Applica le forze e i momenti
        data.qfrc_applied[0] = force_x
        data.qfrc_applied[1] = force_y
        data.qfrc_applied[2] = torque_phi

        # Avanza la simulazione
        mujoco.mj_step(model, data)

        # Debug: verifica posizione e velocità
        print(f"Tempo: {t:.2f}, Posizione: x={data.qpos[0]:.3f}, y={data.qpos[1]:.3f}, phi={data.qpos[2]:.3f}")
        print(f"Velocità: x_vel={data.qvel[0]:.3f}, y_vel={data.qvel[1]:.3f}, phi_vel={data.qvel[2]:.3f}")

        # Renderizza la scena
        mujoco.mjv_updateScene(model, data, mujoco.MjvOption(), None, camera, mujoco.mjtCatBit.mjCAT_ALL, scene)
        viewport = mujoco.MjrRect(0, 0, viewport_width, viewport_height)
        mujoco.mjr_render(viewport, scene, context)

        # Leggi i pixel RGB
        mujoco.mjr_readPixels(rgb_buffer, depth_buffer, viewport, context)

        # Salva il frame corrente come array
        frame_array = save_image_to_array(rgb_buffer.tobytes(), viewport_width, viewport_height, target_size=(64, 64))

        frame = torch.tensor(frame_array).float() / 255.0
        frame = frame.permute(2, 0, 1)
        frame = frame.unsqueeze(0)

        # Ottieni lo stato latente
        with torch.no_grad():
            latent_state = encoder(frame)
            latent_state = latent_state.view(latent_state.size(0), -1).unsqueeze(1)
        
        action, _ = actor_critic_rnn(latent_state)
        predicted_state = latent_state + action

        # Decodifica il frame reale e predetto
        real_frame_decoded = torch.tensor(latent_state).float()
        real_frame_decoded = real_frame_decoded.view(1, 128, 8, 8)
        real_frame_decoded = decoder(real_frame_decoded).detach().squeeze(0).permute(1, 2, 0).cpu().numpy()
        
        predicted_frame_decoded = torch.tensor(predicted_state).float()
        predicted_frame_decoded = predicted_frame_decoded.view(1, 128, 8, 8)
        predicted_frame_decoded = decoder(predicted_frame_decoded).detach().squeeze(0).permute(1, 2, 0).cpu().numpy()

        frame_count += 1

        # Visualizza i frame reali e predetti
        visualize_frames(real_frame_decoded, predicted_frame_decoded, frame_count)

        glfw.swap_buffers(window)
        glfw.poll_events()
        time.sleep(dt)

    glfw.destroy_window(window)
    glfw.terminate()


if __name__ == "__main__":
    main()
# Out:
# Tempo: 0.01, Posizione: x=0.000, y=0.009, phi=-0.012
# Velocità: x_vel=0.030, y_vel=0.947, phi_vel=-1.234
# /var/folders/72/24j7jy9s6sb2xm_dc84kdhm00000gn/T/ipykernel_29949/429546829.py:165: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   real_frame_decoded = torch.tensor(latent_state).float()
# /var/folders/72/24j7jy9s6sb2xm_dc84kdhm00000gn/T/ipykernel_29949/429546829.py:169: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   predicted_frame_decoded = torch.tensor(predicted_state).float()
# Tempo: 0.02, Posizione: x=0.001, y=0.019, phi=-0.024
# Velocità: x_vel=0.059, y_vel=0.930, phi_vel=-1.207
# Tempo: 0.03, Posizione: x=0.002, y=0.026, phi=-0.043
# Velocità: x_vel=0.066, y_vel=0.702, phi_vel=-1.887
# Tempo: 0.04, Posizione: x=0.003, y=0.035, phi=-0.065
# Velocità: x_vel=0.118, y_vel=0.933, phi_vel=-2.179
# Tempo: 0.05, Posizione: x=0.004, y=0.044, phi=-0.087
# Velocità: x_vel=0.146, y_vel=0.927, phi_vel=-2.161
# Tempo: 0.06, Posizione: x=0.006, y=0.054, phi=-0.108
# Velocità: x_vel=0.175, y_vel=0.925, phi_vel=-2.146
# Tempo: 0.07, Posizione: x=0.007, y=0.061, phi=-0.128
# Velocità: x_vel=0.153, y_vel=0.698, phi_vel=-1.961
# Tempo: 0.08, Posizione: x=0.010, y=0.070, phi=-0.150
# Velocità: x_vel=0.233, y_vel=0.925, phi_vel=-2.247
# Tempo: 0.09, Posizione: x=0.012, y=0.079, phi=-0.172
# Velocità: x_vel=0.260, y_vel=0.918, phi_vel=-2.219
# Tempo: 0.10, Posizione: x=0.015, y=0.088, phi=-0.194
# Velocità: x_vel=0.288, y_vel=0.915, phi_vel=-2.194
# Tempo: 0.11, Posizione: x=0.017, y=0.094, phi=-0.211
# Velocità: x_vel=0.200, y_vel=0.579, phi_vel=-1.694
# Tempo: 0.12, Posizione: x=0.020, y=0.101, phi=-0.231
# Velocità: x_vel=0.260, y_vel=0.695, phi_vel=-1.997
# Tempo: 0.13, Posizione: x=0.023, y=0.108, phi=-0.251
# Velocità: x_vel=0.300, y_vel=0.731, phi_vel=-2.021
# Tempo: 0.14, Posizione: x=0.027, y=0.117, phi=-0.274
# Velocità: x_vel=0.398, y_vel=0.902, phi_vel=-2.231
# Tempo: 0.15, Posizione: x=0.031, y=0.126, phi=-0.296
# Velocità: x_vel=0.423, y_vel=0.894, phi_vel=-2.189
# Tempo: 0.16, Posizione: x=0.036, y=0.135, phi=-0.317
# Velocità: x_vel=0.449, y_vel=0.889, phi_vel=-2.150
# Tempo: 0.17, Posizione: x=0.039, y=0.142, phi=-0.338
# Velocità: x_vel=0.356, y_vel=0.668, phi_vel=-2.051
# Tempo: 0.18, Posizione: x=0.044, y=0.151, phi=-0.361
# Velocità: x_vel=0.501, y_vel=0.882, phi_vel=-2.329
# Tempo: 0.19, Posizione: x=0.049, y=0.159, phi=-0.384
# Velocità: x_vel=0.524, y_vel=0.872, phi_vel=-2.276
# Tempo: 0.20, Posizione: x=0.055, y=0.168, phi=-0.406
# Velocità: x_vel=0.548, y_vel=0.866, phi_vel=-2.226
# Tempo: 0.21, Posizione: x=0.061, y=0.177, phi=-0.428
# Velocità: x_vel=0.571, y_vel=0.859, phi_vel=-2.174
# Tempo: 0.22, Posizione: x=0.067, y=0.185, phi=-0.449
# Velocità: x_vel=0.594, y_vel=0.852, phi_vel=-2.119
# Tempo: 0.23, Posizione: x=0.073, y=0.194, phi=-0.470
# Velocità: x_vel=0.616, y_vel=0.845, phi_vel=-2.061
# Tempo: 0.24, Posizione: x=0.077, y=0.199, phi=-0.487
# Velocità: x_vel=0.428, y_vel=0.498, phi_vel=-1.762
# Tempo: 0.25, Posizione: x=0.083, y=0.205, phi=-0.507
# Velocità: x_vel=0.594, y_vel=0.659, phi_vel=-1.982
# Tempo: 0.26, Posizione: x=0.089, y=0.212, phi=-0.526
# Velocità: x_vel=0.609, y_vel=0.649, phi_vel=-1.910
# Tempo: 0.27, Posizione: x=0.094, y=0.216, phi=-0.544
# Velocità: x_vel=0.471, y_vel=0.486, phi_vel=-1.803
# Tempo: 0.28, Posizione: x=0.100, y=0.223, phi=-0.564
# Velocità: x_vel=0.647, y_vel=0.636, phi_vel=-2.015
# Tempo: 0.29, Posizione: x=0.104, y=0.227, phi=-0.580
# Velocità: x_vel=0.417, y_vel=0.398, phi_vel=-1.556
# Tempo: 0.30, Posizione: x=0.111, y=0.233, phi=-0.599
# Velocità: x_vel=0.680, y_vel=0.621, phi_vel=-1.907
# Tempo: 0.31, Posizione: x=0.118, y=0.239, phi=-0.617
# Velocità: x_vel=0.690, y_vel=0.608, phi_vel=-1.818
# Tempo: 0.32, Posizione: x=0.125, y=0.245, phi=-0.634
# Velocità: x_vel=0.704, y_vel=0.600, phi_vel=-1.734
# Tempo: 0.33, Posizione: x=0.132, y=0.251, phi=-0.651
# Velocità: x_vel=0.717, y_vel=0.591, phi_vel=-1.646
# Tempo: 0.34, Posizione: x=0.140, y=0.257, phi=-0.666
# Velocità: x_vel=0.730, y_vel=0.582, phi_vel=-1.555
# Tempo: 0.35, Posizione: x=0.147, y=0.263, phi=-0.681
# Velocità: x_vel=0.741, y_vel=0.572, phi_vel=-1.461
# Tempo: 0.36, Posizione: x=0.154, y=0.268, phi=-0.695
# Velocità: x_vel=0.752, y_vel=0.562, phi_vel=-1.364
# Tempo: 0.37, Posizione: x=0.162, y=0.274, phi=-0.707
# Velocità: x_vel=0.762, y_vel=0.552, phi_vel=-1.263
# Tempo: 0.38, Posizione: x=0.170, y=0.279, phi=-0.719
# Velocità: x_vel=0.771, y_vel=0.542, phi_vel=-1.159
# Tempo: 0.39, Posizione: x=0.178, y=0.284, phi=-0.729
# Velocità: x_vel=0.780, y_vel=0.531, phi_vel=-1.052
# Tempo: 0.40, Posizione: x=0.185, y=0.290, phi=-0.739
# Velocità: x_vel=0.787, y_vel=0.521, phi_vel=-0.942
# Tempo: 0.41, Posizione: x=0.193, y=0.295, phi=-0.747
# Velocità: x_vel=0.794, y_vel=0.510, phi_vel=-0.828
# Tempo: 0.42, Posizione: x=0.201, y=0.300, phi=-0.754
# Velocità: x_vel=0.800, y_vel=0.498, phi_vel=-0.710
# Tempo: 0.43, Posizione: x=0.209, y=0.305, phi=-0.760
# Velocità: x_vel=0.805, y_vel=0.487, phi_vel=-0.589
# Tempo: 0.44, Posizione: x=0.218, y=0.309, phi=-0.765
# Velocità: x_vel=0.809, y_vel=0.475, phi_vel=-0.465
# Tempo: 0.45, Posizione: x=0.226, y=0.314, phi=-0.768
# Velocità: x_vel=0.813, y_vel=0.463, phi_vel=-0.337
# Tempo: 0.46, Posizione: x=0.234, y=0.318, phi=-0.770
# Velocità: x_vel=0.815, y_vel=0.451, phi_vel=-0.205
# Tempo: 0.47, Posizione: x=0.242, y=0.323, phi=-0.771
# Velocità: x_vel=0.817, y_vel=0.439, phi_vel=-0.070
# Tempo: 0.48, Posizione: x=0.250, y=0.327, phi=-0.770
# Velocità: x_vel=0.818, y_vel=0.426, phi_vel=0.068
# Tempo: 0.49, Posizione: x=0.258, y=0.331, phi=-0.768
# Velocità: x_vel=0.818, y_vel=0.413, phi_vel=0.210
# Tempo: 0.50, Posizione: x=0.267, y=0.335, phi=-0.765
# Velocità: x_vel=0.817, y_vel=0.400, phi_vel=0.356
# Tempo: 0.51, Posizione: x=0.275, y=0.339, phi=-0.759
# Velocità: x_vel=0.815, y_vel=0.387, phi_vel=0.506
# Tempo: 0.52, Posizione: x=0.281, y=0.342, phi=-0.775
# Velocità: x_vel=0.609, y_vel=0.285, phi_vel=-1.565
# Tempo: 0.53, Posizione: x=0.289, y=0.346, phi=-0.792
# Velocità: x_vel=0.812, y_vel=0.361, phi_vel=-1.682
# Tempo: 0.54, Posizione: x=0.297, y=0.349, phi=-0.807
# Velocità: x_vel=0.804, y_vel=0.346, phi_vel=-1.518
# Tempo: 0.55, Posizione: x=0.303, y=0.352, phi=-0.819
# Velocità: x_vel=0.642, y_vel=0.267, phi_vel=-1.148
# Tempo: 0.56, Posizione: x=0.311, y=0.355, phi=-0.831
# Velocità: x_vel=0.796, y_vel=0.319, phi_vel=-1.193
# Tempo: 0.57, Posizione: x=0.319, y=0.358, phi=-0.841
# Velocità: x_vel=0.786, y_vel=0.303, phi_vel=-1.019
# Tempo: 0.58, Posizione: x=0.327, y=0.361, phi=-0.849
# Velocità: x_vel=0.778, y_vel=0.289, phi_vel=-0.846
# Tempo: 0.59, Posizione: x=0.335, y=0.364, phi=-0.856
# Velocità: x_vel=0.769, y_vel=0.274, phi_vel=-0.669
# Tempo: 0.60, Posizione: x=0.342, y=0.366, phi=-0.861
# Velocità: x_vel=0.759, y_vel=0.259, phi_vel=-0.488
# Tempo: 0.61, Posizione: x=0.350, y=0.369, phi=-0.864
# Velocità: x_vel=0.749, y_vel=0.244, phi_vel=-0.305
# Tempo: 0.62, Posizione: x=0.355, y=0.370, phi=-0.878
# Velocità: x_vel=0.553, y_vel=0.176, phi_vel=-1.379
# Tempo: 0.63, Posizione: x=0.361, y=0.372, phi=-0.892
# Velocità: x_vel=0.550, y_vel=0.166, phi_vel=-1.433
# Tempo: 0.64, Posizione: x=0.368, y=0.374, phi=-0.907
# Velocità: x_vel=0.716, y_vel=0.199, phi_vel=-1.460
# Tempo: 0.65, Posizione: x=0.375, y=0.376, phi=-0.919
# Velocità: x_vel=0.699, y_vel=0.182, phi_vel=-1.259
# Tempo: 0.66, Posizione: x=0.379, y=0.377, phi=-0.930
# Velocità: x_vel=0.432, y_vel=0.108, phi_vel=-1.112
# Tempo: 0.67, Posizione: x=0.386, y=0.378, phi=-0.942
# Velocità: x_vel=0.674, y_vel=0.152, phi_vel=-1.223
# Tempo: 0.68, Posizione: x=0.392, y=0.380, phi=-0.953
# Velocità: x_vel=0.653, y_vel=0.135, phi_vel=-1.010
# Tempo: 0.69, Posizione: x=0.399, y=0.381, phi=-0.961
# Velocità: x_vel=0.636, y_vel=0.119, phi_vel=-0.800
# Tempo: 0.70, Posizione: x=0.403, y=0.382, phi=-0.972
# Velocità: x_vel=0.464, y_vel=0.081, phi_vel=-1.129
# Tempo: 0.71, Posizione: x=0.408, y=0.382, phi=-0.983
# Velocità: x_vel=0.455, y_vel=0.069, phi_vel=-1.119
# Tempo: 0.72, Posizione: x=0.413, y=0.383, phi=-0.992
# Velocità: x_vel=0.471, y_vel=0.056, phi_vel=-0.940
# Tempo: 0.73, Posizione: x=0.418, y=0.384, phi=-1.001
# Velocità: x_vel=0.564, y_vel=0.053, phi_vel=-0.849
# Tempo: 0.74, Posizione: x=0.424, y=0.384, phi=-1.007
# Velocità: x_vel=0.541, y_vel=0.037, phi_vel=-0.621
# Tempo: 0.75, Posizione: x=0.429, y=0.384, phi=-1.011
# Velocità: x_vel=0.520, y_vel=0.020, phi_vel=-0.391
# Tempo: 0.76, Posizione: x=0.434, y=0.384, phi=-1.013
# Velocità: x_vel=0.498, y_vel=0.004, phi_vel=-0.158
# Tempo: 0.77, Posizione: x=0.439, y=0.384, phi=-1.012
# Velocità: x_vel=0.476, y_vel=-0.013, phi_vel=0.078
# Tempo: 0.78, Posizione: x=0.442, y=0.384, phi=-1.008
# Velocità: x_vel=0.364, y_vel=-0.024, phi_vel=0.412
# Tempo: 0.79, Posizione: x=0.447, y=0.383, phi=-1.002
# Velocità: x_vel=0.431, y_vel=-0.046, phi_vel=0.558
# Tempo: 0.80, Posizione: x=0.450, y=0.383, phi=-1.008
# Velocità: x_vel=0.303, y_vel=-0.045, phi_vel=-0.538
# Tempo: 0.81, Posizione: x=0.454, y=0.382, phi=-1.011
# Velocità: x_vel=0.383, y_vel=-0.080, phi_vel=-0.392
# Tempo: 0.82, Posizione: x=0.457, y=0.381, phi=-1.013
# Velocità: x_vel=0.356, y_vel=-0.097, phi_vel=-0.139
# Tempo: 0.83, Posizione: x=0.460, y=0.380, phi=-1.012
# Velocità: x_vel=0.330, y_vel=-0.114, phi_vel=0.114
# Tempo: 0.84, Posizione: x=0.463, y=0.379, phi=-1.008
# Velocità: x_vel=0.304, y_vel=-0.131, phi_vel=0.371
# Tempo: 0.85, Posizione: x=0.466, y=0.378, phi=-1.011
# Velocità: x_vel=0.207, y_vel=-0.108, phi_vel=-0.255
# Tempo: 0.86, Posizione: x=0.468, y=0.376, phi=-1.011
# Velocità: x_vel=0.253, y_vel=-0.165, phi_vel=-0.045
# Tempo: 0.87, Posizione: x=0.470, y=0.374, phi=-1.009
# Velocità: x_vel=0.224, y_vel=-0.181, phi_vel=0.221
# Tempo: 0.88, Posizione: x=0.472, y=0.372, phi=-1.004
# Velocità: x_vel=0.197, y_vel=-0.198, phi_vel=0.489
# Tempo: 0.89, Posizione: x=0.474, y=0.371, phi=-1.004
# Velocità: x_vel=0.124, y_vel=-0.159, phi_vel=0.006
# Tempo: 0.90, Posizione: x=0.475, y=0.369, phi=-1.003
# Velocità: x_vel=0.104, y_vel=-0.173, phi_vel=0.038
# Tempo: 0.91, Posizione: x=0.476, y=0.366, phi=-1.000
# Velocità: x_vel=0.113, y_vel=-0.250, phi_vel=0.315
# Tempo: 0.92, Posizione: x=0.477, y=0.364, phi=-0.994
# Velocità: x_vel=0.083, y_vel=-0.265, phi_vel=0.593
# Tempo: 0.93, Posizione: x=0.477, y=0.361, phi=-0.986
# Velocità: x_vel=0.054, y_vel=-0.282, phi_vel=0.874
# Tempo: 0.94, Posizione: x=0.477, y=0.358, phi=-0.974
# Velocità: x_vel=0.025, y_vel=-0.299, phi_vel=1.156
# Tempo: 0.95, Posizione: x=0.477, y=0.355, phi=-0.960
# Velocità: x_vel=-0.004, y_vel=-0.315, phi_vel=1.441
# Tempo: 0.96, Posizione: x=0.477, y=0.351, phi=-0.942
# Velocità: x_vel=-0.033, y_vel=-0.332, phi_vel=1.729
# Tempo: 0.97, Posizione: x=0.476, y=0.348, phi=-0.922
# Velocità: x_vel=-0.063, y_vel=-0.348, phi_vel=2.018
# Tempo: 0.98, Posizione: x=0.475, y=0.344, phi=-0.899
# Velocità: x_vel=-0.093, y_vel=-0.364, phi_vel=2.310
# Tempo: 0.99, Posizione: x=0.474, y=0.340, phi=-0.873
# Velocità: x_vel=-0.122, y_vel=-0.381, phi_vel=2.603
# Tempo: 1.00, Posizione: x=0.473, y=0.336, phi=-0.844
# Velocità: x_vel=-0.152, y_vel=-0.397, phi_vel=2.899
# Tempo: 1.01, Posizione: x=0.471, y=0.332, phi=-0.812
# Velocità: x_vel=-0.182, y_vel=-0.413, phi_vel=3.196
# Tempo: 1.02, Posizione: x=0.469, y=0.329, phi=-0.801
# Velocità: x_vel=-0.163, y_vel=-0.323, phi_vel=1.105
# Tempo: 1.03, Posizione: x=0.467, y=0.326, phi=-0.791
# Velocità: x_vel=-0.185, y_vel=-0.337, phi_vel=1.047
# Tempo: 1.04, Posizione: x=0.465, y=0.322, phi=-0.780
# Velocità: x_vel=-0.208, y_vel=-0.349, phi_vel=1.109
# Tempo: 1.05, Posizione: x=0.462, y=0.317, phi=-0.764
# Velocità: x_vel=-0.301, y_vel=-0.478, phi_vel=1.577
# Tempo: 1.06, Posizione: x=0.459, y=0.313, phi=-0.745
# Velocità: x_vel=-0.329, y_vel=-0.492, phi_vel=1.881
# Tempo: 1.07, Posizione: x=0.455, y=0.308, phi=-0.723
# Velocità: x_vel=-0.358, y_vel=-0.507, phi_vel=2.188
# Tempo: 1.08, Posizione: x=0.452, y=0.304, phi=-0.709
# Velocità: x_vel=-0.293, y_vel=-0.394, phi_vel=1.429
# Tempo: 1.09, Posizione: x=0.448, y=0.298, phi=-0.689
# Velocità: x_vel=-0.417, y_vel=-0.540, phi_vel=1.949
# Tempo: 1.10, Posizione: x=0.445, y=0.294, phi=-0.669
# Velocità: x_vel=-0.357, y_vel=-0.444, phi_vel=2.076
