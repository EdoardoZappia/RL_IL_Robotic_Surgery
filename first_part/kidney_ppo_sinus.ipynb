# %%
import mujoco
import glfw
import numpy as np
import time
from gymnasium import Env, spaces

class ForceMatchingEnv(Env):
    def __init__(self, model_path, target_positions_path, max_distance=0.01):
        super(ForceMatchingEnv, self).__init__()

        self.model = mujoco.MjModel.from_xml_path(model_path)
        self.data = mujoco.MjData(self.model)

        # Definizione dello stato (x, y, vel_x, vel_y)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(4,), dtype=np.float32)

        # Azioni: (forza_x, forza_y)
        self.action_space = spaces.Box(low=-5, high=5, shape=(2,), dtype=np.float32)

        # Carica le posizioni target
        self.target_positions = np.load(target_positions_path)

        self.step_count = 0
        self.max_steps = 140
        self.max_distance = max_distance  # Distanza massima oltre la quale l'episodio termina

        # Inizializza GLFW per la visualizzazione
        if not glfw.init():
            raise Exception("Impossibile inizializzare GLFW")

        glfw.window_hint(glfw.VISIBLE, glfw.TRUE)
        self.window = glfw.create_window(800, 800, "MuJoCo Viewer", None, None)
        if not self.window:
            glfw.terminate()
            raise Exception("Errore nella creazione della finestra GLFW")

        glfw.make_context_current(self.window)

        # Configura la telecamera
        self.camera = mujoco.MjvCamera()
        self.camera.type = mujoco.mjtCamera.mjCAMERA_FREE
        self.camera.lookat = np.array([0, 0, 0])
        self.camera.distance = 2.0
        self.camera.azimuth = 90
        self.camera.elevation = -90

        # Renderer
        self.scene = mujoco.MjvScene(self.model, maxgeom=1000)
        self.context = mujoco.MjrContext(self.model, mujoco.mjtFontScale.mjFONTSCALE_150)

    def reset(self, seed=None, options=None):
        mujoco.mj_resetData(self.model, self.data)
        self.data.qacc[:] = 0  # Resetta le accelerazioni per evitare instabilità
        self.data.qpos[0] = self.target_positions[0][0]
        self.data.qpos[1] = self.target_positions[0][1]
        self.data.qvel[:] = 0
        mujoco.mj_forward(self.model, self.data)

        self.step_count = 0

        obs = np.array([self.data.qpos[0], self.data.qpos[1], self.data.qvel[0], self.data.qvel[1]])
        return obs, {}

    def step(self, action):
        action = np.array(action, dtype=np.float32)

        self.data.qfrc_applied[0] = action[0] * 500
        self.data.qfrc_applied[1] = action[1] * 500

        mujoco.mj_step(self.model, self.data)

        obs = np.array([self.data.qpos[0], self.data.qpos[1], self.data.qvel[0], self.data.qvel[1]])

        target_pos = self.target_positions[self.step_count]

        dist_x = np.abs(obs[0] - target_pos[0])
        dist_y = np.abs(obs[1] - target_pos[1])
        #distance = np.linalg.norm(obs[:2] - target_pos)

        flag = dist_x <= self.max_distance  and dist_y <= self.max_distance

        # Reward discreto
        reward = +1 if flag else 0

        # Termina episodio se troppo lontano
        done = (not flag) or self.step_count >= self.max_steps

        self.step_count += 1
        return obs, reward, done, False, {}

    def render(self):
        if glfw.window_should_close(self.window):
            glfw.destroy_window(self.window)
            glfw.terminate()
            return

        mujoco.mjv_updateScene(self.model, self.data, mujoco.MjvOption(), None, self.camera, mujoco.mjtCatBit.mjCAT_ALL, self.scene)
        viewport_width, viewport_height = glfw.get_framebuffer_size(self.window)
        viewport = mujoco.MjrRect(0, 0, viewport_width, viewport_height)
        mujoco.mjr_render(viewport, self.scene, self.context)

        glfw.swap_buffers(self.window)
        glfw.poll_events()

    def close(self):
        glfw.destroy_window(self.window)
        glfw.terminate()

# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Normal
import matplotlib.pyplot as plt

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

MAX_MEMORY = 200
NUM_NEURONS = 256
LR_CRITIC = 0.0005
LR_ACTOR = 0.001
GAMMA = 0.99
LAMBDA = 0.95
CLIP_EPS = 0.2
K_EPOCH = 10
EARLY_STOP_THRESHOLD = 120
EPISODES_EARLY_STOP = 30
MAX_EPISODES = 20000

def compute_advantages(rewards, values, dones, gamma=GAMMA, lam=LAMBDA):
    advantages = []
    gae = 0
    values = values + [0]  # Append a 0 for the last state
    for t in reversed(range(len(rewards))):
        delta = rewards[t] + gamma * values[t + 1] * (1 - dones[t]) - values[t]
        gae = delta + gamma * lam * (1 - dones[t]) * gae
        advantages.insert(0, gae)
    return torch.tensor(advantages, dtype=torch.float32)

def compute_returns(rewards, dones, gamma=0.99):
    returns = []
    G = 0
    for reward, done in zip(reversed(rewards), reversed(dones)):
        G = reward + gamma * G * (1 - done)  # Reset if episode ended
        returns.insert(0, G)
    return torch.tensor(returns, dtype=torch.float32)

class PolicyNet(nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(PolicyNet, self).__init__()
        
        self.dense=nn.Sequential(
            nn.Linear(num_inputs, NUM_NEURONS),
            nn.ReLU(),
            nn.Linear(NUM_NEURONS, NUM_NEURONS),
            nn.ReLU(),
        )

        # Output della media delle azioni
        self.mean_layer = nn.Linear(NUM_NEURONS, num_actions)
        
        # Output della deviazione standard (log std per stabilità numerica)
        self.log_std_layer = nn.Linear(NUM_NEURONS, num_actions)

    def forward(self, x):
        x = self.dense(x)
        mean = self.mean_layer(x)
        
        # Il log_std viene trasformato in std con exp() per garantire valori positivi
        log_std = self.log_std_layer(x)
        std = torch.exp(log_std)
        
        return mean, std

class ValueNet(nn.Module):
    def __init__(self, num_inputs):
        super(ValueNet, self).__init__()
        self.fc1 = nn.Linear(num_inputs, NUM_NEURONS)
        self.fc2 = nn.Linear(NUM_NEURONS, NUM_NEURONS)
        self.fc3 = nn.Linear(NUM_NEURONS, 1)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

class PPOAgent(nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(PPOAgent, self).__init__()
        self.actor = PolicyNet(num_inputs, num_actions)
        self.critic = ValueNet(num_inputs)
        self.optimizer_actor = optim.Adam(self.actor.parameters(), lr=LR_ACTOR)
        self.optimizer_critic = optim.Adam(self.critic.parameters(), lr=LR_CRITIC)
        self.buffer = []
    
    def get_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)
        mu, sigma = self.actor(state)
        dist = Normal(mu, sigma)
        action = dist.sample()
        log_prob = dist.log_prob(action).sum()
        return action.detach().numpy(), log_prob

    def store_transition(self, transition):
        self.buffer.append(transition)
    
    def update(self):
        states, actions, rewards, dones, old_log_probs = zip(*self.buffer)
        old_log_probs = torch.stack(old_log_probs)
        states = torch.tensor(states, dtype=torch.float32)
        actions = torch.tensor(actions, dtype=torch.float32)  # Azioni continue
        rewards = torch.tensor(rewards, dtype=torch.float32)
        dones = torch.tensor(dones, dtype=torch.float32)
        values = self.critic(states).squeeze()
        advantages = compute_advantages(rewards.tolist(), values.tolist(), dones.tolist())
        returns = compute_returns(rewards.tolist(), dones.tolist())

        for _ in range(K_EPOCH):
            mu, sigma = self.actor(states)
            new_dist = Normal(mu, sigma)
            new_log_probs = new_dist.log_prob(actions).sum(dim=1)

            ratio = torch.exp(new_log_probs - old_log_probs.detach())
            surr1 = ratio * advantages
            surr2 = torch.clamp(ratio, 1 - CLIP_EPS, 1 + CLIP_EPS) * advantages
            policy_loss = -torch.min(surr1, surr2).mean()
            #entropy_loss = -0.01 * new_dist.entropy().mean()  # Il valore 0.01 regola l'importanza dell'esplorazione
            #policy_loss += entropy_loss
            value_loss = F.mse_loss(self.critic(states).squeeze(), returns)

            self.optimizer_actor.zero_grad()
            self.optimizer_critic.zero_grad()
            policy_loss.backward()
            value_loss.backward()
            self.optimizer_actor.step()
            self.optimizer_critic.step()

        self.buffer.clear()

def train_ppo(num_episodes=MAX_EPISODES):
    env = ForceMatchingEnv("/Users/edoardozappia/Desktop/Tesi_Magistrale/irregular_shape_2D.xml", "/Users/edoardozappia/Desktop/Tesi_Magistrale/target_positions_semicircle.npy")
    num_inputs = env.observation_space.shape[0]
    num_actions = env.action_space.shape[0]  # Ora è continuo
    agent = PPOAgent(num_inputs, num_actions)
    reward_history = []
    
    for episode in range(num_episodes):
        #print(f"Episode: {episode}")
        state, _ = env.reset()
        #print(state.shape)
        done = False
        early_stop = False
        total_reward = 0
        
        while not done:
            action, log_prob = agent.get_action(state)
            #print(state.shape)
            next_state, reward, terminated, truncated, _ = env.step(action)
            #print(f"Reward: {reward}")
            done = terminated or truncated
            #print(f"done: {done}")
            agent.store_transition((state, action, reward, done, log_prob))
            state = next_state
            total_reward += reward

        reward_history.append(total_reward)

        if len(reward_history) >= 50 and np.mean(reward_history[-EPISODES_EARLY_STOP:]) > EARLY_STOP_THRESHOLD:
            print(f"Early stopping at episode {episode}, average reward: {np.mean(reward_history[-30:])}")
            early_stop = True
            break
        
        if early_stop:
            break

        if len(agent.buffer) >= MAX_MEMORY:
            agent.update()
        
        if episode % 10 == 0:
            print(f"Episode {episode}, Total Reward: {total_reward}")
    
    env.close()

    plt.plot(reward_history)
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.title('Training Progress')
    plt.show()

    return agent

if __name__ == "__main__":
    trained_agent = train_ppo()
# Out:
# Episode 0, Total Reward: 5
# Episode 10, Total Reward: 6
# Episode 20, Total Reward: 6
# /var/folders/72/24j7jy9s6sb2xm_dc84kdhm00000gn/T/ipykernel_19468/1394031831.py:106: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:278.)
#   states = torch.tensor(states, dtype=torch.float32)
# Episode 30, Total Reward: 5
# Episode 40, Total Reward: 6
# Episode 50, Total Reward: 12
# Episode 60, Total Reward: 11
# Episode 70, Total Reward: 7
# Episode 80, Total Reward: 8
# Episode 90, Total Reward: 7
# Episode 100, Total Reward: 9
# Episode 110, Total Reward: 10
# Episode 120, Total Reward: 10
# Episode 130, Total Reward: 10
# Episode 140, Total Reward: 10
# Episode 150, Total Reward: 9
# Episode 160, Total Reward: 10
# Episode 170, Total Reward: 8
# Episode 180, Total Reward: 12
# Episode 190, Total Reward: 13
# Episode 200, Total Reward: 10
# Episode 210, Total Reward: 13
# Episode 220, Total Reward: 14
# Episode 230, Total Reward: 13
# Episode 240, Total Reward: 12
# Episode 250, Total Reward: 17
# Episode 260, Total Reward: 14
# Episode 270, Total Reward: 11
# Episode 280, Total Reward: 12
# Episode 290, Total Reward: 12
# Episode 5840, Total Reward: 39
# Episode 5850, Total Reward: 75
# Episode 5860, Total Reward: 95
# Episode 5870, Total Reward: 77
# Episode 5880, Total Reward: 81
# Episode 5890, Total Reward: 102
# Episode 5900, Total Reward: 82
# Episode 5910, Total Reward: 89
# Episode 5920, Total Reward: 22
# Episode 5930, Total Reward: 28
# Episode 5940, Total Reward: 78
# Episode 5950, Total Reward: 85
# Episode 5960, Total Reward: 47
# Episode 5970, Total Reward: 77
# Episode 5980, Total Reward: 88
# Episode 5990, Total Reward: 94
# Episode 6000, Total Reward: 70
# Episode 6010, Total Reward: 108
# Episode 6020, Total Reward: 27
# Episode 6030, Total Reward: 77
# Episode 6040, Total Reward: 68
# Episode 6050, Total Reward: 55
# Episode 6060, Total Reward: 72
# Episode 6070, Total Reward: 85
# Episode 6080, Total Reward: 65
# Episode 6090, Total Reward: 86
# Episode 6100, Total Reward: 100
# Episode 6110, Total Reward: 26
# Episode 6120, Total Reward: 78
# Episode 6130, Total Reward: 100
# Episode 6140, Total Reward: 108
# Episode 6150, Total Reward: 86
# Episode 6160, Total Reward: 90
# Episode 6170, Total Reward: 72
# Episode 6180, Total Reward: 50
# Episode 6190, Total Reward: 115
# Episode 6200, Total Reward: 120
# Episode 6210, Total Reward: 64
# Episode 6220, Total Reward: 132
# Episode 6230, Total Reward: 75
# Episode 6240, Total Reward: 64
# Episode 6250, Total Reward: 58
# Episode 6260, Total Reward: 117
# Episode 6270, Total Reward: 126
# Episode 6280, Total Reward: 118
# Episode 6290, Total Reward: 130
# Episode 6300, Total Reward: 89
# Episode 6310, Total Reward: 91
# Episode 6320, Total Reward: 31
# Episode 6330, Total Reward: 123
# Episode 6340, Total Reward: 124
# Episode 6350, Total Reward: 72
# Episode 6360, Total Reward: 63
# Episode 6370, Total Reward: 48
# Episode 6380, Total Reward: 66
# Episode 6390, Total Reward: 52
# Episode 6400, Total Reward: 47
# Episode 6410, Total Reward: 49
# Episode 6420, Total Reward: 106
# Episode 6430, Total Reward: 112
# Episode 6440, Total Reward: 131
# Episode 6450, Total Reward: 64
# Episode 6460, Total Reward: 130
# Episode 6470, Total Reward: 70
# Episode 6480, Total Reward: 25
# Episode 6490, Total Reward: 74
# Episode 6500, Total Reward: 84
# Episode 6510, Total Reward: 113
# Episode 6520, Total Reward: 108
# Episode 6530, Total Reward: 54
# Episode 6540, Total Reward: 128
# Episode 6550, Total Reward: 138
# Episode 6560, Total Reward: 140
# Early stopping at episode 6561, average reward: 122.16666666666667

# %%
import numpy as np
import torch
import mujoco
import time
import matplotlib.pyplot as plt

# Inizializza l'ambiente
env = ForceMatchingEnv("/Users/edoardozappia/Desktop/Tesi_Magistrale/irregular_shape_2D.xml", "/Users/edoardozappia/Desktop/Tesi_Magistrale/target_positions_semicircle.npy")
target_positions = np.load("/Users/edoardozappia/Desktop/Tesi_Magistrale/target_positions_semicircle.npy")
# Assumi che il modello PPO sia già stato allenato e in memoria
agent = trained_agent
agent.eval()  # Metti il modello in modalità valutazione

# Reset dell'ambiente
state, _ = env.reset()
done = False

# Liste per il logging
episode_rewards = []
positions = []
actions_list = []

print("▶️ Test della policy appresa...")
i = 1

while not done:
    # Ottieni l'azione dalla policy senza esplorazione
    with torch.no_grad():
        action, _ = agent.get_action(state)

    # Esegui l'azione nell'ambiente
    next_state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated

    # Salva i dati
    episode_rewards.append(reward)
    positions.append((env.data.qpos[0], env.data.qpos[1]))
    actions_list.append(action)

    # Stampa informazioni
    print(f"Posizione: x={env.data.qpos[0]:.3f}, y={env.data.qpos[1]:.3f} | Posizione target: x={target_positions[i][0]:.3f}, y={target_positions[i][1]:.3f} Azione: {action} | Reward: {reward:.3f}")

    i += 1

    # Aggiorna lo stato
    state = next_state

    # Visualizza l'ambiente (solo se sei su una macchina con GUI)
    env.render()
    time.sleep(0.05)  # Piccola pausa per visualizzazione fluida

env.close()

# ▶️ **Plotta le azioni nel tempo**
actions_list = np.array(actions_list)
plt.figure(figsize=(12, 5))
plt.plot(actions_list[:, 0], label="Forza X")
plt.plot(actions_list[:, 1], label="Forza Y")
plt.xlabel("Step")
plt.ylabel("Forza Applicata")
plt.title("Evoluzione delle Azioni della Policy Appresa")
plt.legend()
plt.show()

# ▶️ **Plotta la traiettoria seguita**
positions = np.array(positions)
plt.figure(figsize=(6, 6))
plt.plot(positions[:, 0], positions[:, 1], marker="o", linestyle="-", markersize=3, label="Traiettoria")
plt.scatter([positions[0, 0]], [positions[0, 1]], color="red", label="Start", marker="o", s=100)
plt.scatter([positions[-1, 0]], [positions[-1, 1]], color="green", label="End", marker="x", s=100)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Traiettoria della Policy Appresa")
plt.legend()
plt.grid()
plt.show()

# ▶️ **Plotta l'andamento della ricompensa**
plt.figure(figsize=(10, 4))
plt.plot(episode_rewards, label="Reward")
plt.xlabel("Step")
plt.ylabel("Reward")
plt.title("Andamento della Ricompensa")
plt.legend()
plt.show()
# Out:
# ▶️ Test della policy appresa...
# Posizione: x=-0.003, y=-0.000 | Posizione target: x=-0.002, y=-0.000 Azione: [-2.7748094  -0.36283258] | Reward: 1.000
# Posizione: x=-0.003, y=-0.000 | Posizione target: x=-0.003, y=-0.000 Azione: [-1.28669    0.2428912] | Reward: 1.000
# Posizione: x=-0.008, y=-0.001 | Posizione target: x=-0.005, y=-0.000 Azione: [-4.4540186 -1.1094629] | Reward: 1.000
# Posizione: x=-0.009, y=-0.000 | Posizione target: x=-0.007, y=-0.000 Azione: [-1.7989181   0.92900133] | Reward: 1.000
# Posizione: x=-0.011, y=-0.000 | Posizione target: x=-0.008, y=-0.000 Azione: [-1.5213772   0.18008202] | Reward: 1.000
# Posizione: x=-0.012, y=-0.001 | Posizione target: x=-0.010, y=-0.001 Azione: [-1.2112327 -1.1529281] | Reward: 1.000
# Posizione: x=-0.015, y=-0.001 | Posizione target: x=-0.011, y=-0.001 Azione: [-3.073713  0.607579] | Reward: 1.000
# Posizione: x=-0.016, y=-0.001 | Posizione target: x=-0.013, y=-0.001 Azione: [-1.870999   -0.34014177] | Reward: 1.000
# Posizione: x=-0.019, y=-0.002 | Posizione target: x=-0.015, y=-0.001 Azione: [-2.4938083 -0.705642 ] | Reward: 1.000
# Posizione: x=-0.020, y=-0.002 | Posizione target: x=-0.016, y=-0.001 Azione: [-1.4320333  -0.47364527] | Reward: 1.000
# Posizione: x=-0.021, y=-0.004 | Posizione target: x=-0.018, y=-0.002 Azione: [-0.70252645 -1.8856711 ] | Reward: 1.000
# Posizione: x=-0.024, y=-0.004 | Posizione target: x=-0.019, y=-0.002 Azione: [-3.2393975  -0.23294133] | Reward: 1.000
# Posizione: x=-0.025, y=-0.004 | Posizione target: x=-0.021, y=-0.002 Azione: [-0.9311424 -0.2377365] | Reward: 1.000
# Posizione: x=-0.027, y=-0.006 | Posizione target: x=-0.023, y=-0.003 Azione: [-2.3995109 -1.3506877] | Reward: 1.000
# Posizione: x=-0.027, y=-0.006 | Posizione target: x=-0.024, y=-0.003 Azione: [-0.6901577  -0.11351702] | Reward: 1.000
# Posizione: x=-0.030, y=-0.007 | Posizione target: x=-0.026, y=-0.003 Azione: [-2.9028943 -1.3028027] | Reward: 1.000
# Posizione: x=-0.031, y=-0.008 | Posizione target: x=-0.027, y=-0.004 Azione: [-1.7689644  -0.86850977] | Reward: 1.000
# Posizione: x=-0.034, y=-0.009 | Posizione target: x=-0.029, y=-0.004 Azione: [-3.1112134 -1.7016511] | Reward: 1.000
# Posizione: x=-0.034, y=-0.010 | Posizione target: x=-0.030, y=-0.005 Azione: [-0.16261768 -0.8339841 ] | Reward: 1.000
# Posizione: x=-0.037, y=-0.010 | Posizione target: x=-0.032, y=-0.005 Azione: [-3.1708655 -0.5889262] | Reward: 1.000
# Posizione: x=-0.037, y=-0.011 | Posizione target: x=-0.034, y=-0.006 Azione: [-0.2088443  -0.15737024] | Reward: 1.000
# Posizione: x=-0.040, y=-0.011 | Posizione target: x=-0.035, y=-0.006 Azione: [-2.7954175 -0.6298992] | Reward: 1.000
# Posizione: x=-0.040, y=-0.012 | Posizione target: x=-0.037, y=-0.007 Azione: [-0.1537981  -0.45288187] | Reward: 1.000
# Posizione: x=-0.042, y=-0.012 | Posizione target: x=-0.039, y=-0.008 Azione: [-2.186143   -0.91985494] | Reward: 1.000
# Posizione: x=-0.043, y=-0.013 | Posizione target: x=-0.040, y=-0.009 Azione: [-1.047139  -0.5854696] | Reward: 1.000
# Posizione: x=-0.045, y=-0.014 | Posizione target: x=-0.042, y=-0.009 Azione: [-2.1194537 -1.0538442] | Reward: 1.000
# Posizione: x=-0.047, y=-0.015 | Posizione target: x=-0.044, y=-0.010 Azione: [-2.3878546  -0.68457973] | Reward: 1.000
# Posizione: x=-0.048, y=-0.015 | Posizione target: x=-0.045, y=-0.011 Azione: [-0.528181   -0.98095965] | Reward: 1.000
# Posizione: x=-0.051, y=-0.016 | Posizione target: x=-0.047, y=-0.011 Azione: [-3.31839    -0.73088443] | Reward: 1.000
# Posizione: x=-0.051, y=-0.016 | Posizione target: x=-0.048, y=-0.012 Azione: [-0.32639033 -0.27528706] | Reward: 1.000
# Posizione: x=-0.053, y=-0.017 | Posizione target: x=-0.049, y=-0.013 Azione: [-2.9551728 -1.1291867] | Reward: 1.000
# Posizione: x=-0.054, y=-0.018 | Posizione target: x=-0.051, y=-0.014 Azione: [-0.5295546  -0.39881516] | Reward: 1.000
# Posizione: x=-0.056, y=-0.018 | Posizione target: x=-0.053, y=-0.015 Azione: [-2.644927  -1.0200775] | Reward: 1.000
# Posizione: x=-0.057, y=-0.019 | Posizione target: x=-0.054, y=-0.016 Azione: [-1.3515058  -0.95239097] | Reward: 1.000
# Posizione: x=-0.057, y=-0.020 | Posizione target: x=-0.056, y=-0.017 Azione: [-0.38163948 -1.00473   ] | Reward: 1.000
# Posizione: x=-0.059, y=-0.020 | Posizione target: x=-0.057, y=-0.018 Azione: [-3.0478358 -0.8179261] | Reward: 1.000
# Posizione: x=-0.061, y=-0.021 | Posizione target: x=-0.059, y=-0.019 Azione: [-1.4778664 -1.0622244] | Reward: 1.000
# Posizione: x=-0.061, y=-0.022 | Posizione target: x=-0.060, y=-0.019 Azione: [-0.7262748 -0.996754 ] | Reward: 1.000
# Posizione: x=-0.064, y=-0.023 | Posizione target: x=-0.061, y=-0.020 Azione: [-2.5209     -0.98271304] | Reward: 1.000
# Posizione: x=-0.064, y=-0.024 | Posizione target: x=-0.062, y=-0.021 Azione: [-0.78946054 -1.0720736 ] | Reward: 1.000
# Posizione: x=-0.066, y=-0.025 | Posizione target: x=-0.064, y=-0.022 Azione: [-1.5649233 -1.0287244] | Reward: 1.000
# Posizione: x=-0.066, y=-0.026 | Posizione target: x=-0.065, y=-0.023 Azione: [-0.6318339 -1.307487 ] | Reward: 1.000
# Posizione: x=-0.067, y=-0.027 | Posizione target: x=-0.067, y=-0.024 Azione: [-1.764581 -1.194497] | Reward: 1.000
# Posizione: x=-0.068, y=-0.028 | Posizione target: x=-0.068, y=-0.026 Azione: [-0.39682716 -1.3855565 ] | Reward: 1.000
# Posizione: x=-0.070, y=-0.029 | Posizione target: x=-0.069, y=-0.027 Azione: [-2.5178032 -1.211667 ] | Reward: 1.000
# Posizione: x=-0.071, y=-0.030 | Posizione target: x=-0.071, y=-0.028 Azione: [-1.1221724 -1.0019962] | Reward: 1.000
# Posizione: x=-0.072, y=-0.032 | Posizione target: x=-0.072, y=-0.029 Azione: [-1.385172  -1.6905433] | Reward: 1.000
# Posizione: x=-0.074, y=-0.033 | Posizione target: x=-0.074, y=-0.030 Azione: [-1.2669402 -1.2472526] | Reward: 1.000
# Posizione: x=-0.075, y=-0.034 | Posizione target: x=-0.075, y=-0.032 Azione: [-1.6777886 -1.6281087] | Reward: 1.000
# Posizione: x=-0.075, y=-0.036 | Posizione target: x=-0.076, y=-0.033 Azione: [ 0.3229977 -1.6483101] | Reward: 1.000
# Posizione: x=-0.077, y=-0.037 | Posizione target: x=-0.077, y=-0.034 Azione: [-2.7676356 -1.340215 ] | Reward: 1.000
# Posizione: x=-0.077, y=-0.038 | Posizione target: x=-0.079, y=-0.036 Azione: [ 0.32550627 -0.86120415] | Reward: 1.000
# Posizione: x=-0.079, y=-0.039 | Posizione target: x=-0.080, y=-0.037 Azione: [-2.3616798 -1.8050636] | Reward: 1.000
# Posizione: x=-0.080, y=-0.040 | Posizione target: x=-0.081, y=-0.038 Azione: [-0.9177339  -0.99965215] | Reward: 1.000
# Posizione: x=-0.080, y=-0.042 | Posizione target: x=-0.082, y=-0.039 Azione: [-0.38955104 -1.5982269 ] | Reward: 1.000
# Posizione: x=-0.082, y=-0.043 | Posizione target: x=-0.083, y=-0.041 Azione: [-2.1628504 -1.3377184] | Reward: 1.000
# Posizione: x=-0.082, y=-0.044 | Posizione target: x=-0.084, y=-0.042 Azione: [-0.29388803 -1.3667744 ] | Reward: 1.000
# Posizione: x=-0.083, y=-0.045 | Posizione target: x=-0.085, y=-0.044 Azione: [-1.5038997 -1.6256442] | Reward: 1.000
# Posizione: x=-0.084, y=-0.047 | Posizione target: x=-0.086, y=-0.045 Azione: [-0.85405105 -1.5648192 ] | Reward: 1.000
# Posizione: x=-0.085, y=-0.048 | Posizione target: x=-0.087, y=-0.046 Azione: [-1.3797458 -1.7416148] | Reward: 1.000
# Posizione: x=-0.085, y=-0.049 | Posizione target: x=-0.088, y=-0.047 Azione: [-0.16444284 -1.7220465 ] | Reward: 1.000
# Posizione: x=-0.086, y=-0.050 | Posizione target: x=-0.089, y=-0.048 Azione: [-1.4398053 -1.6600105] | Reward: 1.000
# Posizione: x=-0.087, y=-0.052 | Posizione target: x=-0.090, y=-0.050 Azione: [-1.3573439 -1.5560491] | Reward: 1.000
# Posizione: x=-0.087, y=-0.053 | Posizione target: x=-0.090, y=-0.051 Azione: [-0.21073177 -1.4911602 ] | Reward: 1.000
# Posizione: x=-0.089, y=-0.055 | Posizione target: x=-0.091, y=-0.053 Azione: [-2.124681  -1.5800968] | Reward: 1.000
# Posizione: x=-0.089, y=-0.056 | Posizione target: x=-0.092, y=-0.054 Azione: [ 0.19952792 -1.1025422 ] | Reward: 1.000
# Posizione: x=-0.091, y=-0.057 | Posizione target: x=-0.093, y=-0.056 Azione: [-1.7484806 -1.7043234] | Reward: 1.000
# Posizione: x=-0.091, y=-0.058 | Posizione target: x=-0.094, y=-0.057 Azione: [ 0.24220847 -1.1933722 ] | Reward: 1.000
# Posizione: x=-0.091, y=-0.060 | Posizione target: x=-0.095, y=-0.059 Azione: [-0.5336072 -1.7996758] | Reward: 1.000
# Posizione: x=-0.092, y=-0.061 | Posizione target: x=-0.096, y=-0.060 Azione: [-1.0100982 -1.3184092] | Reward: 1.000
# Posizione: x=-0.092, y=-0.063 | Posizione target: x=-0.096, y=-0.062 Azione: [-0.30319363 -1.9107747 ] | Reward: 1.000
# Posizione: x=-0.094, y=-0.064 | Posizione target: x=-0.097, y=-0.063 Azione: [-1.3035125 -1.6762507] | Reward: 1.000
# Posizione: x=-0.095, y=-0.066 | Posizione target: x=-0.098, y=-0.065 Azione: [-1.6167878 -1.8739406] | Reward: 1.000
# Posizione: x=-0.095, y=-0.067 | Posizione target: x=-0.098, y=-0.067 Azione: [-0.08623801 -1.5954676 ] | Reward: 1.000
# Posizione: x=-0.096, y=-0.068 | Posizione target: x=-0.099, y=-0.068 Azione: [-0.6257498 -1.5534506] | Reward: 1.000
# Posizione: x=-0.096, y=-0.070 | Posizione target: x=-0.100, y=-0.070 Azione: [-0.69198024 -1.8306164 ] | Reward: 1.000
# Posizione: x=-0.097, y=-0.072 | Posizione target: x=-0.101, y=-0.072 Azione: [-0.89339745 -1.8124717 ] | Reward: 1.000
# Posizione: x=-0.097, y=-0.074 | Posizione target: x=-0.101, y=-0.074 Azione: [ 0.18157473 -1.7828386 ] | Reward: 1.000
# Posizione: x=-0.099, y=-0.075 | Posizione target: x=-0.102, y=-0.075 Azione: [-1.7561463 -1.655469 ] | Reward: 1.000
# Posizione: x=-0.098, y=-0.077 | Posizione target: x=-0.102, y=-0.076 Azione: [ 0.16074821 -1.7426904 ] | Reward: 1.000
# Posizione: x=-0.099, y=-0.078 | Posizione target: x=-0.102, y=-0.078 Azione: [-0.6930045 -1.5964525] | Reward: 1.000
# Posizione: x=-0.099, y=-0.080 | Posizione target: x=-0.103, y=-0.079 Azione: [-0.15067287 -1.8569394 ] | Reward: 1.000
# Posizione: x=-0.100, y=-0.082 | Posizione target: x=-0.103, y=-0.081 Azione: [-0.38891932 -1.6962364 ] | Reward: 1.000
# Posizione: x=-0.100, y=-0.083 | Posizione target: x=-0.104, y=-0.082 Azione: [-0.16816598 -1.739281  ] | Reward: 1.000
# Posizione: x=-0.100, y=-0.084 | Posizione target: x=-0.104, y=-0.084 Azione: [ 0.19351792 -1.7849832 ] | Reward: 1.000
# Posizione: x=-0.100, y=-0.086 | Posizione target: x=-0.104, y=-0.086 Azione: [-0.48558962 -1.7879944 ] | Reward: 1.000
# Posizione: x=-0.100, y=-0.087 | Posizione target: x=-0.105, y=-0.088 Azione: [ 0.15586272 -1.7111742 ] | Reward: 1.000
# Posizione: x=-0.101, y=-0.088 | Posizione target: x=-0.105, y=-0.089 Azione: [-0.8824465 -1.6922011] | Reward: 1.000
# Posizione: x=-0.101, y=-0.090 | Posizione target: x=-0.106, y=-0.091 Azione: [-0.26990178 -1.8850642 ] | Reward: 1.000
# Posizione: x=-0.102, y=-0.092 | Posizione target: x=-0.106, y=-0.093 Azione: [-1.1882511 -1.8162782] | Reward: 1.000
# Posizione: x=-0.102, y=-0.094 | Posizione target: x=-0.106, y=-0.094 Azione: [ 0.25254503 -2.0911143 ] | Reward: 1.000
# Posizione: x=-0.103, y=-0.095 | Posizione target: x=-0.106, y=-0.096 Azione: [-0.96269697 -1.7946805 ] | Reward: 1.000
# Posizione: x=-0.103, y=-0.097 | Posizione target: x=-0.106, y=-0.098 Azione: [-0.12758598 -1.9345782 ] | Reward: 1.000
# Posizione: x=-0.103, y=-0.098 | Posizione target: x=-0.107, y=-0.100 Azione: [-0.35158706 -1.9276192 ] | Reward: 1.000
# Posizione: x=-0.101, y=-0.100 | Posizione target: x=-0.107, y=-0.101 Azione: [ 1.5944492 -1.6813637] | Reward: 1.000
# Posizione: x=-0.103, y=-0.101 | Posizione target: x=-0.107, y=-0.103 Azione: [-1.999063  -1.6509122] | Reward: 1.000
# Posizione: x=-0.102, y=-0.103 | Posizione target: x=-0.107, y=-0.105 Azione: [ 1.0372198 -1.9637318] | Reward: 1.000
# Posizione: x=-0.103, y=-0.104 | Posizione target: x=-0.107, y=-0.106 Azione: [-0.52268726 -1.6457992 ] | Reward: 1.000
# Posizione: x=-0.103, y=-0.107 | Posizione target: x=-0.107, y=-0.107 Azione: [-0.16008839 -2.1609023 ] | Reward: 1.000
# Posizione: x=-0.103, y=-0.108 | Posizione target: x=-0.107, y=-0.109 Azione: [-0.42516568 -1.8370754 ] | Reward: 1.000
# Posizione: x=-0.102, y=-0.110 | Posizione target: x=-0.107, y=-0.111 Azione: [ 1.3736079 -1.8893049] | Reward: 1.000
# Posizione: x=-0.103, y=-0.111 | Posizione target: x=-0.107, y=-0.112 Azione: [-0.79304594 -1.5957954 ] | Reward: 1.000
# Posizione: x=-0.102, y=-0.113 | Posizione target: x=-0.107, y=-0.114 Azione: [ 1.1030816 -2.1005902] | Reward: 1.000
# Posizione: x=-0.102, y=-0.115 | Posizione target: x=-0.107, y=-0.116 Azione: [-0.43455318 -1.6083825 ] | Reward: 1.000
# Posizione: x=-0.101, y=-0.117 | Posizione target: x=-0.106, y=-0.118 Azione: [ 0.8728204 -1.86976  ] | Reward: 1.000
# Posizione: x=-0.102, y=-0.118 | Posizione target: x=-0.106, y=-0.119 Azione: [-0.64710456 -2.0047827 ] | Reward: 1.000
# Posizione: x=-0.101, y=-0.120 | Posizione target: x=-0.106, y=-0.121 Azione: [ 1.2589873 -1.9158193] | Reward: 1.000
# Posizione: x=-0.102, y=-0.121 | Posizione target: x=-0.106, y=-0.123 Azione: [-1.070859  -1.4593766] | Reward: 1.000
# Posizione: x=-0.100, y=-0.123 | Posizione target: x=-0.106, y=-0.124 Azione: [ 1.7740265 -1.6210399] | Reward: 1.000
# Posizione: x=-0.101, y=-0.124 | Posizione target: x=-0.105, y=-0.126 Azione: [-1.2833731 -1.5840827] | Reward: 1.000
# Posizione: x=-0.101, y=-0.125 | Posizione target: x=-0.105, y=-0.128 Azione: [ 0.1875729 -1.5985918] | Reward: 1.000
# Posizione: x=-0.101, y=-0.127 | Posizione target: x=-0.105, y=-0.129 Azione: [-0.05218062 -2.2589657 ] | Reward: 1.000
# Posizione: x=-0.101, y=-0.129 | Posizione target: x=-0.104, y=-0.131 Azione: [ 0.1243711 -2.0543947] | Reward: 1.000
# Posizione: x=-0.101, y=-0.131 | Posizione target: x=-0.104, y=-0.133 Azione: [-0.2708844 -2.0247338] | Reward: 1.000
# Posizione: x=-0.101, y=-0.132 | Posizione target: x=-0.104, y=-0.134 Azione: [ 0.600013  -2.0416648] | Reward: 1.000
# Posizione: x=-0.100, y=-0.133 | Posizione target: x=-0.103, y=-0.136 Azione: [ 0.9905937 -2.0076673] | Reward: 1.000
# Posizione: x=-0.100, y=-0.135 | Posizione target: x=-0.103, y=-0.138 Azione: [-0.1840825 -2.045748 ] | Reward: 1.000
# Posizione: x=-0.100, y=-0.137 | Posizione target: x=-0.102, y=-0.139 Azione: [ 0.47109222 -1.768479  ] | Reward: 1.000
# Posizione: x=-0.099, y=-0.138 | Posizione target: x=-0.102, y=-0.141 Azione: [ 0.65359926 -1.678072  ] | Reward: 1.000
# Posizione: x=-0.099, y=-0.139 | Posizione target: x=-0.101, y=-0.142 Azione: [-0.02715044 -1.8170235 ] | Reward: 1.000
# Posizione: x=-0.099, y=-0.142 | Posizione target: x=-0.101, y=-0.144 Azione: [ 0.24490032 -2.255255  ] | Reward: 1.000
# Posizione: x=-0.099, y=-0.143 | Posizione target: x=-0.100, y=-0.145 Azione: [-0.01824622 -1.6313196 ] | Reward: 1.000
# Posizione: x=-0.097, y=-0.145 | Posizione target: x=-0.100, y=-0.147 Azione: [ 1.7386426 -2.191551 ] | Reward: 1.000
# Posizione: x=-0.097, y=-0.147 | Posizione target: x=-0.099, y=-0.148 Azione: [ 0.06447995 -1.4865745 ] | Reward: 1.000
# Posizione: x=-0.095, y=-0.148 | Posizione target: x=-0.099, y=-0.150 Azione: [ 2.0321636 -2.0512588] | Reward: 1.000
# Posizione: x=-0.096, y=-0.150 | Posizione target: x=-0.098, y=-0.151 Azione: [-0.6644942 -1.4846178] | Reward: 1.000
# Posizione: x=-0.096, y=-0.152 | Posizione target: x=-0.097, y=-0.153 Azione: [ 0.23554665 -2.1405    ] | Reward: 1.000
# Posizione: x=-0.095, y=-0.153 | Posizione target: x=-0.096, y=-0.155 Azione: [ 0.56353873 -1.752268  ] | Reward: 1.000
# Posizione: x=-0.095, y=-0.154 | Posizione target: x=-0.095, y=-0.156 Azione: [ 0.43825597 -1.9032888 ] | Reward: 1.000
# Posizione: x=-0.094, y=-0.156 | Posizione target: x=-0.095, y=-0.158 Azione: [ 0.9565376 -1.8797779] | Reward: 1.000
# Posizione: x=-0.094, y=-0.157 | Posizione target: x=-0.094, y=-0.160 Azione: [ 0.06900657 -1.609529  ] | Reward: 1.000
# Posizione: x=-0.093, y=-0.159 | Posizione target: x=-0.093, y=-0.161 Azione: [ 0.80358684 -2.0028186 ] | Reward: 1.000
# Posizione: x=-0.093, y=-0.161 | Posizione target: x=-0.092, y=-0.163 Azione: [ 0.32593247 -1.6928871 ] | Reward: 1.000
# Posizione: x=-0.091, y=-0.163 | Posizione target: x=-0.091, y=-0.164 Azione: [ 1.6314744 -1.8576124] | Reward: 1.000
# Posizione: x=-0.093, y=-0.164 | Posizione target: x=-0.090, y=-0.166 Azione: [-1.4570355 -1.5153264] | Reward: 1.000
# Posizione: x=-0.091, y=-0.165 | Posizione target: x=-0.089, y=-0.167 Azione: [ 1.9085581 -1.9417756] | Reward: 1.000
# Posizione: x=-0.091, y=-0.167 | Posizione target: x=-0.088, y=-0.169 Azione: [-0.12377882 -1.6213466 ] | Reward: 1.000
# Posizione: x=-0.091, y=-0.169 | Posizione target: x=-0.087, y=-0.170 Azione: [-0.6412233 -1.9590445] | Reward: 1.000
# Posizione: x=-0.091, y=-0.170 | Posizione target: x=-0.086, y=-0.172 Azione: [ 0.8404292 -1.7728993] | Reward: 1.000
# Posizione: x=-0.090, y=-0.172 | Posizione target: x=-0.085, y=-0.173 Azione: [ 0.4083125 -1.792495 ] | Reward: 1.000
# Posizione: x=-0.090, y=-0.173 | Posizione target: x=-0.084, y=-0.174 Azione: [ 0.7913941 -1.5065949] | Reward: 1.000
