# %%
import mujoco
import glfw
import numpy as np
import time
from PIL import Image

XML_FILE_PATH = "/Users/edoardozappia/Desktop/Tesi_Magistrale/irregular_shape_2D.xml"

def save_image_to_array(rgb_buffer, width, height, target_size):
    """
    Salva un'immagine dalla simulazione in un array ridimensionato alla dimensione target_size.
    """
    # Converti il buffer in un'immagine
    img = np.frombuffer(rgb_buffer, dtype=np.uint8).reshape(height, width, 3)
    img = Image.fromarray(img)

    # Ridimensiona l'immagine
    img_resized = img.resize(target_size, Image.LANCZOS)

    # Converti l'immagine ridimensionata in un array numpy
    return np.array(img_resized)

def main():

    dt = 0.01
    side_length = 0.6  # Lunghezza del lato del quadrato
    half_side = side_length / 2  # Metà lato (limiti del quadrato)
    alpha_x = 1
    alpha_y = 1
    beta_x = 1
    beta_y = 1
    std_x = 0.0    #std for gaussian noise on direction change and velocity. If 0.0 velocity is opposite
    std_y = 0.0    #std for gaussian noise on direction change and velocity. If 0.0 velocity is opposite

    if not glfw.init():
        print("Impossibile inizializzare GLFW")
        return

    glfw.window_hint(glfw.VISIBLE, glfw.TRUE)
    window = glfw.create_window(800, 800, "MuJoCo Viewer", None, None)
    if not window:
        print("Errore durante la creazione della finestra GLFW")
        glfw.terminate()
        return

    glfw.make_context_current(window)

    model = mujoco.MjModel.from_xml_path(XML_FILE_PATH)
    data = mujoco.MjData(model)

    # Configura la telecamera
    camera = mujoco.MjvCamera()
    camera.type = mujoco.mjtCamera.mjCAMERA_FREE
    camera.lookat = np.array([0, 0, 0])
    camera.distance = 2.0
    camera.azimuth = 90
    camera.elevation = -90

    # Renderer per visualizzare la finestra
    scene = mujoco.MjvScene(model, maxgeom=1000)
    context = mujoco.MjrContext(model, mujoco.mjtFontScale.mjFONTSCALE_150)

    t = 0  # Tempo iniziale
    frame_count = 0

    # Ottieni dimensioni del viewport
    viewport_width, viewport_height = glfw.get_framebuffer_size(window)

    # Prealloca buffer per RGB e profondità
    rgb_buffer = np.zeros((viewport_height, viewport_width, 3), dtype=np.uint8)
    depth_buffer = np.zeros((viewport_height, viewport_width), dtype=np.float32)

    frames = []

    while not glfw.window_should_close(window):

        t += dt

        # Posizione attuale
        x = data.qpos[0]
        y = data.qpos[1]

        # Rileva collisioni con i lati del quadrato
        if x >= half_side or x <= -half_side:
            alpha_x *= np.random.normal(-1, std_x)  # Inverti velocità lungo x
            print(f"Rimbalzo su lato verticale: x={x:.3f}, v_x={data.qvel[0]:.3f}")

        if y >= half_side or y <= -half_side:
            alpha_y *= np.random.normal(-1, std_y)  # Inverti velocità lungo y
            print(f"Rimbalzo su lato orizzontale: y={y:.3f}, v_y={data.qvel[1]:.3f}")

        # Calcola forze basate sulle velocità
        force_x = alpha_x * 1000 * beta_x * np.random.normal(1, 0.5)
        force_y = alpha_y * 1000 * beta_y * np.random.normal(1, 0.5)

        # Applica forze
        data.qfrc_applied[0] = force_x
        data.qfrc_applied[1] = force_y

        # Avanza la simulazione
        mujoco.mj_step(model, data)

        # Debug
        print(f"Posizione: x={x:.3f}, y={y:.3f}")
        print(f"Velocità: x_vel={data.qvel[0]:.3f}, y_vel={data.qvel[1]:.3f}")
        print(f"Forze: force_x={force_x:.3f}, force_y={force_y:.3f}")

        # Renderizza la scena
        mujoco.mjv_updateScene(model, data, mujoco.MjvOption(), None, camera, mujoco.mjtCatBit.mjCAT_ALL, scene)
        viewport = mujoco.MjrRect(0, 0, viewport_width, viewport_height)
        mujoco.mjr_render(viewport, scene, context)

        # Salva il frame corrente come array
        frame_array = save_image_to_array(rgb_buffer.tobytes(), viewport_width, viewport_height, target_size=(64, 64))
        frames.append(frame_array)

        frame_count += 1

        glfw.swap_buffers(window)
        glfw.poll_events()
        time.sleep(dt)

    glfw.destroy_window(window)
    glfw.terminate()

    # Converti la lista di frame in un array numpy
    frames = np.stack(frames)
    print("Frames salvati per l'autoencoder:", frames.shape)

if __name__ == "__main__":
    main()
# Out:
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.171, y_vel=0.148
# Forze: force_x=901.610, force_y=782.371
# Posizione: x=0.002, y=0.001
# Velocità: x_vel=0.322, y_vel=0.239
# Forze: force_x=1716.770, force_y=1276.022
# Posizione: x=0.005, y=0.004
# Velocità: x_vel=0.081, y_vel=0.087
# Forze: force_x=454.847, force_y=481.145
# Posizione: x=0.006, y=0.005
# Velocità: x_vel=0.083, y_vel=0.185
# Forze: force_x=446.961, force_y=985.389
# Posizione: x=0.007, y=0.007
# Velocità: x_vel=0.370, y_vel=0.272
# Forze: force_x=1959.968, force_y=1450.868
# Posizione: x=0.010, y=0.009
# Velocità: x_vel=0.157, y_vel=0.078
# Forze: force_x=860.714, force_y=435.525
# Posizione: x=0.012, y=0.010
# Velocità: x_vel=0.208, y_vel=0.094
# Forze: force_x=1113.796, force_y=502.066
# Posizione: x=0.014, y=0.011
# Velocità: x_vel=0.111, y_vel=0.189
# Forze: force_x=605.240, force_y=1004.905
# Posizione: x=0.015, y=0.013
# Velocità: x_vel=0.209, y_vel=0.151
# Forze: force_x=1488.475, force_y=1069.390
# Posizione: x=0.017, y=0.014
# Velocità: x_vel=0.062, y_vel=0.131
# Forze: force_x=475.120, force_y=928.066
# Posizione: x=0.018, y=0.016
# Velocità: x_vel=0.297, y_vel=0.276
# Forze: force_x=1573.512, force_y=1465.836
# Posizione: x=0.021, y=0.018
# Velocità: x_vel=0.218, y_vel=0.265
# Forze: force_x=1178.954, force_y=1422.978
# Posizione: x=0.023, y=0.021
# Velocità: x_vel=0.226, y_vel=0.112
# Forze: force_x=1210.019, force_y=615.493
# Posizione: x=0.025, y=0.022
# Velocità: x_vel=0.332, y_vel=0.210
# Forze: force_x=1774.866, force_y=1117.901
# Posizione: x=0.028, y=0.024
# Velocità: x_vel=0.109, y_vel=0.260
# Forze: force_x=822.742, force_y=1824.116
# Posizione: x=0.030, y=0.027
# Velocità: x_vel=0.117, y_vel=0.005
# Forze: force_x=842.681, force_y=80.888
# Posizione: x=0.031, y=0.027
# Velocità: x_vel=0.233, y_vel=0.017
# Forze: force_x=1238.269, force_y=89.275
# Posizione: x=0.033, y=0.027
# Velocità: x_vel=0.061, y_vel=0.077
# Forze: force_x=342.482, force_y=405.393
# Posizione: x=0.034, y=0.028
# Velocità: x_vel=-0.020, y_vel=0.314
# Forze: force_x=-101.505, force_y=1662.100
# Posizione: x=0.033, y=0.031
# Velocità: x_vel=0.199, y_vel=0.183
# Forze: force_x=1049.764, force_y=995.495
# Posizione: x=0.035, y=0.033
# Velocità: x_vel=0.158, y_vel=0.221
# Forze: force_x=853.837, force_y=1182.423
# Posizione: x=0.037, y=0.035
# Velocità: x_vel=0.286, y_vel=0.174
# Forze: force_x=2037.258, force_y=1229.551
# Posizione: x=0.040, y=0.037
# Velocità: x_vel=0.175, y_vel=0.145
# Forze: force_x=948.453, force_y=782.887
# Posizione: x=0.042, y=0.038
# Velocità: x_vel=0.083, y_vel=0.147
# Forze: force_x=451.903, force_y=786.756
# Posizione: x=0.042, y=0.040
# Velocità: x_vel=0.084, y_vel=0.118
# Forze: force_x=708.286, force_y=988.148
# Posizione: x=0.043, y=0.041
# Velocità: x_vel=0.334, y_vel=0.276
# Forze: force_x=2354.072, force_y=1916.216
# Posizione: x=0.047, y=0.044
# Velocità: x_vel=0.184, y_vel=-0.032
# Forze: force_x=1000.414, force_y=-143.244
# Posizione: x=0.049, y=0.043
# Velocità: x_vel=0.264, y_vel=0.169
# Forze: force_x=1412.357, force_y=886.910
# Posizione: x=0.051, y=0.045
# Velocità: x_vel=0.169, y_vel=-0.009
# Forze: force_x=1231.242, force_y=-38.355
# Posizione: x=0.053, y=0.045
# Velocità: x_vel=0.255, y_vel=0.106
# Forze: force_x=1817.478, force_y=721.185
# Posizione: x=0.055, y=0.046
# Velocità: x_vel=0.418, y_vel=0.131
# Forze: force_x=2227.698, force_y=702.361
# Posizione: x=0.060, y=0.047
# Velocità: x_vel=0.056, y_vel=0.078
# Forze: force_x=558.747, force_y=663.379
# Posizione: x=0.060, y=0.048
# Velocità: x_vel=0.115, y_vel=0.095
# Forze: force_x=813.681, force_y=667.753
# Posizione: x=0.061, y=0.049
# Velocità: x_vel=0.184, y_vel=0.075
# Forze: force_x=1309.902, force_y=529.267
# Posizione: x=0.063, y=0.050
# Velocità: x_vel=0.078, y_vel=0.196
# Forze: force_x=579.523, force_y=1357.204
# Posizione: x=0.064, y=0.052
# Velocità: x_vel=0.127, y_vel=0.157
# Forze: force_x=899.498, force_y=1114.711
# Posizione: x=0.065, y=0.053
# Velocità: x_vel=0.160, y_vel=0.121
# Forze: force_x=1140.927, force_y=859.282
# Posizione: x=0.067, y=0.055
# Velocità: x_vel=0.058, y_vel=0.278
# Forze: force_x=429.461, force_y=1933.746
# Posizione: x=0.067, y=0.057
# Velocità: x_vel=0.155, y_vel=0.190
# Forze: force_x=1095.687, force_y=1353.736
# Posizione: x=0.069, y=0.059
# Velocità: x_vel=0.181, y_vel=0.200
# Forze: force_x=970.492, force_y=1072.875
# Posizione: x=0.071, y=0.061
# Velocità: x_vel=0.106, y_vel=0.136
# Forze: force_x=577.782, force_y=736.162
# Posizione: x=0.072, y=0.063
# Velocità: x_vel=0.248, y_vel=0.156
# Forze: force_x=1319.575, force_y=834.334
# Posizione: x=0.074, y=0.064
# Velocità: x_vel=0.221, y_vel=0.320
# Forze: force_x=1188.599, force_y=1702.907
# Posizione: x=0.076, y=0.067
# Velocità: x_vel=0.290, y_vel=0.282
# Forze: force_x=1548.887, force_y=1515.958
# Posizione: x=0.079, y=0.070
# Velocità: x_vel=0.048, y_vel=0.149
# Forze: force_x=277.749, force_y=811.343
# Posizione: x=0.080, y=0.072
# Velocità: x_vel=0.109, y_vel=0.124
# Forze: force_x=577.790, force_y=666.047
# Posizione: x=0.081, y=0.073
# Velocità: x_vel=0.193, y_vel=0.151
# Forze: force_x=1030.344, force_y=806.105
# Posizione: x=0.083, y=0.074
# Velocità: x_vel=0.180, y_vel=0.103
# Forze: force_x=969.824, force_y=557.260
# Posizione: x=0.085, y=0.075
# Velocità: x_vel=0.130, y_vel=0.119
# Forze: force_x=702.994, force_y=636.106
# Posizione: x=0.086, y=0.077
# Velocità: x_vel=0.333, y_vel=0.297
# Forze: force_x=1768.081, force_y=1575.910
# Posizione: x=0.089, y=0.080
# Velocità: x_vel=0.206, y_vel=0.158
# Forze: force_x=1497.770, force_y=1130.671
# Posizione: x=0.091, y=0.081
# Velocità: x_vel=0.178, y_vel=0.268
# Forze: force_x=960.416, force_y=1429.628
# Posizione: x=0.093, y=0.084
# Velocità: x_vel=0.230, y_vel=0.137
# Forze: force_x=1229.190, force_y=745.530
# Posizione: x=0.095, y=0.085
# Velocità: x_vel=0.272, y_vel=0.145
# Forze: force_x=1458.625, force_y=776.108
# Posizione: x=0.098, y=0.087
# Velocità: x_vel=0.165, y_vel=0.176
# Forze: force_x=1417.780, force_y=1454.315
# Posizione: x=0.100, y=0.088
# Velocità: x_vel=0.111, y_vel=0.108
# Forze: force_x=601.597, force_y=583.542
# Posizione: x=0.101, y=0.090
# Velocità: x_vel=0.106, y_vel=0.143
# Forze: force_x=571.443, force_y=765.096
# Posizione: x=0.102, y=0.091
# Velocità: x_vel=0.318, y_vel=0.136
# Forze: force_x=1688.654, force_y=732.784
# Posizione: x=0.105, y=0.092
# Velocità: x_vel=0.175, y_vel=0.266
# Forze: force_x=952.289, force_y=1418.845
# Posizione: x=0.107, y=0.095
# Velocità: x_vel=0.284, y_vel=0.146
# Forze: force_x=1512.925, force_y=795.065
# Posizione: x=0.110, y=0.096
# Velocità: x_vel=0.191, y_vel=0.227
# Forze: force_x=1033.245, force_y=1213.038
# Posizione: x=0.112, y=0.099
# Velocità: x_vel=0.227, y_vel=0.296
# Forze: force_x=1214.624, force_y=1585.351
# Posizione: x=0.114, y=0.102
# Velocità: x_vel=0.196, y_vel=0.276
# Forze: force_x=1054.517, force_y=1482.615
# Posizione: x=0.116, y=0.104
# Velocità: x_vel=0.264, y_vel=0.156
# Forze: force_x=1409.736, force_y=847.398
# Posizione: x=0.119, y=0.106
# Velocità: x_vel=0.092, y_vel=0.193
# Forze: force_x=682.625, force_y=1354.426
# Posizione: x=0.119, y=0.108
# Velocità: x_vel=0.274, y_vel=0.110
# Forze: force_x=1455.341, force_y=597.328
# Posizione: x=0.122, y=0.109
# Velocità: x_vel=0.181, y_vel=0.170
# Forze: force_x=981.752, force_y=909.172
# Posizione: x=0.124, y=0.111
# Velocità: x_vel=0.262, y_vel=0.145
# Forze: force_x=1864.903, force_y=1015.587
# Posizione: x=0.127, y=0.112
# Velocità: x_vel=0.154, y_vel=0.050
# Forze: force_x=837.969, force_y=275.945
# Posizione: x=0.128, y=0.113
# Velocità: x_vel=0.248, y_vel=0.137
# Forze: force_x=1320.482, force_y=727.261
# Posizione: x=0.131, y=0.114
# Velocità: x_vel=0.065, y_vel=0.171
# Forze: force_x=493.492, force_y=1195.453
# Posizione: x=0.131, y=0.116
# Velocità: x_vel=0.215, y_vel=0.112
# Forze: force_x=1141.902, force_y=604.888
# Posizione: x=0.133, y=0.117
# Velocità: x_vel=0.195, y_vel=0.281
# Forze: force_x=1388.296, force_y=1947.962
# Posizione: x=0.135, y=0.120
# Velocità: x_vel=0.133, y_vel=0.177
# Forze: force_x=720.603, force_y=958.530
# Posizione: x=0.137, y=0.121
# Velocità: x_vel=0.045, y_vel=0.266
# Forze: force_x=327.316, force_y=1860.696
# Posizione: x=0.137, y=0.124
# Velocità: x_vel=0.339, y_vel=0.275
# Forze: force_x=1792.029, force_y=1475.599
# Posizione: x=0.141, y=0.127
# Velocità: x_vel=0.179, y_vel=0.141
# Forze: force_x=977.289, force_y=766.801
# Posizione: x=0.142, y=0.128
# Velocità: x_vel=0.116, y_vel=0.353
# Forze: force_x=980.807, force_y=2885.402
# Posizione: x=0.143, y=0.132
# Velocità: x_vel=0.207, y_vel=0.302
# Forze: force_x=1453.553, force_y=2131.097
# Posizione: x=0.146, y=0.135
# Velocità: x_vel=0.054, y_vel=0.285
# Forze: force_x=304.864, force_y=1530.178
# Posizione: x=0.146, y=0.138
# Velocità: x_vel=0.087, y_vel=0.161
# Forze: force_x=464.697, force_y=876.408
# Posizione: x=0.147, y=0.139
# Velocità: x_vel=0.093, y_vel=0.180
# Forze: force_x=653.272, force_y=1261.871
# Posizione: x=0.148, y=0.141
# Velocità: x_vel=0.143, y_vel=0.107
# Forze: force_x=1011.431, force_y=762.097
# Posizione: x=0.149, y=0.142
# Velocità: x_vel=0.130, y_vel=0.146
# Forze: force_x=924.924, force_y=1019.356
# Posizione: x=0.151, y=0.144
# Velocità: x_vel=0.172, y_vel=0.147
# Forze: force_x=1219.351, force_y=1029.066
# Posizione: x=0.152, y=0.145
# Velocità: x_vel=0.246, y_vel=0.192
# Forze: force_x=1313.304, force_y=1027.251
# Posizione: x=0.155, y=0.147
# Velocità: x_vel=0.202, y_vel=0.271
# Forze: force_x=1086.393, force_y=1449.334
# Posizione: x=0.157, y=0.150
# Velocità: x_vel=-0.013, y_vel=0.178
# Forze: force_x=-66.094, force_y=1276.134
# Posizione: x=0.157, y=0.152
# Velocità: x_vel=0.100, y_vel=0.088
# Forze: force_x=815.487, force_y=753.422
# Posizione: x=0.158, y=0.152
# Velocità: x_vel=0.039, y_vel=0.036
# Forze: force_x=216.510, force_y=200.555
# Posizione: x=0.158, y=0.153
# Velocità: x_vel=0.057, y_vel=0.053
# Forze: force_x=306.717, force_y=281.598
# Posizione: x=0.159, y=0.153
# Velocità: x_vel=0.243, y_vel=0.172
# Forze: force_x=1286.222, force_y=913.475
# Posizione: x=0.161, y=0.155
# Velocità: x_vel=0.173, y_vel=0.095
# Forze: force_x=933.697, force_y=514.753
# Posizione: x=0.163, y=0.156
# Velocità: x_vel=0.260, y_vel=0.213
# Forze: force_x=1385.707, force_y=1130.874
# Posizione: x=0.165, y=0.158
# Velocità: x_vel=0.199, y_vel=0.141
# Forze: force_x=1426.309, force_y=1000.951
# Posizione: x=0.167, y=0.159
# Velocità: x_vel=0.182, y_vel=0.357
# Forze: force_x=979.207, force_y=1895.380
# Posizione: x=0.169, y=0.163
# Velocità: x_vel=0.081, y_vel=0.071
# Forze: force_x=442.975, force_y=407.397
# Posizione: x=0.170, y=0.164
# Velocità: x_vel=0.146, y_vel=0.239
# Forze: force_x=779.471, force_y=1269.446
# Posizione: x=0.172, y=0.166
# Velocità: x_vel=0.135, y_vel=0.222
# Forze: force_x=725.307, force_y=1192.095
# Posizione: x=0.173, y=0.168
# Velocità: x_vel=0.136, y_vel=0.126
# Forze: force_x=968.008, force_y=900.883
# Posizione: x=0.174, y=0.170
# Velocità: x_vel=0.237, y_vel=0.296
# Forze: force_x=1263.557, force_y=1574.357
# Posizione: x=0.177, y=0.173
# Velocità: x_vel=-0.065, y_vel=0.097
# Forze: force_x=-415.386, force_y=726.632
# Posizione: x=0.176, y=0.174
# Velocità: x_vel=0.203, y_vel=0.054
# Forze: force_x=1065.277, force_y=294.994
# Posizione: x=0.178, y=0.174
# Velocità: x_vel=0.178, y_vel=0.067
# Forze: force_x=959.079, force_y=360.174
# Posizione: x=0.180, y=0.175
# Velocità: x_vel=0.024, y_vel=0.366
# Forze: force_x=141.615, force_y=1940.498
# Posizione: x=0.180, y=0.178
# Velocità: x_vel=0.063, y_vel=0.155
# Forze: force_x=332.809, force_y=852.770
# Posizione: x=0.181, y=0.180
# Velocità: x_vel=0.403, y_vel=0.188
# Forze: force_x=2135.185, force_y=1007.189
# Posizione: x=0.185, y=0.182
# Velocità: x_vel=0.193, y_vel=0.147
# Forze: force_x=1052.446, force_y=792.980
# Posizione: x=0.187, y=0.183
# Velocità: x_vel=0.209, y_vel=0.197
# Forze: force_x=1121.373, force_y=1051.775
# Posizione: x=0.189, y=0.185
# Velocità: x_vel=-0.057, y_vel=0.350
# Forze: force_x=-281.238, force_y=1867.877
# Posizione: x=0.188, y=0.189
# Velocità: x_vel=0.069, y_vel=0.211
# Forze: force_x=357.758, force_y=1145.878
# Posizione: x=0.189, y=0.191
# Velocità: x_vel=0.175, y_vel=0.130
# Forze: force_x=930.490, force_y=703.926
# Posizione: x=0.191, y=0.192
# Velocità: x_vel=0.082, y_vel=0.205
# Forze: force_x=448.949, force_y=1096.272
# Posizione: x=0.191, y=0.194
# Velocità: x_vel=0.149, y_vel=0.275
# Forze: force_x=791.745, force_y=1470.131
# Posizione: x=0.193, y=0.197
# Velocità: x_vel=0.119, y_vel=0.162
# Forze: force_x=847.581, force_y=1161.534
# Posizione: x=0.194, y=0.199
# Velocità: x_vel=0.141, y_vel=0.095
# Forze: force_x=998.960, force_y=676.442
# Posizione: x=0.195, y=0.200
# Velocità: x_vel=0.132, y_vel=0.199
# Forze: force_x=710.204, force_y=1060.698
# Posizione: x=0.197, y=0.202
# Velocità: x_vel=0.200, y_vel=0.132
# Forze: force_x=1067.535, force_y=714.867
# Posizione: x=0.199, y=0.203
# Velocità: x_vel=0.291, y_vel=0.083
# Forze: force_x=1556.545, force_y=452.459
# Posizione: x=0.202, y=0.204
# Velocità: x_vel=0.182, y_vel=0.172
# Forze: force_x=987.778, force_y=913.756
# Posizione: x=0.204, y=0.205
# Velocità: x_vel=0.177, y_vel=0.268
# Forze: force_x=948.432, force_y=1429.972
# Posizione: x=0.205, y=0.208
# Velocità: x_vel=0.051, y_vel=0.062
# Forze: force_x=381.313, force_y=473.115
# Posizione: x=0.206, y=0.209
# Velocità: x_vel=0.215, y_vel=0.064
# Forze: force_x=1500.611, force_y=438.558
# Posizione: x=0.208, y=0.209
# Velocità: x_vel=0.027, y_vel=0.491
# Forze: force_x=163.422, force_y=2599.601
# Posizione: x=0.208, y=0.214
# Velocità: x_vel=0.232, y_vel=0.159
# Forze: force_x=1610.365, force_y=1172.654
# Posizione: x=0.211, y=0.216
# Velocità: x_vel=0.276, y_vel=0.261
# Forze: force_x=1479.647, force_y=1392.843
# Posizione: x=0.213, y=0.219
# Velocità: x_vel=0.250, y_vel=0.192
# Forze: force_x=1342.115, force_y=1038.940
# Posizione: x=0.216, y=0.220
# Velocità: x_vel=0.205, y_vel=0.248
# Forze: force_x=1102.777, force_y=1325.621
# Posizione: x=0.218, y=0.223
# Velocità: x_vel=0.155, y_vel=0.182
# Forze: force_x=1103.628, force_y=1296.530
# Posizione: x=0.219, y=0.225
# Velocità: x_vel=0.082, y_vel=0.133
# Forze: force_x=591.239, force_y=948.977
# Posizione: x=0.220, y=0.226
# Velocità: x_vel=0.200, y_vel=0.155
# Forze: force_x=1060.891, force_y=827.592
# Posizione: x=0.222, y=0.228
# Velocità: x_vel=0.316, y_vel=0.261
# Forze: force_x=1687.853, force_y=1392.297
# Posizione: x=0.225, y=0.230
# Velocità: x_vel=-0.074, y_vel=-0.001
# Forze: force_x=-362.202, force_y=17.069
# Posizione: x=0.225, y=0.230
# Velocità: x_vel=0.042, y_vel=0.143
# Forze: force_x=214.906, force_y=754.682
# Posizione: x=0.225, y=0.232
# Velocità: x_vel=0.080, y_vel=-0.016
# Forze: force_x=424.932, force_y=-69.189
# Posizione: x=0.226, y=0.232
# Velocità: x_vel=0.123, y_vel=0.068
# Forze: force_x=655.480, force_y=355.239
# Posizione: x=0.227, y=0.232
# Velocità: x_vel=0.075, y_vel=0.239
# Forze: force_x=529.370, force_y=1665.207
# Posizione: x=0.228, y=0.235
# Velocità: x_vel=0.164, y_vel=0.238
# Forze: force_x=1136.585, force_y=1679.495
# Posizione: x=0.229, y=0.237
# Velocità: x_vel=0.148, y_vel=0.292
# Forze: force_x=984.020, force_y=1928.959
# Posizione: x=0.231, y=0.240
# Velocità: x_vel=0.142, y_vel=0.130
# Forze: force_x=764.440, force_y=709.869
# Posizione: x=0.232, y=0.241
# Velocità: x_vel=0.124, y_vel=0.244
# Forze: force_x=666.497, force_y=1298.452
# Posizione: x=0.234, y=0.244
# Velocità: x_vel=0.299, y_vel=0.203
# Forze: force_x=1589.195, force_y=1091.290
# Posizione: x=0.237, y=0.246
# Velocità: x_vel=0.361, y_vel=0.192
# Forze: force_x=1931.503, force_y=1033.712
# Posizione: x=0.240, y=0.248
# Velocità: x_vel=0.356, y_vel=0.101
# Forze: force_x=1909.159, force_y=551.783
# Posizione: x=0.244, y=0.249
# Velocità: x_vel=0.248, y_vel=0.213
# Forze: force_x=1339.049, force_y=1135.244
# Posizione: x=0.246, y=0.251
# Velocità: x_vel=0.133, y_vel=0.148
# Forze: force_x=726.740, force_y=802.714
# Posizione: x=0.248, y=0.252
# Velocità: x_vel=0.196, y_vel=0.298
# Forze: force_x=1364.543, force_y=2079.465
# Posizione: x=0.250, y=0.255
# Velocità: x_vel=0.188, y_vel=0.288
# Forze: force_x=1007.849, force_y=1548.816
# Posizione: x=0.251, y=0.258
# Velocità: x_vel=0.122, y_vel=0.228
# Forze: force_x=862.307, force_y=1625.652
# Posizione: x=0.253, y=0.260
# Velocità: x_vel=0.267, y_vel=0.240
# Forze: force_x=1422.201, force_y=1289.577
# Posizione: x=0.255, y=0.263
# Velocità: x_vel=0.277, y_vel=0.195
# Forze: force_x=1955.673, force_y=1379.858
# Posizione: x=0.258, y=0.265
# Velocità: x_vel=0.077, y_vel=0.151
# Forze: force_x=571.401, force_y=1080.320
# Posizione: x=0.259, y=0.266
# Velocità: x_vel=0.169, y_vel=0.338
# Forze: force_x=896.167, force_y=1800.004
# Posizione: x=0.261, y=0.270
# Velocità: x_vel=0.227, y_vel=0.111
# Forze: force_x=1216.174, force_y=613.587
# Posizione: x=0.263, y=0.271
# Velocità: x_vel=0.158, y_vel=0.442
# Forze: force_x=853.588, force_y=2342.390
# Posizione: x=0.264, y=0.275
# Velocità: x_vel=0.078, y_vel=0.360
# Forze: force_x=426.212, force_y=1941.405
# Posizione: x=0.265, y=0.279
# Velocità: x_vel=0.157, y_vel=0.218
# Forze: force_x=838.439, force_y=1182.767
# Posizione: x=0.267, y=0.281
# Velocità: x_vel=0.356, y_vel=0.173
# Forze: force_x=1891.989, force_y=932.159
# Posizione: x=0.270, y=0.283
# Velocità: x_vel=0.193, y_vel=0.185
# Forze: force_x=1051.582, force_y=993.621
# Posizione: x=0.272, y=0.284
# Velocità: x_vel=0.150, y_vel=0.163
# Forze: force_x=808.626, force_y=878.214
# Posizione: x=0.274, y=0.286
# Velocità: x_vel=0.142, y_vel=0.233
# Forze: force_x=763.087, force_y=1246.150
# Posizione: x=0.275, y=0.288
# Velocità: x_vel=0.147, y_vel=0.180
# Forze: force_x=1217.017, force_y=1513.282
# Posizione: x=0.277, y=0.290
# Velocità: x_vel=0.148, y_vel=0.139
# Forze: force_x=1038.362, force_y=989.844
# Posizione: x=0.278, y=0.292
# Velocità: x_vel=0.154, y_vel=0.254
# Forze: force_x=824.260, force_y=1355.298
# Posizione: x=0.280, y=0.294
# Velocità: x_vel=0.310, y_vel=0.161
# Forze: force_x=1649.808, force_y=871.442
# Posizione: x=0.283, y=0.296
# Velocità: x_vel=0.265, y_vel=0.121
# Forze: force_x=1425.813, force_y=651.149
# Posizione: x=0.285, y=0.297
# Velocità: x_vel=0.200, y_vel=0.210
# Forze: force_x=1077.185, force_y=1117.092
# Posizione: x=0.287, y=0.299
# Velocità: x_vel=0.258, y_vel=0.119
# Forze: force_x=1380.829, force_y=648.887
# Rimbalzo su lato orizzontale: y=0.300, v_y=0.119
# Posizione: x=0.290, y=0.300
# Velocità: x_vel=0.272, y_vel=-0.228
# Forze: force_x=1458.821, force_y=-1191.400
# Posizione: x=0.293, y=0.298
# Velocità: x_vel=0.168, y_vel=-0.199
# Forze: force_x=913.787, force_y=-1070.821
# Posizione: x=0.294, y=0.296
# Velocità: x_vel=0.125, y_vel=-0.094
# Forze: force_x=904.452, force_y=-697.557
# Posizione: x=0.296, y=0.295
# Velocità: x_vel=0.301, y_vel=-0.170
# Forze: force_x=1602.635, force_y=-908.473
# Posizione: x=0.299, y=0.293
# Velocità: x_vel=0.203, y_vel=-0.269
# Forze: force_x=1475.709, force_y=-1921.876
# Rimbalzo su lato verticale: x=0.301, v_x=0.203
# Posizione: x=0.301, y=0.291
# Velocità: x_vel=-0.194, y_vel=-0.069
# Forze: force_x=-1300.357, force_y=-518.330
# Posizione: x=0.299, y=0.290
# Velocità: x_vel=-0.007, y_vel=-0.074
# Forze: force_x=-55.961, force_y=-399.521
# Posizione: x=0.299, y=0.289
# Velocità: x_vel=-0.259, y_vel=-0.118
# Forze: force_x=-1367.884, force_y=-630.965
# Posizione: x=0.296, y=0.288
# Velocità: x_vel=-0.103, y_vel=-0.064
# Forze: force_x=-569.645, force_y=-349.475
# Posizione: x=0.295, y=0.287
# Velocità: x_vel=-0.177, y_vel=-0.361
# Forze: force_x=-943.343, force_y=-1910.931
# Posizione: x=0.293, y=0.284
# Velocità: x_vel=-0.174, y_vel=-0.202
# Forze: force_x=-934.312, force_y=-1100.087
# Posizione: x=0.291, y=0.282
# Velocità: x_vel=-0.276, y_vel=-0.144
# Forze: force_x=-1473.795, force_y=-775.689
# Posizione: x=0.289, y=0.280
# Velocità: x_vel=-0.174, y_vel=-0.103
# Forze: force_x=-945.121, force_y=-556.348
# Posizione: x=0.287, y=0.279
# Velocità: x_vel=-0.044, y_vel=-0.013
# Forze: force_x=-248.973, force_y=-80.400
# Posizione: x=0.287, y=0.279
# Velocità: x_vel=-0.295, y_vel=-0.107
# Forze: force_x=-1560.131, force_y=-564.502
# Posizione: x=0.284, y=0.278
# Velocità: x_vel=-0.102, y_vel=-0.299
# Forze: force_x=-565.274, force_y=-1587.463
# Posizione: x=0.283, y=0.275
# Velocità: x_vel=-0.103, y_vel=-0.154
# Forze: force_x=-719.959, force_y=-1119.134
# Posizione: x=0.282, y=0.274
# Velocità: x_vel=0.024, y_vel=0.025
# Forze: force_x=117.592, force_y=118.149
# Posizione: x=0.282, y=0.274
# Velocità: x_vel=-0.160, y_vel=-0.044
# Forze: force_x=-839.779, force_y=-228.851
# Posizione: x=0.280, y=0.273
# Velocità: x_vel=-0.185, y_vel=-0.139
# Forze: force_x=-1298.604, force_y=-959.677
# Posizione: x=0.278, y=0.272
# Velocità: x_vel=-0.285, y_vel=-0.217
# Forze: force_x=-1519.348, force_y=-1160.222
# Posizione: x=0.276, y=0.270
# Velocità: x_vel=-0.122, y_vel=-0.200
# Forze: force_x=-668.481, force_y=-1073.403
# Posizione: x=0.274, y=0.268
# Velocità: x_vel=-0.222, y_vel=-0.225
# Forze: force_x=-1183.382, force_y=-1207.011
# Posizione: x=0.272, y=0.266
# Velocità: x_vel=-0.163, y_vel=-0.228
# Forze: force_x=-1153.118, force_y=-1616.139
# Posizione: x=0.270, y=0.263
# Velocità: x_vel=-0.029, y_vel=-0.202
# Forze: force_x=-167.766, force_y=-1085.689
# Posizione: x=0.270, y=0.261
# Velocità: x_vel=-0.048, y_vel=-0.266
# Forze: force_x=-319.487, force_y=-1883.520
# Posizione: x=0.270, y=0.259
# Velocità: x_vel=-0.035, y_vel=-0.214
# Forze: force_x=-231.673, force_y=-1535.050
# Posizione: x=0.269, y=0.256
# Velocità: x_vel=-0.200, y_vel=-0.137
# Forze: force_x=-1387.861, force_y=-974.969
# Posizione: x=0.267, y=0.255
# Velocità: x_vel=-0.297, y_vel=-0.172
# Forze: force_x=-1584.532, force_y=-918.049
# Posizione: x=0.264, y=0.253
# Velocità: x_vel=-0.296, y_vel=-0.292
# Forze: force_x=-1591.208, force_y=-1556.838
# Posizione: x=0.261, y=0.250
# Velocità: x_vel=-0.260, y_vel=-0.380
# Forze: force_x=-1398.969, force_y=-2032.879
# Posizione: x=0.259, y=0.247
# Velocità: x_vel=-0.193, y_vel=-0.198
# Forze: force_x=-1043.994, force_y=-1077.181
# Posizione: x=0.257, y=0.245
# Velocità: x_vel=-0.161, y_vel=-0.353
# Forze: force_x=-867.925, force_y=-1880.440
# Posizione: x=0.255, y=0.241
# Velocità: x_vel=-0.021, y_vel=-0.247
# Forze: force_x=-126.162, force_y=-1337.930
# Posizione: x=0.255, y=0.239
# Velocità: x_vel=-0.265, y_vel=-0.157
# Forze: force_x=-1399.254, force_y=-849.582
# Posizione: x=0.252, y=0.237
# Velocità: x_vel=-0.148, y_vel=-0.294
# Forze: force_x=-806.578, force_y=-1563.843
# Posizione: x=0.251, y=0.234
# Velocità: x_vel=-0.193, y_vel=-0.221
# Forze: force_x=-1351.989, force_y=-1574.497
# Posizione: x=0.249, y=0.232
# Velocità: x_vel=-0.286, y_vel=-0.328
# Forze: force_x=-1527.738, force_y=-1748.590
# Posizione: x=0.246, y=0.229
# Velocità: x_vel=-0.127, y_vel=-0.157
# Forze: force_x=-918.997, force_y=-1134.597
# Posizione: x=0.245, y=0.227
# Velocità: x_vel=-0.023, y_vel=-0.160
# Forze: force_x=-132.188, force_y=-858.901
# Posizione: x=0.245, y=0.226
# Velocità: x_vel=-0.241, y_vel=-0.097
# Forze: force_x=-1273.346, force_y=-526.707
# Posizione: x=0.242, y=0.225
# Velocità: x_vel=-0.142, y_vel=-0.373
# Forze: force_x=-768.552, force_y=-1978.373
# Posizione: x=0.241, y=0.221
# Velocità: x_vel=-0.113, y_vel=-0.180
# Forze: force_x=-796.580, force_y=-1302.995
# Posizione: x=0.240, y=0.219
# Velocità: x_vel=-0.166, y_vel=-0.139
# Forze: force_x=-887.338, force_y=-747.897
# Posizione: x=0.238, y=0.218
# Velocità: x_vel=-0.319, y_vel=-0.237
# Forze: force_x=-1698.890, force_y=-1261.923
# Posizione: x=0.235, y=0.215
# Velocità: x_vel=-0.230, y_vel=-0.219
# Forze: force_x=-1243.067, force_y=-1178.823
# Posizione: x=0.233, y=0.213
# Velocità: x_vel=-0.083, y_vel=-0.288
# Forze: force_x=-456.981, force_y=-1538.410
# Posizione: x=0.232, y=0.210
# Velocità: x_vel=-0.218, y_vel=-0.146
# Forze: force_x=-1158.803, force_y=-794.000
# Posizione: x=0.229, y=0.209
# Velocità: x_vel=-0.138, y_vel=-0.140
# Forze: force_x=-987.411, force_y=-988.820
# Posizione: x=0.228, y=0.207
# Velocità: x_vel=-0.154, y_vel=-0.137
# Forze: force_x=-1090.304, force_y=-962.116
# Posizione: x=0.227, y=0.206
# Velocità: x_vel=-0.140, y_vel=-0.182
# Forze: force_x=-988.454, force_y=-1272.278
# Posizione: x=0.225, y=0.204
# Velocità: x_vel=-0.258, y_vel=-0.236
# Forze: force_x=-1807.842, force_y=-1649.881
# Posizione: x=0.223, y=0.202
# Velocità: x_vel=-0.130, y_vel=-0.274
# Forze: force_x=-706.898, force_y=-1467.658
# Posizione: x=0.221, y=0.199
# Velocità: x_vel=-0.196, y_vel=-0.255
# Forze: force_x=-1046.074, force_y=-1371.492
# Posizione: x=0.219, y=0.197
# Velocità: x_vel=-0.254, y_vel=-0.263
# Forze: force_x=-1356.639, force_y=-1409.172
# Posizione: x=0.217, y=0.194
# Velocità: x_vel=-0.186, y_vel=-0.102
# Forze: force_x=-1005.099, force_y=-562.602
# Posizione: x=0.215, y=0.193
# Velocità: x_vel=-0.130, y_vel=-0.248
# Forze: force_x=-703.340, force_y=-1319.517
# Posizione: x=0.214, y=0.190
# Velocità: x_vel=0.034, y_vel=-0.058
# Forze: force_x=165.673, force_y=-329.367
# Posizione: x=0.214, y=0.190
# Velocità: x_vel=-0.193, y_vel=-0.081
# Forze: force_x=-1013.837, force_y=-429.731
# Posizione: x=0.212, y=0.189
# Velocità: x_vel=-0.255, y_vel=-0.044
# Forze: force_x=-1363.576, force_y=-239.110
# Posizione: x=0.209, y=0.189
# Velocità: x_vel=-0.212, y_vel=-0.201
# Forze: force_x=-1140.845, force_y=-1067.172
# Posizione: x=0.207, y=0.187
# Velocità: x_vel=-0.055, y_vel=0.004
# Forze: force_x=-307.008, force_y=3.753
# Posizione: x=0.207, y=0.187
# Velocità: x_vel=-0.248, y_vel=-0.240
# Forze: force_x=-1722.165, force_y=-1643.754
# Posizione: x=0.204, y=0.184
# Velocità: x_vel=-0.348, y_vel=-0.247
# Forze: force_x=-1861.761, force_y=-1326.292
# Posizione: x=0.201, y=0.182
# Velocità: x_vel=-0.259, y_vel=-0.065
# Forze: force_x=-1863.131, force_y=-478.031
# Posizione: x=0.198, y=0.181
# Velocità: x_vel=-0.075, y_vel=-0.093
# Forze: force_x=-418.803, force_y=-498.530
# Posizione: x=0.198, y=0.180
# Velocità: x_vel=-0.122, y_vel=-0.304
# Forze: force_x=-651.948, force_y=-1611.451
# Posizione: x=0.196, y=0.177
# Velocità: x_vel=-0.148, y_vel=-0.206
# Forze: force_x=-791.270, force_y=-1116.402
# Posizione: x=0.195, y=0.175
# Velocità: x_vel=-0.267, y_vel=-0.161
# Forze: force_x=-1421.900, force_y=-866.854
# Posizione: x=0.192, y=0.173
# Velocità: x_vel=-0.312, y_vel=-0.219
# Forze: force_x=-1668.608, force_y=-1168.616
# Posizione: x=0.189, y=0.171
# Velocità: x_vel=-0.259, y_vel=-0.103
# Forze: force_x=-1396.433, force_y=-561.374
# Posizione: x=0.186, y=0.170
# Velocità: x_vel=-0.127, y_vel=-0.309
# Forze: force_x=-692.349, force_y=-1639.596
# Posizione: x=0.185, y=0.167
# Velocità: x_vel=-0.233, y_vel=-0.299
# Forze: force_x=-1240.924, force_y=-1606.496
# Posizione: x=0.183, y=0.164
# Velocità: x_vel=-0.160, y_vel=-0.173
# Forze: force_x=-1149.532, force_y=-1239.363
# Posizione: x=0.181, y=0.162
# Velocità: x_vel=-0.128, y_vel=-0.025
# Forze: force_x=-688.141, force_y=-147.919
# Posizione: x=0.180, y=0.162
# Velocità: x_vel=-0.148, y_vel=-0.082
# Forze: force_x=-790.242, force_y=-433.747
# Posizione: x=0.179, y=0.161
# Velocità: x_vel=-0.087, y_vel=-0.101
# Forze: force_x=-472.759, force_y=-540.081
# Posizione: x=0.178, y=0.160
# Velocità: x_vel=-0.132, y_vel=-0.190
# Forze: force_x=-702.651, force_y=-1013.056
# Posizione: x=0.176, y=0.158
# Velocità: x_vel=-0.146, y_vel=-0.211
# Forze: force_x=-1212.670, force_y=-1744.647
# Posizione: x=0.175, y=0.156
# Velocità: x_vel=-0.148, y_vel=-0.200
# Forze: force_x=-794.391, force_y=-1076.388
# Posizione: x=0.173, y=0.154
# Velocità: x_vel=-0.075, y_vel=-0.077
# Forze: force_x=-548.284, force_y=-563.061
# Posizione: x=0.173, y=0.154
# Velocità: x_vel=-0.221, y_vel=-0.364
# Forze: force_x=-1172.489, force_y=-1925.802
# Posizione: x=0.170, y=0.150
# Velocità: x_vel=-0.083, y_vel=-0.114
# Forze: force_x=-613.212, force_y=-845.126
# Posizione: x=0.170, y=0.149
# Velocità: x_vel=-0.288, y_vel=-0.227
# Forze: force_x=-1527.677, force_y=-1208.406
# Posizione: x=0.167, y=0.146
# Velocità: x_vel=-0.152, y_vel=-0.260
# Forze: force_x=-827.651, force_y=-1393.237
# Posizione: x=0.165, y=0.144
# Velocità: x_vel=-0.286, y_vel=-0.262
# Forze: force_x=-1525.360, force_y=-1407.294
# Posizione: x=0.162, y=0.141
# Velocità: x_vel=-0.213, y_vel=-0.286
# Forze: force_x=-1150.728, force_y=-1533.109
# Posizione: x=0.160, y=0.138
# Velocità: x_vel=-0.096, y_vel=-0.195
# Forze: force_x=-830.683, force_y=-1645.852
# Posizione: x=0.159, y=0.136
# Velocità: x_vel=0.036, y_vel=0.001
# Forze: force_x=235.919, force_y=-28.655
# Posizione: x=0.160, y=0.136
# Velocità: x_vel=-0.186, y_vel=-0.157
# Forze: force_x=-976.635, force_y=-829.373
# Posizione: x=0.158, y=0.135
# Velocità: x_vel=-0.188, y_vel=-0.174
# Forze: force_x=-1007.743, force_y=-935.185
# Posizione: x=0.156, y=0.133
# Velocità: x_vel=-0.284, y_vel=-0.176
# Forze: force_x=-1514.534, force_y=-944.133
# Posizione: x=0.153, y=0.131
# Velocità: x_vel=-0.075, y_vel=-0.253
# Forze: force_x=-529.065, force_y=-1671.413
# Posizione: x=0.152, y=0.129
# Velocità: x_vel=-0.123, y_vel=-0.087
# Forze: force_x=-656.219, force_y=-481.022
# Posizione: x=0.151, y=0.128
# Velocità: x_vel=-0.255, y_vel=-0.242
# Forze: force_x=-1354.768, force_y=-1284.535
# Posizione: x=0.149, y=0.126
# Velocità: x_vel=-0.124, y_vel=-0.002
# Forze: force_x=-678.859, force_y=-35.210
# Posizione: x=0.147, y=0.126
# Velocità: x_vel=-0.405, y_vel=-0.184
# Forze: force_x=-2148.299, force_y=-970.227
# Posizione: x=0.143, y=0.124
# Velocità: x_vel=-0.166, y_vel=-0.122
# Forze: force_x=-912.070, force_y=-662.967
# Posizione: x=0.142, y=0.122
# Velocità: x_vel=-0.190, y_vel=-0.363
# Forze: force_x=-1015.876, force_y=-1926.757
# Posizione: x=0.140, y=0.119
# Velocità: x_vel=-0.109, y_vel=-0.033
# Forze: force_x=-798.399, force_y=-286.570
# Posizione: x=0.139, y=0.119
# Velocità: x_vel=-0.072, y_vel=-0.082
# Forze: force_x=-520.306, force_y=-568.953
# Posizione: x=0.138, y=0.118
# Velocità: x_vel=-0.284, y_vel=-0.376
# Forze: force_x=-1505.552, force_y=-1993.605
# Posizione: x=0.135, y=0.114
# Velocità: x_vel=-0.285, y_vel=-0.202
# Forze: force_x=-1527.823, force_y=-1100.485
# Posizione: x=0.132, y=0.112
# Velocità: x_vel=-0.201, y_vel=-0.305
# Forze: force_x=-1088.100, force_y=-1626.430
# Posizione: x=0.130, y=0.109
# Velocità: x_vel=-0.117, y_vel=-0.172
# Forze: force_x=-635.513, force_y=-936.622
# Posizione: x=0.129, y=0.107
# Velocità: x_vel=-0.261, y_vel=-0.346
# Forze: force_x=-1390.773, force_y=-1839.072
# Posizione: x=0.126, y=0.104
# Velocità: x_vel=-0.148, y_vel=-0.186
# Forze: force_x=-803.284, force_y=-1015.827
# Posizione: x=0.125, y=0.102
# Velocità: x_vel=-0.165, y_vel=-0.294
# Forze: force_x=-1168.486, force_y=-2049.227
# Posizione: x=0.123, y=0.099
# Velocità: x_vel=-0.167, y_vel=-0.272
# Forze: force_x=-1188.879, force_y=-1914.438
# Posizione: x=0.122, y=0.096
# Velocità: x_vel=-0.161, y_vel=-0.346
# Forze: force_x=-863.488, force_y=-1852.402
# Posizione: x=0.120, y=0.093
# Velocità: x_vel=-0.180, y_vel=-0.303
# Forze: force_x=-962.725, force_y=-1628.441
# Posizione: x=0.118, y=0.090
# Velocità: x_vel=0.023, y_vel=-0.150
# Forze: force_x=134.230, force_y=-1083.670
# Posizione: x=0.118, y=0.088
# Velocità: x_vel=-0.307, y_vel=-0.072
# Forze: force_x=-1617.611, force_y=-392.058
# Posizione: x=0.115, y=0.087
# Velocità: x_vel=-0.190, y_vel=-0.221
# Forze: force_x=-1376.513, force_y=-1524.212
# Posizione: x=0.113, y=0.085
# Velocità: x_vel=-0.332, y_vel=-0.351
# Forze: force_x=-1770.541, force_y=-1870.093
# Posizione: x=0.110, y=0.082
# Velocità: x_vel=-0.147, y_vel=-0.217
# Forze: force_x=-807.573, force_y=-1174.891
# Posizione: x=0.109, y=0.080
# Velocità: x_vel=-0.141, y_vel=-0.118
# Forze: force_x=-759.894, force_y=-642.793
# Posizione: x=0.107, y=0.078
# Velocità: x_vel=-0.170, y_vel=-0.081
# Forze: force_x=-911.739, force_y=-437.174
# Posizione: x=0.106, y=0.078
# Velocità: x_vel=-0.071, y_vel=-0.124
# Forze: force_x=-387.496, force_y=-662.678
# Posizione: x=0.105, y=0.076
# Velocità: x_vel=-0.234, y_vel=-0.226
# Forze: force_x=-1239.963, force_y=-1205.546
# Posizione: x=0.102, y=0.074
# Velocità: x_vel=-0.143, y_vel=-0.105
# Forze: force_x=-777.412, force_y=-576.320
# Posizione: x=0.101, y=0.073
# Velocità: x_vel=-0.314, y_vel=-0.340
# Forze: force_x=-1672.097, force_y=-1802.170
# Posizione: x=0.098, y=0.070
# Velocità: x_vel=-0.199, y_vel=-0.114
# Forze: force_x=-1077.461, force_y=-631.473
# Posizione: x=0.096, y=0.068
# Velocità: x_vel=-0.235, y_vel=-0.104
# Forze: force_x=-1259.606, force_y=-557.794
# Posizione: x=0.094, y=0.067
# Velocità: x_vel=-0.115, y_vel=-0.139
# Forze: force_x=-629.525, force_y=-743.513
# Posizione: x=0.092, y=0.066
# Velocità: x_vel=-0.016, y_vel=-0.196
# Forze: force_x=-128.739, force_y=-1372.448
# Posizione: x=0.092, y=0.064
# Velocità: x_vel=-0.212, y_vel=-0.155
# Forze: force_x=-1740.631, force_y=-1294.922
# Posizione: x=0.090, y=0.063
# Velocità: x_vel=-0.188, y_vel=-0.202
# Forze: force_x=-1012.396, force_y=-1080.449
# Posizione: x=0.088, y=0.061
# Velocità: x_vel=-0.176, y_vel=-0.257
# Forze: force_x=-945.147, force_y=-1374.464
# Posizione: x=0.086, y=0.058
# Velocità: x_vel=-0.326, y_vel=-0.404
# Forze: force_x=-1735.876, force_y=-2157.475
# Posizione: x=0.083, y=0.054
# Velocità: x_vel=-0.120, y_vel=-0.185
# Forze: force_x=-662.544, force_y=-1015.652
# Posizione: x=0.082, y=0.052
# Velocità: x_vel=-0.098, y_vel=-0.067
# Forze: force_x=-529.412, force_y=-370.973
# Posizione: x=0.081, y=0.051
# Velocità: x_vel=-0.247, y_vel=-0.123
# Forze: force_x=-1744.453, force_y=-851.808
# Posizione: x=0.079, y=0.050
# Velocità: x_vel=-0.174, y_vel=-0.270
# Forze: force_x=-939.981, force_y=-1435.224
# Posizione: x=0.077, y=0.047
# Velocità: x_vel=-0.250, y_vel=-0.136
# Forze: force_x=-1333.420, force_y=-743.833
# Posizione: x=0.074, y=0.046
# Velocità: x_vel=-0.207, y_vel=-0.123
# Forze: force_x=-1115.994, force_y=-661.748
# Posizione: x=0.072, y=0.045
# Velocità: x_vel=-0.119, y_vel=-0.163
# Forze: force_x=-868.227, force_y=-1141.247
# Posizione: x=0.071, y=0.043
# Velocità: x_vel=-0.259, y_vel=-0.181
# Forze: force_x=-1376.800, force_y=-971.237
# Posizione: x=0.068, y=0.041
# Velocità: x_vel=-0.217, y_vel=-0.204
# Forze: force_x=-1167.139, force_y=-1092.903
# Posizione: x=0.066, y=0.039
# Velocità: x_vel=-0.148, y_vel=-0.271
# Forze: force_x=-802.948, force_y=-1447.945
# Posizione: x=0.065, y=0.037
# Velocità: x_vel=-0.142, y_vel=-0.286
# Forze: force_x=-761.605, force_y=-1533.976
# Posizione: x=0.063, y=0.034
# Velocità: x_vel=-0.077, y_vel=-0.121
# Forze: force_x=-523.513, force_y=-827.694
# Posizione: x=0.063, y=0.033
# Velocità: x_vel=-0.154, y_vel=-0.127
# Forze: force_x=-819.654, force_y=-680.179
# Posizione: x=0.061, y=0.031
# Velocità: x_vel=-0.293, y_vel=-0.198
# Forze: force_x=-2078.772, force_y=-1380.386
# Posizione: x=0.058, y=0.029
# Velocità: x_vel=-0.337, y_vel=-0.174
# Forze: force_x=-1805.960, force_y=-934.634
# Posizione: x=0.055, y=0.028
# Velocità: x_vel=-0.103, y_vel=-0.112
# Forze: force_x=-783.481, force_y=-799.345
# Posizione: x=0.054, y=0.027
# Velocità: x_vel=-0.082, y_vel=-0.157
# Forze: force_x=-440.270, force_y=-837.418
# Posizione: x=0.053, y=0.025
# Velocità: x_vel=-0.208, y_vel=-0.159
# Forze: force_x=-1106.004, force_y=-855.560
# Posizione: x=0.051, y=0.023
# Velocità: x_vel=-0.244, y_vel=-0.167
# Forze: force_x=-1304.862, force_y=-893.487
# Posizione: x=0.048, y=0.022
# Velocità: x_vel=-0.172, y_vel=-0.146
# Forze: force_x=-1249.488, force_y=-1033.554
# Posizione: x=0.047, y=0.020
# Velocità: x_vel=-0.221, y_vel=-0.071
# Forze: force_x=-1179.575, force_y=-388.866
# Posizione: x=0.045, y=0.020
# Velocità: x_vel=-0.280, y_vel=0.082
# Forze: force_x=-1498.109, force_y=426.355
# Posizione: x=0.042, y=0.020
# Velocità: x_vel=-0.254, y_vel=-0.171
# Forze: force_x=-1368.052, force_y=-893.389
# Posizione: x=0.039, y=0.019
# Velocità: x_vel=-0.262, y_vel=-0.162
# Forze: force_x=-1406.645, force_y=-871.567
# Posizione: x=0.037, y=0.017
# Velocità: x_vel=-0.489, y_vel=-0.085
# Forze: force_x=-2606.639, force_y=-464.265
# Posizione: x=0.032, y=0.016
# Velocità: x_vel=-0.283, y_vel=-0.180
# Forze: force_x=-1538.868, force_y=-955.512
# Posizione: x=0.029, y=0.014
# Velocità: x_vel=-0.362, y_vel=-0.134
# Forze: force_x=-1935.043, force_y=-723.323
# Posizione: x=0.025, y=0.013
# Velocità: x_vel=-0.142, y_vel=-0.037
# Forze: force_x=-782.168, force_y=-209.412
# Posizione: x=0.024, y=0.013
# Velocità: x_vel=-0.192, y_vel=-0.209
# Forze: force_x=-1028.968, force_y=-1103.799
# Posizione: x=0.022, y=0.011
# Velocità: x_vel=-0.123, y_vel=-0.101
# Forze: force_x=-667.936, force_y=-554.684
# Posizione: x=0.021, y=0.010
# Velocità: x_vel=-0.199, y_vel=-0.234
# Forze: force_x=-1663.072, force_y=-1912.665
# Posizione: x=0.019, y=0.007
# Velocità: x_vel=-0.059, y_vel=-0.054
# Forze: force_x=-537.266, force_y=-490.037
# Posizione: x=0.018, y=0.007
# Velocità: x_vel=-0.181, y_vel=-0.125
# Forze: force_x=-960.430, force_y=-663.697
# Posizione: x=0.016, y=0.005
# Velocità: x_vel=-0.259, y_vel=-0.095
# Forze: force_x=-1380.967, force_y=-510.890
# Posizione: x=0.014, y=0.004
# Velocità: x_vel=-0.182, y_vel=-0.187
# Forze: force_x=-1320.134, force_y=-1303.962
# Posizione: x=0.012, y=0.003
# Velocità: x_vel=-0.153, y_vel=-0.242
# Forze: force_x=-1106.825, force_y=-1697.091
# Posizione: x=0.010, y=0.000
# Velocità: x_vel=-0.143, y_vel=-0.033
# Forze: force_x=-948.058, force_y=-249.145
# Posizione: x=0.009, y=-0.000
# Velocità: x_vel=-0.205, y_vel=-0.231
# Forze: force_x=-1097.525, force_y=-1219.971
# Posizione: x=0.007, y=-0.002
# Velocità: x_vel=-0.163, y_vel=-0.222
# Forze: force_x=-879.442, force_y=-1193.747
# Posizione: x=0.005, y=-0.005
# Velocità: x_vel=-0.127, y_vel=-0.191
# Forze: force_x=-685.071, force_y=-1029.097
# Posizione: x=0.004, y=-0.007
# Velocità: x_vel=-0.283, y_vel=-0.271
# Forze: force_x=-1503.907, force_y=-1446.166
# Posizione: x=0.001, y=-0.009
# Velocità: x_vel=-0.156, y_vel=-0.104
# Forze: force_x=-848.023, force_y=-571.823
# Posizione: x=-0.000, y=-0.010
# Velocità: x_vel=-0.095, y_vel=-0.164
# Forze: force_x=-822.928, force_y=-1352.592
# Posizione: x=-0.001, y=-0.012
# Velocità: x_vel=-0.131, y_vel=-0.152
# Forze: force_x=-937.496, force_y=-1075.811
# Posizione: x=-0.003, y=-0.014
# Velocità: x_vel=-0.157, y_vel=-0.057
# Forze: force_x=-841.498, force_y=-315.824
# Posizione: x=-0.004, y=-0.014
# Velocità: x_vel=-0.135, y_vel=-0.180
# Forze: force_x=-726.031, force_y=-954.632
# Posizione: x=-0.006, y=-0.016
# Velocità: x_vel=-0.126, y_vel=-0.055
# Forze: force_x=-912.139, force_y=-409.986
# Posizione: x=-0.007, y=-0.016
# Velocità: x_vel=-0.271, y_vel=-0.216
# Forze: force_x=-1440.577, force_y=-1142.555
# Posizione: x=-0.010, y=-0.019
# Velocità: x_vel=-0.332, y_vel=-0.106
# Forze: force_x=-1779.070, force_y=-581.204
# Posizione: x=-0.013, y=-0.020
# Velocità: x_vel=-0.229, y_vel=-0.144
# Forze: force_x=-1666.649, force_y=-1008.162
# Posizione: x=-0.015, y=-0.021
# Velocità: x_vel=-0.115, y_vel=-0.294
# Forze: force_x=-627.408, force_y=-1563.002
# Posizione: x=-0.016, y=-0.024
# Velocità: x_vel=-0.235, y_vel=-0.131
# Forze: force_x=-1249.259, force_y=-717.046
# Posizione: x=-0.019, y=-0.025
# Velocità: x_vel=-0.236, y_vel=-0.078
# Forze: force_x=-1697.167, force_y=-561.461
# Posizione: x=-0.021, y=-0.026
# Velocità: x_vel=-0.243, y_vel=-0.149
# Forze: force_x=-1304.509, force_y=-793.698
# Posizione: x=-0.024, y=-0.028
# Velocità: x_vel=-0.316, y_vel=-0.269
# Forze: force_x=-1689.659, force_y=-1435.746
# Posizione: x=-0.027, y=-0.030
# Velocità: x_vel=-0.207, y_vel=-0.112
# Forze: force_x=-1122.373, force_y=-613.198
# Posizione: x=-0.029, y=-0.031
# Velocità: x_vel=-0.169, y_vel=-0.156
# Forze: force_x=-912.208, force_y=-834.510
# Posizione: x=-0.030, y=-0.033
# Velocità: x_vel=-0.151, y_vel=-0.397
# Forze: force_x=-812.135, force_y=-2110.214
# Posizione: x=-0.032, y=-0.037
# Velocità: x_vel=-0.038, y_vel=-0.249
# Forze: force_x=-211.883, force_y=-1350.875
# Posizione: x=-0.032, y=-0.039
# Velocità: x_vel=-0.115, y_vel=-0.227
# Forze: force_x=-609.687, force_y=-1220.983
# Posizione: x=-0.033, y=-0.042
# Velocità: x_vel=-0.365, y_vel=-0.126
# Forze: force_x=-1938.236, force_y=-686.719
# Posizione: x=-0.037, y=-0.043
# Velocità: x_vel=-0.170, y_vel=-0.148
# Forze: force_x=-930.375, force_y=-794.528
# Posizione: x=-0.039, y=-0.044
# Velocità: x_vel=-0.199, y_vel=-0.167
# Forze: force_x=-1681.339, force_y=-1385.746
# Posizione: x=-0.041, y=-0.046
# Velocità: x_vel=-0.173, y_vel=-0.034
# Forze: force_x=-929.857, force_y=-195.980
# Posizione: x=-0.043, y=-0.046
# Velocità: x_vel=-0.146, y_vel=-0.076
# Forze: force_x=-788.526, force_y=-402.916
# Posizione: x=-0.044, y=-0.047
# Velocità: x_vel=-0.332, y_vel=-0.281
# Forze: force_x=-1768.396, force_y=-1490.109
# Posizione: x=-0.047, y=-0.050
# Velocità: x_vel=-0.292, y_vel=-0.355
# Forze: force_x=-1571.301, force_y=-1897.202
# Posizione: x=-0.050, y=-0.054
# Velocità: x_vel=-0.350, y_vel=0.045
# Forze: force_x=-1875.058, force_y=206.442
# Posizione: x=-0.054, y=-0.053
# Velocità: x_vel=-0.311, y_vel=-0.155
# Forze: force_x=-1674.526, force_y=-813.122
# Posizione: x=-0.057, y=-0.055
# Velocità: x_vel=-0.124, y_vel=-0.110
# Forze: force_x=-931.508, force_y=-783.299
# Posizione: x=-0.058, y=-0.056
# Velocità: x_vel=-0.135, y_vel=-0.276
# Forze: force_x=-726.300, force_y=-1465.055
# Posizione: x=-0.059, y=-0.059
# Velocità: x_vel=-0.205, y_vel=-0.083
# Forze: force_x=-1092.839, force_y=-461.080
# Posizione: x=-0.062, y=-0.059
# Velocità: x_vel=-0.031, y_vel=-0.062
# Forze: force_x=-234.024, force_y=-412.216
# Posizione: x=-0.062, y=-0.060
# Velocità: x_vel=-0.161, y_vel=-0.167
# Forze: force_x=-1138.514, force_y=-1162.742
# Posizione: x=-0.063, y=-0.062
# Velocità: x_vel=-0.058, y_vel=-0.119
# Forze: force_x=-440.077, force_y=-849.465
# Posizione: x=-0.064, y=-0.063
# Velocità: x_vel=-0.291, y_vel=-0.196
# Forze: force_x=-1544.059, force_y=-1044.218
# Posizione: x=-0.067, y=-0.065
# Velocità: x_vel=-0.265, y_vel=-0.209
# Forze: force_x=-1427.504, force_y=-1120.206
# Posizione: x=-0.070, y=-0.067
# Velocità: x_vel=-0.072, y_vel=-0.174
# Forze: force_x=-402.677, force_y=-934.631
# Posizione: x=-0.070, y=-0.069
# Velocità: x_vel=-0.189, y_vel=-0.243
# Forze: force_x=-1002.143, force_y=-1299.245
# Posizione: x=-0.072, y=-0.071
# Velocità: x_vel=-0.087, y_vel=-0.248
# Forze: force_x=-478.093, force_y=-1329.421
# Posizione: x=-0.073, y=-0.074
# Velocità: x_vel=-0.185, y_vel=-0.208
# Forze: force_x=-985.308, force_y=-1121.144
# Posizione: x=-0.075, y=-0.076
# Velocità: x_vel=-0.113, y_vel=-0.032
# Forze: force_x=-612.551, force_y=-186.433
# Posizione: x=-0.076, y=-0.076
# Velocità: x_vel=-0.181, y_vel=-0.120
# Forze: force_x=-1291.691, force_y=-835.172
# Posizione: x=-0.078, y=-0.077
# Velocità: x_vel=-0.188, y_vel=-0.135
# Forze: force_x=-1009.403, force_y=-724.655
# Posizione: x=-0.080, y=-0.078
# Velocità: x_vel=-0.300, y_vel=-0.251
# Forze: force_x=-1599.539, force_y=-1337.138
# Posizione: x=-0.083, y=-0.081
# Velocità: x_vel=-0.375, y_vel=-0.281
# Forze: force_x=-2004.420, force_y=-1505.271
# Posizione: x=-0.086, y=-0.084
# Velocità: x_vel=-0.219, y_vel=-0.175
# Forze: force_x=-1191.176, force_y=-948.307
# Posizione: x=-0.089, y=-0.086
# Velocità: x_vel=-0.065, y_vel=-0.242
# Forze: force_x=-359.955, force_y=-1291.473
# Posizione: x=-0.089, y=-0.088
# Velocità: x_vel=-0.316, y_vel=-0.159
# Forze: force_x=-1672.783, force_y=-859.329
# Posizione: x=-0.092, y=-0.090
# Velocità: x_vel=-0.070, y_vel=-0.172
# Forze: force_x=-395.565, force_y=-922.260
# Posizione: x=-0.093, y=-0.091
# Velocità: x_vel=-0.128, y_vel=-0.266
# Forze: force_x=-919.864, force_y=-1863.395
# Posizione: x=-0.094, y=-0.094
# Velocità: x_vel=-0.047, y_vel=-0.151
# Forze: force_x=-258.292, force_y=-820.948
# Posizione: x=-0.095, y=-0.095
# Velocità: x_vel=-0.186, y_vel=-0.186
# Forze: force_x=-986.263, force_y=-997.918
# Posizione: x=-0.097, y=-0.097
# Velocità: x_vel=-0.109, y_vel=-0.238
# Forze: force_x=-804.650, force_y=-1672.878
# Posizione: x=-0.098, y=-0.100
# Velocità: x_vel=-0.181, y_vel=-0.204
# Forze: force_x=-967.962, force_y=-1097.552
# Posizione: x=-0.100, y=-0.102
# Velocità: x_vel=-0.188, y_vel=-0.184
# Forze: force_x=-1249.933, force_y=-1222.689
# Posizione: x=-0.102, y=-0.104
# Velocità: x_vel=-0.303, y_vel=-0.419
# Forze: force_x=-1616.197, force_y=-2226.864
# Posizione: x=-0.105, y=-0.108
# Velocità: x_vel=-0.221, y_vel=-0.310
# Forze: force_x=-1193.912, force_y=-1674.471
# Posizione: x=-0.107, y=-0.111
# Velocità: x_vel=-0.280, y_vel=-0.399
# Forze: force_x=-1497.301, force_y=-2135.425
# Posizione: x=-0.110, y=-0.115
# Velocità: x_vel=-0.291, y_vel=-0.263
# Forze: force_x=-1559.132, force_y=-1425.063
# Posizione: x=-0.113, y=-0.117
# Velocità: x_vel=-0.130, y_vel=-0.231
# Forze: force_x=-711.975, force_y=-1245.510
# Posizione: x=-0.114, y=-0.120
# Velocità: x_vel=-0.145, y_vel=-0.136
# Forze: force_x=-1046.055, force_y=-978.639
# Posizione: x=-0.115, y=-0.121
# Velocità: x_vel=-0.161, y_vel=-0.129
# Forze: force_x=-862.261, force_y=-694.234
# Posizione: x=-0.117, y=-0.122
# Velocità: x_vel=-0.241, y_vel=-0.346
# Forze: force_x=-1285.662, force_y=-1839.105
# Posizione: x=-0.119, y=-0.126
# Velocità: x_vel=-0.195, y_vel=-0.184
# Forze: force_x=-1048.232, force_y=-1002.747
# Posizione: x=-0.121, y=-0.128
# Velocità: x_vel=-0.191, y_vel=-0.094
# Forze: force_x=-1027.609, force_y=-510.677
# Posizione: x=-0.123, y=-0.129
# Velocità: x_vel=-0.118, y_vel=-0.064
# Forze: force_x=-861.740, force_y=-460.509
# Posizione: x=-0.124, y=-0.129
# Velocità: x_vel=-0.233, y_vel=-0.187
# Forze: force_x=-1241.638, force_y=-993.919
# Posizione: x=-0.127, y=-0.131
# Velocità: x_vel=-0.153, y_vel=-0.210
# Forze: force_x=-826.995, force_y=-1123.377
# Posizione: x=-0.128, y=-0.133
# Velocità: x_vel=-0.177, y_vel=-0.236
# Forze: force_x=-950.121, force_y=-1264.167
# Posizione: x=-0.130, y=-0.136
# Velocità: x_vel=-0.174, y_vel=-0.188
# Forze: force_x=-933.453, force_y=-1015.116
# Posizione: x=-0.132, y=-0.138
# Velocità: x_vel=-0.120, y_vel=-0.135
# Forze: force_x=-1036.541, force_y=-1146.709
# Posizione: x=-0.133, y=-0.139
# Velocità: x_vel=-0.415, y_vel=-0.169
# Forze: force_x=-2203.300, force_y=-903.158
# Posizione: x=-0.137, y=-0.141
# Velocità: x_vel=-0.245, y_vel=-0.222
# Forze: force_x=-1329.027, force_y=-1185.264
# Posizione: x=-0.139, y=-0.143
# Velocità: x_vel=-0.140, y_vel=-0.201
# Forze: force_x=-758.575, force_y=-1082.614
# Posizione: x=-0.141, y=-0.145
# Velocità: x_vel=-0.263, y_vel=-0.142
# Forze: force_x=-1871.611, force_y=-1027.040
# Posizione: x=-0.144, y=-0.146
# Velocità: x_vel=-0.149, y_vel=-0.304
# Forze: force_x=-809.100, force_y=-1616.254
# Posizione: x=-0.145, y=-0.149
# Velocità: x_vel=-0.230, y_vel=-0.186
# Forze: force_x=-1229.668, force_y=-1011.322
# Posizione: x=-0.147, y=-0.151
# Velocità: x_vel=-0.126, y_vel=-0.102
# Forze: force_x=-685.302, force_y=-555.932
# Posizione: x=-0.149, y=-0.152
# Velocità: x_vel=-0.225, y_vel=-0.278
# Forze: force_x=-1200.759, force_y=-1478.903
# Posizione: x=-0.151, y=-0.155
# Velocità: x_vel=-0.181, y_vel=-0.123
# Forze: force_x=-1545.719, force_y=-1071.771
# Posizione: x=-0.153, y=-0.156
# Velocità: x_vel=-0.025, y_vel=-0.292
# Forze: force_x=-219.450, force_y=-2032.626
# Posizione: x=-0.153, y=-0.159
# Velocità: x_vel=-0.256, y_vel=-0.254
# Forze: force_x=-1353.499, force_y=-1369.066
# Posizione: x=-0.155, y=-0.162
# Velocità: x_vel=-0.316, y_vel=-0.090
# Forze: force_x=-1692.488, force_y=-498.182
# Posizione: x=-0.159, y=-0.163
# Velocità: x_vel=-0.090, y_vel=-0.134
# Forze: force_x=-823.946, force_y=-1111.565
# Posizione: x=-0.159, y=-0.164
# Velocità: x_vel=-0.170, y_vel=-0.271
# Forze: force_x=-903.936, force_y=-1444.021
# Posizione: x=-0.161, y=-0.167
# Velocità: x_vel=-0.255, y_vel=-0.086
# Forze: force_x=-1817.803, force_y=-651.413
# Posizione: x=-0.164, y=-0.167
# Velocità: x_vel=-0.127, y_vel=-0.106
# Forze: force_x=-940.527, force_y=-748.926
# Posizione: x=-0.165, y=-0.168
# Velocità: x_vel=-0.270, y_vel=-0.079
# Forze: force_x=-1437.208, force_y=-427.258
# Posizione: x=-0.168, y=-0.169
# Velocità: x_vel=-0.132, y_vel=-0.128
# Forze: force_x=-1158.164, force_y=-1058.906
# Posizione: x=-0.169, y=-0.171
# Velocità: x_vel=-0.099, y_vel=-0.218
# Forze: force_x=-535.970, force_y=-1163.546
# Posizione: x=-0.170, y=-0.173
# Velocità: x_vel=-0.026, y_vel=-0.281
# Forze: force_x=-143.707, force_y=-1504.766
# Posizione: x=-0.170, y=-0.176
# Velocità: x_vel=-0.121, y_vel=-0.131
# Forze: force_x=-642.276, force_y=-716.772
# Posizione: x=-0.171, y=-0.177
# Velocità: x_vel=-0.237, y_vel=-0.098
# Forze: force_x=-1263.382, force_y=-528.972
# Posizione: x=-0.174, y=-0.178
# Velocità: x_vel=-0.185, y_vel=-0.301
# Forze: force_x=-998.817, force_y=-1596.653
# Posizione: x=-0.176, y=-0.181
# Velocità: x_vel=-0.238, y_vel=-0.215
# Forze: force_x=-1271.148, force_y=-1161.513
# Posizione: x=-0.178, y=-0.183
# Velocità: x_vel=-0.109, y_vel=-0.110
# Forze: force_x=-810.093, force_y=-803.554
# Posizione: x=-0.179, y=-0.184
# Velocità: x_vel=-0.271, y_vel=-0.288
# Forze: force_x=-1439.192, force_y=-1531.290
# Posizione: x=-0.182, y=-0.187
# Velocità: x_vel=-0.111, y_vel=-0.181
# Forze: force_x=-835.708, force_y=-1301.472
# Posizione: x=-0.183, y=-0.189
# Velocità: x_vel=-0.061, y_vel=-0.131
# Forze: force_x=-333.615, force_y=-706.036
# Posizione: x=-0.184, y=-0.190
# Velocità: x_vel=-0.090, y_vel=-0.005
# Forze: force_x=-642.213, force_y=-64.716
# Posizione: x=-0.185, y=-0.190
# Velocità: x_vel=-0.187, y_vel=-0.026
# Forze: force_x=-993.328, force_y=-137.456
# Posizione: x=-0.186, y=-0.190
# Velocità: x_vel=-0.262, y_vel=-0.410
# Forze: force_x=-1398.155, force_y=-2164.200
# Posizione: x=-0.189, y=-0.195
# Velocità: x_vel=-0.183, y_vel=-0.155
# Forze: force_x=-990.578, force_y=-854.750
# Posizione: x=-0.191, y=-0.196
# Velocità: x_vel=-0.272, y_vel=0.011
# Forze: force_x=-1449.861, force_y=44.609
# Posizione: x=-0.194, y=-0.196
# Velocità: x_vel=-0.266, y_vel=-0.288
# Forze: force_x=-1428.255, force_y=-1520.284
# Posizione: x=-0.196, y=-0.199
# Velocità: x_vel=-0.510, y_vel=-0.075
# Forze: force_x=-2715.302, force_y=-422.382
# Posizione: x=-0.201, y=-0.200
# Velocità: x_vel=-0.192, y_vel=-0.325
# Forze: force_x=-1058.073, force_y=-1723.501
# Posizione: x=-0.203, y=-0.203
# Velocità: x_vel=-0.115, y_vel=-0.043
# Forze: force_x=-838.880, force_y=-362.690
# Posizione: x=-0.204, y=-0.203
# Velocità: x_vel=-0.159, y_vel=-0.333
# ...
# Posizione: x=0.199, y=0.180
# Velocità: x_vel=-0.025, y_vel=0.190
# Forze: force_x=-108.791, force_y=1033.786
# Posizione: x=0.199, y=0.182
# Velocità: x_vel=0.170, y_vel=0.261
# Forze: force_x=895.337, force_y=1396.456
# Posizione: x=0.201, y=0.184
# Velocità: x_vel=0.071, y_vel=0.130
# Forze: force_x=390.288, force_y=707.977
# Posizione: x=0.202, y=0.186
# Velocità: x_vel=0.165, y_vel=0.218
# Forze: force_x=878.191, force_y=1161.169
# Posizione: x=0.203, y=0.188
# Velocità: x_vel=0.130, y_vel=0.115
# Forze: force_x=702.449, force_y=627.459
# Posizione: x=0.205, y=0.189
# Velocità: x_vel=0.154, y_vel=0.053
# Forze: force_x=826.176, force_y=290.317
# Posizione: x=0.206, y=0.190
# Velocità: x_vel=0.245, y_vel=0.317
# Forze: force_x=1306.069, force_y=1680.201
# Posizione: x=0.209, y=0.193
# Velocità: x_vel=0.091, y_vel=0.160
# Forze: force_x=502.284, force_y=873.819
# Posizione: x=0.209, y=0.194
# Velocità: x_vel=0.084, y_vel=0.195
# Forze: force_x=588.850, force_y=1371.614
# Posizione: x=0.210, y=0.196
# Velocità: x_vel=0.059, y_vel=0.337
# Forze: force_x=320.894, force_y=1798.867
# Posizione: x=0.211, y=0.200
# Velocità: x_vel=0.200, y_vel=0.188
# Forze: force_x=1061.049, force_y=1020.745
# Posizione: x=0.213, y=0.201
# Velocità: x_vel=0.228, y_vel=0.052
# Forze: force_x=1224.272, force_y=292.551
# Posizione: x=0.215, y=0.202
# Velocità: x_vel=0.156, y_vel=0.347
# Forze: force_x=845.955, force_y=1836.747
# Posizione: x=0.217, y=0.205
# Velocità: x_vel=0.176, y_vel=0.214
# Forze: force_x=943.123, force_y=1160.748
# Posizione: x=0.218, y=0.208
# Velocità: x_vel=0.081, y_vel=-0.004
# Forze: force_x=594.223, force_y=0.215
# Posizione: x=0.219, y=0.208
# Velocità: x_vel=0.177, y_vel=0.070
# Forze: force_x=1242.704, force_y=472.349
# Posizione: x=0.221, y=0.208
# Velocità: x_vel=0.225, y_vel=0.186
# Forze: force_x=1202.786, force_y=990.187
# Posizione: x=0.223, y=0.210
# Velocità: x_vel=0.282, y_vel=0.194
# Forze: force_x=1510.998, force_y=1038.208
# Posizione: x=0.226, y=0.212
# Velocità: x_vel=0.098, y_vel=0.250
# Forze: force_x=541.219, force_y=1335.320
# Posizione: x=0.227, y=0.215
# Velocità: x_vel=0.268, y_vel=0.230
# Forze: force_x=1423.683, force_y=1234.073
# Posizione: x=0.230, y=0.217
# Velocità: x_vel=0.004, y_vel=0.125
# Forze: force_x=43.420, force_y=680.013
# Posizione: x=0.230, y=0.218
# Velocità: x_vel=0.240, y_vel=0.155
# Forze: force_x=1268.326, force_y=830.259
# Posizione: x=0.232, y=0.220
# Velocità: x_vel=0.055, y_vel=0.176
# Forze: force_x=409.443, force_y=1243.872
# Posizione: x=0.233, y=0.221
# Velocità: x_vel=0.168, y_vel=0.136
# Forze: force_x=892.732, force_y=732.366
# Posizione: x=0.234, y=0.223
# Velocità: x_vel=0.189, y_vel=0.166
# Forze: force_x=1330.543, force_y=1158.217
# Posizione: x=0.236, y=0.224
# Velocità: x_vel=0.216, y_vel=0.241
# Forze: force_x=1157.172, force_y=1289.091
# Posizione: x=0.239, y=0.227
# Velocità: x_vel=0.284, y_vel=0.188
# Forze: force_x=1516.273, force_y=1016.083
# Posizione: x=0.241, y=0.229
# Velocità: x_vel=0.297, y_vel=0.250
# Forze: force_x=1593.087, force_y=1334.812
# Posizione: x=0.244, y=0.231
# Velocità: x_vel=0.288, y_vel=0.231
# Forze: force_x=1546.067, force_y=1243.291
# Posizione: x=0.247, y=0.234
# Velocità: x_vel=0.130, y_vel=0.259
# Forze: force_x=709.631, force_y=1386.201
# Posizione: x=0.248, y=0.236
# Velocità: x_vel=0.310, y_vel=0.122
# Forze: force_x=1649.630, force_y=668.071
# Posizione: x=0.252, y=0.237
# Velocità: x_vel=0.131, y_vel=0.249
# Forze: force_x=947.968, force_y=1743.359
# Posizione: x=0.253, y=0.240
# Velocità: x_vel=0.099, y_vel=0.111
# Forze: force_x=700.771, force_y=804.208
# Posizione: x=0.254, y=0.241
# Velocità: x_vel=0.220, y_vel=0.337
# Forze: force_x=1168.487, force_y=1791.106
# Posizione: x=0.256, y=0.244
# Velocità: x_vel=0.277, y_vel=0.201
# Forze: force_x=1481.591, force_y=1090.422
# Posizione: x=0.259, y=0.246
# Velocità: x_vel=0.083, y_vel=0.276
# Forze: force_x=460.373, force_y=1475.736
# Posizione: x=0.260, y=0.249
# Velocità: x_vel=0.157, y_vel=0.248
# Forze: force_x=837.679, force_y=1336.202
# Posizione: x=0.261, y=0.252
# Velocità: x_vel=0.111, y_vel=0.256
# Forze: force_x=598.627, force_y=1375.773
# Posizione: x=0.262, y=0.254
# Velocità: x_vel=0.221, y_vel=0.301
# Forze: force_x=1174.739, force_y=1611.906
# Posizione: x=0.265, y=0.257
# Velocità: x_vel=0.019, y_vel=0.038
# Forze: force_x=120.911, force_y=225.571
# Posizione: x=0.265, y=0.258
# Velocità: x_vel=0.282, y_vel=0.234
# Forze: force_x=1491.942, force_y=1238.066
# Posizione: x=0.268, y=0.260
# Velocità: x_vel=0.202, y_vel=0.044
# Forze: force_x=1094.160, force_y=251.432
# Posizione: x=0.270, y=0.260
# Velocità: x_vel=0.357, y_vel=0.199
# Forze: force_x=1902.249, force_y=1052.912
# Posizione: x=0.273, y=0.262
# Velocità: x_vel=0.211, y_vel=0.121
# Forze: force_x=1517.014, force_y=857.514
# Posizione: x=0.275, y=0.264
# Velocità: x_vel=0.372, y_vel=0.256
# Forze: force_x=1982.655, force_y=1360.829
# Posizione: x=0.279, y=0.266
# Velocità: x_vel=0.102, y_vel=0.248
# Forze: force_x=753.777, force_y=1761.798
# Posizione: x=0.280, y=0.269
# Velocità: x_vel=0.314, y_vel=0.148
# Forze: force_x=1669.080, force_y=800.482
# Posizione: x=0.283, y=0.270
# Velocità: x_vel=0.328, y_vel=0.200
# Forze: force_x=1758.064, force_y=1071.278
# Posizione: x=0.286, y=0.272
# Velocità: x_vel=0.141, y_vel=0.198
# Forze: force_x=773.562, force_y=1061.726
# Posizione: x=0.288, y=0.274
# Velocità: x_vel=0.277, y_vel=0.265
# Forze: force_x=1476.536, force_y=1414.600
# Posizione: x=0.291, y=0.277
# Velocità: x_vel=0.186, y_vel=0.205
# Forze: force_x=1006.149, force_y=1106.667
# Posizione: x=0.292, y=0.279
# Velocità: x_vel=0.146, y_vel=0.248
# Forze: force_x=789.677, force_y=1329.872
# Posizione: x=0.294, y=0.281
# Velocità: x_vel=0.157, y_vel=0.351
# Forze: force_x=841.460, force_y=1874.961
# Posizione: x=0.296, y=0.285
# Velocità: x_vel=0.191, y_vel=0.240
# Forze: force_x=1024.220, force_y=1296.461
# Posizione: x=0.297, y=0.287
# Velocità: x_vel=0.257, y_vel=0.116
# Forze: force_x=1804.813, force_y=833.950
# Rimbalzo su lato verticale: x=0.300, v_x=0.257
# Posizione: x=0.300, y=0.288
# Velocità: x_vel=-0.196, y_vel=0.020
# Forze: force_x=-1011.039, force_y=115.007
# Posizione: x=0.298, y=0.288
# Velocità: x_vel=-0.208, y_vel=0.266
# Forze: force_x=-1494.309, force_y=1871.310
# Posizione: x=0.296, y=0.291
# Velocità: x_vel=-0.303, y_vel=0.295
# Forze: force_x=-1617.320, force_y=1583.764
# Posizione: x=0.293, y=0.294
# Velocità: x_vel=-0.199, y_vel=0.077
# Forze: force_x=-1436.800, force_y=602.603
# Posizione: x=0.291, y=0.295
# Velocità: x_vel=-0.150, y_vel=0.151
# Forze: force_x=-809.163, force_y=805.105
# Posizione: x=0.289, y=0.296
# Velocità: x_vel=-0.189, y_vel=0.224
# Forze: force_x=-1013.697, force_y=1194.641
# Posizione: x=0.288, y=0.299
# Velocità: x_vel=-0.127, y_vel=0.189
# Forze: force_x=-929.986, force_y=1362.449
# Rimbalzo su lato orizzontale: y=0.300, v_y=0.189
# Posizione: x=0.286, y=0.300
# Velocità: x_vel=-0.179, y_vel=-0.036
# Forze: force_x=-958.300, force_y=-172.948
# Rimbalzo su lato orizzontale: y=0.300, v_y=-0.036
# Posizione: x=0.284, y=0.300
# Velocità: x_vel=-0.056, y_vel=0.300
# Forze: force_x=-312.680, force_y=1579.918
# Rimbalzo su lato orizzontale: y=0.303, v_y=0.300
# Posizione: x=0.284, y=0.303
# Velocità: x_vel=-0.181, y_vel=-0.182
# Forze: force_x=-1254.050, force_y=-1203.781
# Rimbalzo su lato orizzontale: y=0.301, v_y=-0.182
# Posizione: x=0.282, y=0.301
# Velocità: x_vel=-0.053, y_vel=0.251
# Forze: force_x=-296.674, force_y=1308.152
# Rimbalzo su lato orizzontale: y=0.304, v_y=0.251
# Posizione: x=0.282, y=0.304
# Velocità: x_vel=-0.263, y_vel=-0.136
# Forze: force_x=-1392.675, force_y=-693.632
# Rimbalzo su lato orizzontale: y=0.302, v_y=-0.136
# Posizione: x=0.279, y=0.302
# Velocità: x_vel=-0.087, y_vel=0.247
# Forze: force_x=-484.794, force_y=1292.773
# Rimbalzo su lato orizzontale: y=0.305, v_y=0.247
# Posizione: x=0.278, y=0.305
# Velocità: x_vel=-0.286, y_vel=-0.189
# Forze: force_x=-1519.098, force_y=-974.015
# Rimbalzo su lato orizzontale: y=0.303, v_y=-0.189
# Posizione: x=0.275, y=0.303
# Velocità: x_vel=-0.143, y_vel=0.159
# Forze: force_x=-779.489, force_y=824.831
# Rimbalzo su lato orizzontale: y=0.305, v_y=0.159
# Posizione: x=0.274, y=0.305
# Velocità: x_vel=-0.015, y_vel=-0.178
# Forze: force_x=-145.157, force_y=-1412.270
# Rimbalzo su lato orizzontale: y=0.303, v_y=-0.178
# Posizione: x=0.274, y=0.303
# Velocità: x_vel=-0.150, y_vel=0.234
# Forze: force_x=-795.623, force_y=1221.172
# Rimbalzo su lato orizzontale: y=0.305, v_y=0.234
# Posizione: x=0.272, y=0.305
# Velocità: x_vel=-0.156, y_vel=-0.283
# Forze: force_x=-838.127, force_y=-1472.319
# Rimbalzo su lato orizzontale: y=0.302, v_y=-0.283
# Posizione: x=0.271, y=0.302
# Velocità: x_vel=-0.126, y_vel=-0.090
# Forze: force_x=-679.459, force_y=-500.422
# Rimbalzo su lato orizzontale: y=0.301, v_y=-0.090
# Posizione: x=0.269, y=0.301
# Velocità: x_vel=-0.133, y_vel=-0.107
# Forze: force_x=-713.487, force_y=-573.582
# Rimbalzo su lato orizzontale: y=0.300, v_y=-0.107
# Posizione: x=0.268, y=0.300
# Velocità: x_vel=-0.045, y_vel=0.272
# Forze: force_x=-249.272, force_y=1423.742
# Rimbalzo su lato orizzontale: y=0.303, v_y=0.272
# Posizione: x=0.268, y=0.303
# Velocità: x_vel=-0.161, y_vel=-0.266
# Forze: force_x=-1103.645, force_y=-1791.668
# Rimbalzo su lato orizzontale: y=0.300, v_y=-0.266
# Posizione: x=0.266, y=0.300
# Velocità: x_vel=-0.241, y_vel=0.116
# Forze: force_x=-1708.279, force_y=778.591
# Rimbalzo su lato orizzontale: y=0.302, v_y=0.116
# Posizione: x=0.264, y=0.302
# Velocità: x_vel=-0.245, y_vel=-0.217
# Forze: force_x=-1312.437, force_y=-1136.830
# Posizione: x=0.261, y=0.299
# Velocità: x_vel=-0.255, y_vel=-0.203
# Forze: force_x=-1367.441, force_y=-1089.197
# Posizione: x=0.259, y=0.297
# Velocità: x_vel=-0.137, y_vel=-0.164
# Forze: force_x=-746.076, force_y=-881.834
# Posizione: x=0.257, y=0.296
# Velocità: x_vel=-0.050, y_vel=-0.233
# Forze: force_x=-278.441, force_y=-1245.953
# Posizione: x=0.257, y=0.293
# Velocità: x_vel=-0.164, y_vel=-0.179
# Forze: force_x=-872.473, force_y=-966.476
# Posizione: x=0.255, y=0.292
# Velocità: x_vel=-0.300, y_vel=-0.206
# Forze: force_x=-1600.384, force_y=-1105.853
# Posizione: x=0.252, y=0.290
# Velocità: x_vel=-0.178, y_vel=-0.183
# Forze: force_x=-1274.160, force_y=-1293.749
# Posizione: x=0.250, y=0.288
# Velocità: x_vel=-0.116, y_vel=-0.191
# Forze: force_x=-628.768, force_y=-1026.420
# Posizione: x=0.249, y=0.286
# Velocità: x_vel=-0.056, y_vel=0.025
# Forze: force_x=-307.670, force_y=115.142
# Posizione: x=0.249, y=0.286
# Velocità: x_vel=-0.210, y_vel=-0.137
# Forze: force_x=-1113.653, force_y=-718.703
# Posizione: x=0.246, y=0.285
# Velocità: x_vel=-0.156, y_vel=-0.228
# Forze: force_x=-840.181, force_y=-1214.046
# Posizione: x=0.245, y=0.282
# Velocità: x_vel=-0.169, y_vel=-0.115
# Forze: force_x=-1195.822, force_y=-826.377
# Posizione: x=0.243, y=0.281
# Velocità: x_vel=-0.195, y_vel=-0.197
# Forze: force_x=-1046.513, force_y=-1048.633
# Posizione: x=0.241, y=0.279
# Velocità: x_vel=-0.087, y_vel=-0.128
# Forze: force_x=-743.703, force_y=-1085.338
# Posizione: x=0.240, y=0.278
# Velocità: x_vel=-0.151, y_vel=-0.173
# Forze: force_x=-1053.328, force_y=-1211.663
# Posizione: x=0.239, y=0.276
# Velocità: x_vel=-0.341, y_vel=-0.185
# Forze: force_x=-2383.761, force_y=-1293.559
# Posizione: x=0.235, y=0.274
# Velocità: x_vel=-0.173, y_vel=-0.275
# Forze: force_x=-1241.543, force_y=-1928.229
# Posizione: x=0.234, y=0.272
# Velocità: x_vel=-0.177, y_vel=-0.298
# Forze: force_x=-947.567, force_y=-1599.647
# Posizione: x=0.232, y=0.269
# Velocità: x_vel=-0.020, y_vel=-0.102
# Forze: force_x=-123.643, force_y=-563.717
# Posizione: x=0.232, y=0.268
# Velocità: x_vel=-0.117, y_vel=-0.143
# Forze: force_x=-620.951, force_y=-765.096
# Posizione: x=0.231, y=0.266
# Velocità: x_vel=-0.158, y_vel=-0.126
# Forze: force_x=-1110.815, force_y=-890.051
# Posizione: x=0.229, y=0.265
# Velocità: x_vel=-0.127, y_vel=-0.198
# Forze: force_x=-685.003, force_y=-1055.816
# Posizione: x=0.228, y=0.263
# Velocità: x_vel=-0.180, y_vel=-0.050
# Forze: force_x=-964.125, force_y=-284.063
# Posizione: x=0.226, y=0.263
# Velocità: x_vel=-0.284, y_vel=-0.324
# Forze: force_x=-1512.812, force_y=-1712.463
# Posizione: x=0.223, y=0.259
# Velocità: x_vel=-0.167, y_vel=-0.050
# Forze: force_x=-1205.907, force_y=-392.479
# Posizione: x=0.221, y=0.259
# Velocità: x_vel=-0.028, y_vel=-0.224
# Forze: force_x=-163.739, force_y=-1189.224
# Posizione: x=0.221, y=0.257
# Velocità: x_vel=-0.232, y_vel=-0.141
# Forze: force_x=-1225.077, force_y=-763.932
# Posizione: x=0.219, y=0.255
# Velocità: x_vel=-0.269, y_vel=-0.040
# Forze: force_x=-1440.707, force_y=-221.976
# Posizione: x=0.216, y=0.255
# Velocità: x_vel=-0.077, y_vel=0.012
# Forze: force_x=-432.797, force_y=60.493
# Posizione: x=0.215, y=0.255
# Velocità: x_vel=-0.105, y_vel=-0.152
# Forze: force_x=-737.324, force_y=-1044.909
# Posizione: x=0.214, y=0.253
# Velocità: x_vel=-0.254, y_vel=-0.273
# Forze: force_x=-1347.593, force_y=-1454.401
# Posizione: x=0.212, y=0.251
# Velocità: x_vel=-0.188, y_vel=-0.241
# Forze: force_x=-1017.614, force_y=-1294.670
# Posizione: x=0.210, y=0.248
# Velocità: x_vel=-0.193, y_vel=-0.099
# Forze: force_x=-1035.177, force_y=-546.330
# Posizione: x=0.208, y=0.247
# Velocità: x_vel=-0.216, y_vel=-0.148
# Forze: force_x=-1525.767, force_y=-1030.729
# Posizione: x=0.206, y=0.246
# Velocità: x_vel=-0.144, y_vel=-0.160
# Forze: force_x=-779.249, force_y=-857.001
# Posizione: x=0.204, y=0.244
# Velocità: x_vel=-0.066, y_vel=-0.277
# Forze: force_x=-358.625, force_y=-1474.510
# Posizione: x=0.204, y=0.241
# Velocità: x_vel=-0.193, y_vel=-0.112
# Forze: force_x=-1024.938, force_y=-615.038
# Posizione: x=0.202, y=0.240
# Velocità: x_vel=-0.272, y_vel=-0.160
# Forze: force_x=-1452.246, force_y=-857.001
# Posizione: x=0.199, y=0.239
# Velocità: x_vel=-0.335, y_vel=-0.104
# Forze: force_x=-1794.906, force_y=-562.306
# Posizione: x=0.196, y=0.238
# Velocità: x_vel=0.002, y_vel=-0.143
# Forze: force_x=-16.627, force_y=-765.049
# Posizione: x=0.196, y=0.236
# Velocità: x_vel=-0.219, y_vel=-0.246
# Forze: force_x=-1506.882, force_y=-1715.464
# Posizione: x=0.194, y=0.234
# Velocità: x_vel=-0.283, y_vel=-0.163
# Forze: force_x=-1514.506, force_y=-882.437
# Posizione: x=0.191, y=0.232
# Velocità: x_vel=-0.071, y_vel=-0.057
# Forze: force_x=-399.548, force_y=-313.743
# Posizione: x=0.190, y=0.232
# Velocità: x_vel=-0.213, y_vel=-0.146
# Forze: force_x=-1486.444, force_y=-1005.497
# Posizione: x=0.188, y=0.230
# Velocità: x_vel=-0.081, y_vel=-0.283
# Forze: force_x=-446.128, force_y=-1505.898
# Posizione: x=0.187, y=0.227
# Velocità: x_vel=-0.285, y_vel=-0.265
# Forze: force_x=-1514.466, force_y=-1422.281
# Posizione: x=0.184, y=0.225
# Velocità: x_vel=-0.170, y_vel=-0.172
# Forze: force_x=-924.544, force_y=-930.239
# Posizione: x=0.182, y=0.223
# Velocità: x_vel=-0.158, y_vel=-0.124
# Forze: force_x=-851.862, force_y=-668.501
# Posizione: x=0.181, y=0.222
# Velocità: x_vel=-0.126, y_vel=-0.024
# Forze: force_x=-907.290, force_y=-178.809
# Posizione: x=0.180, y=0.221
# Velocità: x_vel=-0.186, y_vel=-0.177
# Forze: force_x=-994.116, force_y=-935.076
# Posizione: x=0.178, y=0.220
# Velocità: x_vel=-0.106, y_vel=-0.209
# Forze: force_x=-576.331, force_y=-1121.699
# Posizione: x=0.177, y=0.218
# Velocità: x_vel=-0.225, y_vel=-0.061
# Forze: force_x=-1197.490, force_y=-342.377
# Posizione: x=0.174, y=0.217
# Velocità: x_vel=-0.383, y_vel=-0.180
# Forze: force_x=-2039.888, force_y=-954.296
# Posizione: x=0.171, y=0.215
# Velocità: x_vel=-0.083, y_vel=-0.204
# Forze: force_x=-634.363, force_y=-1433.216
# Posizione: x=0.170, y=0.213
# Velocità: x_vel=-0.182, y_vel=-0.100
# Forze: force_x=-967.659, force_y=-544.927
# Posizione: x=0.168, y=0.212
# Velocità: x_vel=-0.142, y_vel=-0.331
# Forze: force_x=-764.265, force_y=-1755.028
# Posizione: x=0.167, y=0.209
# Velocità: x_vel=-0.217, y_vel=-0.242
# Forze: force_x=-1157.257, force_y=-1306.140
# Posizione: x=0.164, y=0.206
# Velocità: x_vel=-0.163, y_vel=-0.345
# Forze: force_x=-881.565, force_y=-1840.886
# Posizione: x=0.163, y=0.203
# Velocità: x_vel=-0.127, y_vel=-0.316
# Forze: force_x=-684.264, force_y=-1696.908
# Posizione: x=0.161, y=0.200
# Velocità: x_vel=-0.123, y_vel=-0.326
# Forze: force_x=-658.178, force_y=-1750.466
# Frames salvati per l'autoencoder: (1614, 64, 64, 3)
# Si è verificato un arresto anomalo del Kernel durante l'esecuzione del codice nella cella attiva o in una cella precedente.
#
# Esaminare il codice nelle celle per identificare una possibile causa dell'errore.
#
# Per altre informazioni, fare clic<a href='https://aka.ms/vscodeJupyterKernelCrash'>qui</a>.
#
# Per ulteriori dettagli, visualizzare Jupyter <a href='command:jupyter.viewOutput'>log</a>.
