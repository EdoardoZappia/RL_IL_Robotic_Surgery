# %%
import mujoco
import glfw
import numpy as np
import time
from PIL import Image

XML_FILE_PATH = "/Users/edoardozappia/Desktop/Tesi_Magistrale/irregular_shape_2D_online.xml"

def main():

    dt = 0.01
    side_length = 0.6  # Lunghezza del lato del quadrato
    half_side = side_length / 2  # Metà lato (limiti del quadrato)
    alpha_x = 1
    alpha_y = 1
    beta_x = 0
    beta_y = 0
    std_x = 0.0    #std for gaussian noise on direction change and velocity. If 0.0 velocity is opposite
    std_y = 0.0    #std for gaussian noise on direction change and velocity. If 0.0 velocity is opposite

    if not glfw.init():
        print("Impossibile inizializzare GLFW")
        return

    glfw.window_hint(glfw.VISIBLE, glfw.TRUE)
    window = glfw.create_window(800, 800, "MuJoCo Viewer", None, None)
    if not window:
        print("Errore durante la creazione della finestra GLFW")
        glfw.terminate()
        return

    glfw.make_context_current(window)

    model = mujoco.MjModel.from_xml_path(XML_FILE_PATH)
    data = mujoco.MjData(model)

    # Configura la telecamera
    camera = mujoco.MjvCamera()
    camera.type = mujoco.mjtCamera.mjCAMERA_FREE
    camera.lookat = np.array([0, 0, 0])
    camera.distance = 2.0
    camera.azimuth = 90
    camera.elevation = -90

    # Renderer per visualizzare la finestra
    scene = mujoco.MjvScene(model, maxgeom=1000)
    context = mujoco.MjrContext(model, mujoco.mjtFontScale.mjFONTSCALE_150)

    t = 0  # Tempo iniziale
    
    positions = []

    while not glfw.window_should_close(window):

        t += dt

        # Posizione attuale
        x = data.qpos[3]
        y = data.qpos[4]

        # Salva la posizione corrente
        positions.append([x, y])

        # Rileva collisioni con i lati del quadrato
        if x >= half_side or x <= -half_side:
            alpha_x *= np.random.normal(-1, std_x)  # Inverti velocità lungo x
            print(f"Rimbalzo su lato verticale: x={x:.3f}, v_x={data.qvel[0]:.3f}")

        if y >= half_side or y <= -half_side:
            alpha_y *= np.random.normal(-1, std_y)  # Inverti velocità lungo y
            print(f"Rimbalzo su lato orizzontale: y={y:.3f}, v_y={data.qvel[1]:.3f}")

        # Calcola forze basate sulle velocità
        force_x = alpha_x * 150 + beta_x * np.random.normal(1, 0.5)
        force_y = alpha_y * 150 + beta_y * np.random.normal(1, 0.5)

        # Applica forze
        data.qfrc_applied[3] = force_x
        data.qfrc_applied[4] = force_y

        # Avanza la simulazione
        mujoco.mj_step(model, data)

        # Debug
        print(f"Posizione: x={x:.3f}, y={y:.3f}")
        print(f"Velocità: x_vel={data.qvel[0]:.3f}, y_vel={data.qvel[1]:.3f}")
        print(f"Forze: force_x={force_x:.3f}, force_y={force_y:.3f}")

        # Renderizza la scena
        mujoco.mjv_updateScene(model, data, mujoco.MjvOption(), None, camera, mujoco.mjtCatBit.mjCAT_ALL, scene)
        viewport_width, viewport_height = glfw.get_framebuffer_size(window)
        viewport = mujoco.MjrRect(0, 0, viewport_width, viewport_height)
        mujoco.mjr_render(viewport, scene, context)


        glfw.swap_buffers(window)
        glfw.poll_events()
        time.sleep(dt)
    
    # Salva il dataset delle posizioni target
    positions = np.array(positions)  # Converti in array NumPy
    print(f"Steps: {len(positions)}")
    #np.save(SAVE_PATH, positions)
    #print(f"Dataset delle posizioni target salvato in: {SAVE_PATH}")

    glfw.destroy_window(window)
    glfw.terminate()

if __name__ == "__main__":
    main()
# Out:
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.001, y=0.001
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.001, y=0.001
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.002, y=0.002
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.002, y=0.002
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.003, y=0.003
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.003, y=0.003
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.004, y=0.004
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.004, y=0.004
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.005, y=0.005
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.005, y=0.005
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.006, y=0.006
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.006, y=0.006
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.007, y=0.007
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.007, y=0.007
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.008, y=0.008
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.008, y=0.008
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.009, y=0.009
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.009, y=0.009
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.010, y=0.010
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.010, y=0.010
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.011, y=0.011
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.011, y=0.011
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.012, y=0.012
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.012, y=0.012
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.013, y=0.013
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.013, y=0.013
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.014, y=0.014
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.014, y=0.014
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.015, y=0.015
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.015, y=0.015
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.016, y=0.016
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.016, y=0.016
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.017, y=0.017
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.017, y=0.017
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.018, y=0.018
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.018, y=0.018
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.019, y=0.019
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.019, y=0.019
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.020, y=0.020
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.020, y=0.020
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.021, y=0.021
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.021, y=0.021
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.022, y=0.022
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.022, y=0.022
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.023, y=0.023
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.023, y=0.023
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.024, y=0.024
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.024, y=0.024
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.025, y=0.025
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.025, y=0.025
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.026, y=0.026
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.026, y=0.026
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.027, y=0.027
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.027, y=0.027
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.028, y=0.028
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.028, y=0.028
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.029, y=0.029
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.029, y=0.029
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.030, y=0.030
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.030, y=0.030
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.031, y=0.031
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.031, y=0.031
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.032, y=0.032
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.032, y=0.032
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.033, y=0.033
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.033, y=0.033
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.034, y=0.034
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.034, y=0.034
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.035, y=0.035
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.035, y=0.035
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.036, y=0.036
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.036, y=0.036
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.037, y=0.037
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.037, y=0.037
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.038, y=0.038
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.038, y=0.038
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.039, y=0.039
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.039, y=0.039
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.040, y=0.040
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.040, y=0.040
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.041, y=0.041
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.041, y=0.041
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.042, y=0.042
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.042, y=0.042
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.043, y=0.043
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.043, y=0.043
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.044, y=0.044
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.044, y=0.044
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.045, y=0.045
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.045, y=0.045
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.046, y=0.046
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.046, y=0.046
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.047, y=0.047
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.047, y=0.047
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.048, y=0.048
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.048, y=0.048
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.049, y=0.049
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.049, y=0.049
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.050, y=0.050
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.050, y=0.050
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.051, y=0.051
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.051, y=0.051
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.052, y=0.052
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.052, y=0.052
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.053, y=0.053
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.053, y=0.053
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.054, y=0.054
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.054, y=0.054
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.055, y=0.055
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.055, y=0.055
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.056, y=0.056
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.056, y=0.056
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.057, y=0.057
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.057, y=0.057
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.058, y=0.058
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.058, y=0.058
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.059, y=0.059
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.059, y=0.059
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.060, y=0.060
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.060, y=0.060
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.061, y=0.061
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.061, y=0.061
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.062, y=0.062
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.062, y=0.062
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.063, y=0.063
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.063, y=0.063
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.064, y=0.064
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.064, y=0.064
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.065, y=0.065
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.065, y=0.065
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.066, y=0.066
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.066, y=0.066
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.067, y=0.067
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.067, y=0.067
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.068, y=0.068
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.068, y=0.068
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.069, y=0.069
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.069, y=0.069
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.070, y=0.070
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.070, y=0.070
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.071, y=0.071
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.071, y=0.071
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.072, y=0.072
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.072, y=0.072
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.073, y=0.073
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.073, y=0.073
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.074, y=0.074
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.074, y=0.074
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.075, y=0.075
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.075, y=0.075
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.076, y=0.076
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.076, y=0.076
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.077, y=0.077
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.077, y=0.077
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.078, y=0.078
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.078, y=0.078
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.079, y=0.079
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.079, y=0.079
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.080, y=0.080
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.080, y=0.080
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.081, y=0.081
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.081, y=0.081
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.082, y=0.082
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.082, y=0.082
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.083, y=0.083
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.083, y=0.083
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.084, y=0.084
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.084, y=0.084
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.085, y=0.085
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.085, y=0.085
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.086, y=0.086
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.086, y=0.086
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.087, y=0.087
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.087, y=0.087
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.088, y=0.088
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.088, y=0.088
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.089, y=0.089
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.089, y=0.089
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.090, y=0.090
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.090, y=0.090
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.091, y=0.091
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.091, y=0.091
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.092, y=0.092
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.092, y=0.092
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.093, y=0.093
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.093, y=0.093
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.094, y=0.094
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.094, y=0.094
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.095, y=0.095
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.095, y=0.095
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.096, y=0.096
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.096, y=0.096
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.097, y=0.097
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.097, y=0.097
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.098, y=0.098
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.098, y=0.098
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.099, y=0.099
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.099, y=0.099
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.100, y=0.100
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.100, y=0.100
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.101, y=0.101
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.101, y=0.101
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.102, y=0.102
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.102, y=0.102
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.103, y=0.103
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.103, y=0.103
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.104, y=0.104
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.104, y=0.104
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.105, y=0.105
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.105, y=0.105
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.106, y=0.106
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.106, y=0.106
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.107, y=0.107
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.107, y=0.107
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.108, y=0.108
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.108, y=0.108
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.109, y=0.109
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.109, y=0.109
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.110, y=0.110
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.110, y=0.110
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.111, y=0.111
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.111, y=0.111
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.112, y=0.112
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.112, y=0.112
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.113, y=0.113
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.113, y=0.113
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.114, y=0.114
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.114, y=0.114
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.115, y=0.115
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.115, y=0.115
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.116, y=0.116
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.116, y=0.116
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.117, y=0.117
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.117, y=0.117
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.118, y=0.118
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.118, y=0.118
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.119, y=0.119
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.119, y=0.119
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.120, y=0.120
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.120, y=0.120
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.121, y=0.121
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.121, y=0.121
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.122, y=0.122
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.122, y=0.122
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.123, y=0.123
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.123, y=0.123
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.124, y=0.124
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.124, y=0.124
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.125, y=0.125
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.125, y=0.125
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.126, y=0.126
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.126, y=0.126
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.127, y=0.127
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.127, y=0.127
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.128, y=0.128
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.128, y=0.128
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.129, y=0.129
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.129, y=0.129
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.130, y=0.130
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.130, y=0.130
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.131, y=0.131
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.131, y=0.131
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.132, y=0.132
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.132, y=0.132
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.133, y=0.133
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.133, y=0.133
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.134, y=0.134
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.134, y=0.134
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.135, y=0.135
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.135, y=0.135
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.136, y=0.136
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.136, y=0.136
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.137, y=0.137
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.137, y=0.137
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.138, y=0.138
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.138, y=0.138
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.139, y=0.139
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.139, y=0.139
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.140, y=0.140
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.140, y=0.140
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.141, y=0.141
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.141, y=0.141
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.142, y=0.142
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.142, y=0.142
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.143, y=0.143
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.143, y=0.143
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.144, y=0.144
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.144, y=0.144
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.145, y=0.145
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.145, y=0.145
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.146, y=0.146
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.146, y=0.146
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.147, y=0.147
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.147, y=0.147
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.148, y=0.148
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.148, y=0.148
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.149, y=0.149
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.149, y=0.149
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.150, y=0.150
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.150, y=0.150
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.151, y=0.151
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.151, y=0.151
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.152, y=0.152
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.152, y=0.152
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.153, y=0.153
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.153, y=0.153
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.154, y=0.154
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.154, y=0.154
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.155, y=0.155
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.155, y=0.155
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.156, y=0.156
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.156, y=0.156
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.157, y=0.157
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.157, y=0.157
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.158, y=0.158
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.158, y=0.158
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.159, y=0.159
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.159, y=0.159
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.160, y=0.160
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.160, y=0.160
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.161, y=0.161
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.161, y=0.161
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.162, y=0.162
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.162, y=0.162
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.163, y=0.163
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.163, y=0.163
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.164, y=0.164
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.164, y=0.164
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.165, y=0.165
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.165, y=0.165
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.166, y=0.166
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.166, y=0.166
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.167, y=0.167
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.167, y=0.167
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.168, y=0.168
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.168, y=0.168
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.169, y=0.169
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.169, y=0.169
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.170, y=0.170
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.170, y=0.170
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.171, y=0.171
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.171, y=0.171
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.172, y=0.172
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.172, y=0.172
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.173, y=0.173
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.173, y=0.173
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.174, y=0.174
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.174, y=0.174
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.175, y=0.175
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.175, y=0.175
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.176, y=0.176
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.176, y=0.176
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.177, y=0.177
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.177, y=0.177
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.178, y=0.178
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.178, y=0.178
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.179, y=0.179
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.179, y=0.179
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.180, y=0.180
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.180, y=0.180
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.181, y=0.181
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.181, y=0.181
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.182, y=0.182
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.182, y=0.182
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.183, y=0.183
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.183, y=0.183
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.184, y=0.184
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.184, y=0.184
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.185, y=0.185
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.185, y=0.185
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.186, y=0.186
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.186, y=0.186
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.187, y=0.187
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.187, y=0.187
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.188, y=0.188
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.188, y=0.188
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.189, y=0.189
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.189, y=0.189
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.190, y=0.190
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.190, y=0.190
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.191, y=0.191
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.191, y=0.191
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.192, y=0.192
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.192, y=0.192
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.193, y=0.193
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.193, y=0.193
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.194, y=0.194
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.194, y=0.194
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.195, y=0.195
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.195, y=0.195
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.196, y=0.196
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.196, y=0.196
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.197, y=0.197
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.197, y=0.197
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.198, y=0.198
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.198, y=0.198
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.199, y=0.199
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.199, y=0.199
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.200, y=0.200
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.200, y=0.200
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.201, y=0.201
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.201, y=0.201
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.202, y=0.202
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.202, y=0.202
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.203, y=0.203
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.203, y=0.203
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.204, y=0.204
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.204, y=0.204
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.205, y=0.205
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.205, y=0.205
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.206, y=0.206
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.206, y=0.206
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.207, y=0.207
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.207, y=0.207
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.208, y=0.208
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.208, y=0.208
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.209, y=0.209
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.209, y=0.209
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.210, y=0.210
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.210, y=0.210
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.211, y=0.211
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.211, y=0.211
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.212, y=0.212
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.212, y=0.212
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.213, y=0.213
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.213, y=0.213
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.214, y=0.214
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.214, y=0.214
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.215, y=0.215
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.215, y=0.215
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.216, y=0.216
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.216, y=0.216
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.217, y=0.217
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.217, y=0.217
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.218, y=0.218
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.218, y=0.218
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.219, y=0.219
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.219, y=0.219
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.220, y=0.220
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.220, y=0.220
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.221, y=0.221
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.221, y=0.221
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.222, y=0.222
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.222, y=0.222
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.223, y=0.223
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.223, y=0.223
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.224, y=0.224
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.224, y=0.224
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.225, y=0.225
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.225, y=0.225
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.226, y=0.226
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.226, y=0.226
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.227, y=0.227
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.227, y=0.227
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.228, y=0.228
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.228, y=0.228
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.229, y=0.229
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.229, y=0.229
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.230, y=0.230
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.230, y=0.230
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.231, y=0.231
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.231, y=0.231
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.232, y=0.232
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.232, y=0.232
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.233, y=0.233
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# ...
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.242, y=0.242
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.242, y=0.242
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.243, y=0.243
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.243, y=0.243
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.244, y=0.244
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.244, y=0.244
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.245, y=0.245
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.245, y=0.245
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.246, y=0.246
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.246, y=0.246
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.247, y=0.247
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.247, y=0.247
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.248, y=0.248
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.248, y=0.248
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.249, y=0.249
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.249, y=0.249
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.250, y=0.250
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.250, y=0.250
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.251, y=0.251
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.251, y=0.251
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.252, y=0.252
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.252, y=0.252
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.253, y=0.253
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.253, y=0.253
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.254, y=0.254
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.254, y=0.254
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.255, y=0.255
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.255, y=0.255
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.256, y=0.256
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.256, y=0.256
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.257, y=0.257
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.257, y=0.257
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.258, y=0.258
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.258, y=0.258
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.259, y=0.259
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.259, y=0.259
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.260, y=0.260
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.260, y=0.260
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.261, y=0.261
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.261, y=0.261
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.262, y=0.262
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.262, y=0.262
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.263, y=0.263
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.263, y=0.263
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.264, y=0.264
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.264, y=0.264
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.265, y=0.265
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.265, y=0.265
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.266, y=0.266
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.266, y=0.266
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.267, y=0.267
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.267, y=0.267
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.268, y=0.268
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.268, y=0.268
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.269, y=0.269
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.269, y=0.269
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.270, y=0.270
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.270, y=0.270
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.271, y=0.271
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.271, y=0.271
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.272, y=0.272
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.272, y=0.272
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.273, y=0.273
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.273, y=0.273
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.274, y=0.274
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.274, y=0.274
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.275, y=0.275
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.275, y=0.275
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.276, y=0.276
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.276, y=0.276
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.277, y=0.277
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.277, y=0.277
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.278, y=0.278
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.278, y=0.278
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.279, y=0.279
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.279, y=0.279
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.280, y=0.280
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.280, y=0.280
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.281, y=0.281
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.281, y=0.281
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.282, y=0.282
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.282, y=0.282
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.283, y=0.283
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.283, y=0.283
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.284, y=0.284
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.284, y=0.284
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.285, y=0.285
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.285, y=0.285
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.286, y=0.286
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.286, y=0.286
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.287, y=0.287
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.287, y=0.287
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.288, y=0.288
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.288, y=0.288
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.289, y=0.289
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.289, y=0.289
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.290, y=0.290
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.290, y=0.290
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.291, y=0.291
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.291, y=0.291
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.292, y=0.292
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.292, y=0.292
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.293, y=0.293
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.293, y=0.293
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.294, y=0.294
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.294, y=0.294
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.295, y=0.295
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.295, y=0.295
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.296, y=0.296
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.296, y=0.296
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.297, y=0.297
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.297, y=0.297
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.298, y=0.298
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.298, y=0.298
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.299, y=0.299
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.299, y=0.299
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Posizione: x=0.300, y=0.300
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=150.000, force_y=150.000
# Rimbalzo su lato verticale: x=0.300, v_x=0.000
# Rimbalzo su lato orizzontale: y=0.300, v_y=0.000
# Posizione: x=0.300, y=0.300
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.299, y=0.299
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.299, y=0.299
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.298, y=0.298
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.298, y=0.298
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.297, y=0.297
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.297, y=0.297
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.296, y=0.296
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.296, y=0.296
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.295, y=0.295
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.295, y=0.295
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.294, y=0.294
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.294, y=0.294
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.293, y=0.293
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.293, y=0.293
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.292, y=0.292
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.292, y=0.292
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.291, y=0.291
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.291, y=0.291
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.290, y=0.290
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.290, y=0.290
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.289, y=0.289
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.289, y=0.289
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.288, y=0.288
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.288, y=0.288
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.287, y=0.287
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.287, y=0.287
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.286, y=0.286
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.286, y=0.286
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.285, y=0.285
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.285, y=0.285
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Posizione: x=0.284, y=0.284
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=-150.000, force_y=-150.000
# Steps: 632
# Si è verificato un arresto anomalo del Kernel durante l'esecuzione del codice nella cella attiva o in una cella precedente.
#
# Esaminare il codice nelle celle per identificare una possibile causa dell'errore.
#
# Per altre informazioni, fare clic<a href='https://aka.ms/vscodeJupyterKernelCrash'>qui</a>.
#
# Per ulteriori dettagli, visualizzare Jupyter <a href='command:jupyter.viewOutput'>log</a>.
