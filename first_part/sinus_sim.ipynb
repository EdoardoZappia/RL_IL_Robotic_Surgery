# %%
import mujoco
import glfw
import numpy as np
import time
from PIL import Image

XML_FILE_PATH = "/Users/edoardozappia/Desktop/Tesi_Magistrale/irregular_shape_2D.xml"
SAVE_PATH = "/Users/edoardozappia/Desktop/Tesi_Magistrale/target_positions_sinus.npy"

def main():

    freq_x = 0.07  # Frequenza della sinusoide lungo x
    freq_y = 0.7  # Frequenza della sinusoide lungo y
    freq_phi = 0.1  # Frequenza della sinusoide per la rotazione
    amp_x = 1000.0  # Ampiezza della sinusoide lungo x
    amp_y = 1000.0  # Ampiezza della sinusoide lungo y
    amp_phi = 1.0  # Ampiezza della sinusoide per la rotazione
    R = 0.2  # Raggio massimo della circonferenza
    dt = 0.01  # Timestep fisso
    noise = 0.0  # Rumore bianco gaussiano

    if not glfw.init():
        print("Impossibile inizializzare GLFW")
        return

    glfw.window_hint(glfw.VISIBLE, glfw.TRUE)
    window = glfw.create_window(800, 800, "MuJoCo Viewer", None, None)
    if not window:
        print("Errore durante la creazione della finestra GLFW")
        glfw.terminate()
        return

    glfw.make_context_current(window)

    model = mujoco.MjModel.from_xml_path(XML_FILE_PATH)
    data = mujoco.MjData(model)

    # Configura la telecamera
    camera = mujoco.MjvCamera()
    camera.type = mujoco.mjtCamera.mjCAMERA_FREE
    camera.lookat = np.array([0, 0, 0])
    camera.distance = 2.0
    camera.azimuth = 90
    camera.elevation = -90

    # Renderer per visualizzare la finestra
    scene = mujoco.MjvScene(model, maxgeom=1000)
    context = mujoco.MjrContext(model, mujoco.mjtFontScale.mjFONTSCALE_150)

    t = 0  # Tempo iniziale
    
    positions = []

    while not glfw.window_should_close(window):

        t += dt

        # Posizione attuale
        x = data.qpos[0]
        y = data.qpos[1]

        force_x = 0
        force_y = 0
        torque_phi = 0

        if t >= 1.64:
            # Salva la posizione corrente
            positions.append([x, y])


            # Forze sinusoidali
            force_x = amp_x * np.sin(2 * np.pi * freq_x * t) + noise * np.random.randn()
            force_y = amp_y * np.cos(2 * np.pi * freq_y * t) + noise * np.random.randn()

            # Momento sinusoidale
            torque_phi = amp_phi * np.sin(2 * np.pi * freq_phi * t) + noise * np.random.randn()

        # Controlla che l'oggetto rimanga dentro la circonferenza
        #distance = np.sqrt(data.qpos[0] ** 2 + data.qpos[1] ** 2)
        #if distance >= R:
            # Forza di rimbalzo verso il centro
        #    direction_x = -data.qpos[0] / distance
        #    direction_y = -data.qpos[1] / distance
        #    force_x += direction_x * 1000.0
        #    force_y += direction_y * 1000.0

        # Applica le forze e i momenti
        data.qfrc_applied[0] = force_x
        data.qfrc_applied[1] = force_y
        data.qfrc_applied[2] = torque_phi

        # Avanza la simulazione
        mujoco.mj_step(model, data)

        # Debug
        print(f"Posizione: x={x:.3f}, y={y:.3f}")
        print(f"Velocità: x_vel={data.qvel[0]:.3f}, y_vel={data.qvel[1]:.3f}")
        print(f"Forze: force_x={force_x:.3f}, force_y={force_y:.3f}")

        # Renderizza la scena
        mujoco.mjv_updateScene(model, data, mujoco.MjvOption(), None, camera, mujoco.mjtCatBit.mjCAT_ALL, scene)
        viewport_width, viewport_height = glfw.get_framebuffer_size(window)
        viewport = mujoco.MjrRect(0, 0, viewport_width, viewport_height)
        mujoco.mjr_render(viewport, scene, context)


        glfw.swap_buffers(window)
        glfw.poll_events()
        time.sleep(dt)
    
    # Salva il dataset delle posizioni target
    positions = np.array(positions)  # Converti in array NumPy
    print(f"Steps: {len(positions)}")
    np.save(SAVE_PATH, positions)
    print(f"Dataset delle posizioni target salvato in: {SAVE_PATH}")

    glfw.destroy_window(window)
    glfw.terminate()

if __name__ == "__main__":
    main()
# Out:
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.000, y_vel=0.000
# Forze: force_x=0.000, force_y=0.000
# Posizione: x=0.000, y=0.000
# Velocità: x_vel=0.125, y_vel=0.113
# Forze: force_x=660.369, force_y=597.905
# Posizione: x=0.001, y=0.001
# Velocità: x_vel=0.124, y_vel=0.104
# Forze: force_x=663.665, force_y=562.083
# Posizione: x=0.002, y=0.002
# Velocità: x_vel=0.124, y_vel=0.097
# Forze: force_x=666.949, force_y=525.175
# Posizione: x=0.004, y=0.003
# Velocità: x_vel=0.125, y_vel=0.090
# Forze: force_x=670.219, force_y=487.250
# Posizione: x=0.005, y=0.004
# Velocità: x_vel=0.125, y_vel=0.083
# Forze: force_x=673.477, force_y=448.383
# Posizione: x=0.006, y=0.005
# Velocità: x_vel=0.126, y_vel=0.076
# Forze: force_x=676.722, force_y=408.649
# Posizione: x=0.007, y=0.006
# Velocità: x_vel=0.094, y_vel=0.050
# Forze: force_x=679.953, force_y=368.125
# Posizione: x=0.008, y=0.006
# Velocità: x_vel=0.128, y_vel=0.061
# Forze: force_x=683.172, force_y=326.888
# Posizione: x=0.010, y=0.007
# Velocità: x_vel=0.128, y_vel=0.053
# Forze: force_x=686.377, force_y=285.019
# Posizione: x=0.011, y=0.007
# Velocità: x_vel=0.128, y_vel=0.045
# Forze: force_x=689.569, force_y=242.599
# Posizione: x=0.012, y=0.008
# Velocità: x_vel=0.129, y_vel=0.037
# Forze: force_x=692.748, force_y=199.710
# Posizione: x=0.014, y=0.008
# Velocità: x_vel=0.130, y_vel=0.029
# Forze: force_x=695.913, force_y=156.434
# Posizione: x=0.015, y=0.008
# Velocità: x_vel=0.130, y_vel=0.021
# Forze: force_x=699.065, force_y=112.856
# Posizione: x=0.016, y=0.009
# Velocità: x_vel=0.097, y_vel=0.008
# Forze: force_x=702.203, force_y=69.060
# Posizione: x=0.017, y=0.009
# Velocità: x_vel=0.132, y_vel=0.004
# Forze: force_x=705.327, force_y=25.130
# Posizione: x=0.018, y=0.009
# Velocità: x_vel=0.082, y_vel=-0.003
# Forze: force_x=708.438, force_y=-18.848
# Posizione: x=0.019, y=0.009
# Velocità: x_vel=0.133, y_vel=-0.012
# Forze: force_x=711.536, force_y=-62.791
# Posizione: x=0.021, y=0.009
# Velocità: x_vel=0.099, y_vel=-0.016
# Forze: force_x=714.619, force_y=-106.611
# Posizione: x=0.022, y=0.008
# Velocità: x_vel=0.134, y_vel=-0.028
# Forze: force_x=717.689, force_y=-150.226
# Posizione: x=0.023, y=0.008
# Velocità: x_vel=0.100, y_vel=-0.028
# Forze: force_x=720.745, force_y=-193.549
# Posizione: x=0.024, y=0.008
# Velocità: x_vel=0.135, y_vel=-0.045
# Forze: force_x=723.787, force_y=-236.499
# Posizione: x=0.025, y=0.007
# Velocità: x_vel=0.100, y_vel=-0.040
# Forze: force_x=726.814, force_y=-278.991
# Posizione: x=0.026, y=0.007
# Velocità: x_vel=0.102, y_vel=-0.046
# Forze: force_x=729.828, force_y=-320.944
# Posizione: x=0.027, y=0.007
# Velocità: x_vel=0.137, y_vel=-0.068
# Forze: force_x=732.828, force_y=-362.275
# Posizione: x=0.029, y=0.006
# Velocità: x_vel=0.102, y_vel=-0.058
# Forze: force_x=735.813, force_y=-402.906
# Posizione: x=0.030, y=0.005
# Velocità: x_vel=0.138, y_vel=-0.083
# Forze: force_x=738.785, force_y=-442.758
# Posizione: x=0.031, y=0.004
# Velocità: x_vel=0.103, y_vel=-0.069
# Forze: force_x=741.742, force_y=-481.754
# Posizione: x=0.032, y=0.004
# Velocità: x_vel=0.139, y_vel=-0.098
# Forze: force_x=744.684, force_y=-519.817
# Posizione: x=0.034, y=0.003
# Velocità: x_vel=0.139, y_vel=-0.104
# Forze: force_x=747.613, force_y=-556.876
# Posizione: x=0.035, y=0.002
# Velocità: x_vel=0.112, y_vel=-0.089
# Forze: force_x=750.526, force_y=-592.857
# Posizione: x=0.036, y=0.001
# Velocità: x_vel=0.089, y_vel=-0.076
# Forze: force_x=753.426, force_y=-627.691
# Posizione: x=0.037, y=0.000
# Velocità: x_vel=0.142, y_vel=-0.124
# Forze: force_x=756.310, force_y=-661.312
# Posizione: x=0.038, y=-0.001
# Velocità: x_vel=0.141, y_vel=-0.130
# Forze: force_x=759.180, force_y=-693.653
# Posizione: x=0.040, y=-0.002
# Velocità: x_vel=0.142, y_vel=-0.135
# Forze: force_x=762.036, force_y=-724.653
# Posizione: x=0.041, y=-0.004
# Velocità: x_vel=0.143, y_vel=-0.141
# Forze: force_x=764.876, force_y=-754.251
# Posizione: x=0.043, y=-0.005
# Velocità: x_vel=0.143, y_vel=-0.146
# Forze: force_x=767.702, force_y=-782.391
# Posizione: x=0.044, y=-0.007
# Velocità: x_vel=0.144, y_vel=-0.151
# Forze: force_x=770.513, force_y=-809.017
# Posizione: x=0.045, y=-0.008
# Velocità: x_vel=0.108, y_vel=-0.119
# Forze: force_x=773.309, force_y=-834.078
# Posizione: x=0.047, y=-0.009
# Velocità: x_vel=0.145, y_vel=-0.161
# Forze: force_x=776.090, force_y=-857.527
# Posizione: x=0.048, y=-0.011
# Velocità: x_vel=0.145, y_vel=-0.164
# Forze: force_x=778.857, force_y=-879.316
# Posizione: x=0.049, y=-0.013
# Velocità: x_vel=0.146, y_vel=-0.168
# Forze: force_x=781.608, force_y=-899.405
# Posizione: x=0.051, y=-0.014
# Velocità: x_vel=0.146, y_vel=-0.171
# Forze: force_x=784.343, force_y=-917.755
# Posizione: x=0.052, y=-0.016
# Velocità: x_vel=0.147, y_vel=-0.174
# Forze: force_x=787.064, force_y=-934.329
# Posizione: x=0.054, y=-0.018
# Velocità: x_vel=0.147, y_vel=-0.177
# Forze: force_x=789.770, force_y=-949.096
# Posizione: x=0.055, y=-0.020
# Velocità: x_vel=0.148, y_vel=-0.179
# Forze: force_x=792.460, force_y=-962.028
# Posizione: x=0.057, y=-0.021
# Velocità: x_vel=0.148, y_vel=-0.181
# Forze: force_x=795.135, force_y=-973.099
# Posizione: x=0.058, y=-0.023
# Velocità: x_vel=0.149, y_vel=-0.183
# Forze: force_x=797.794, force_y=-982.287
# Posizione: x=0.060, y=-0.025
# Velocità: x_vel=0.149, y_vel=-0.184
# Forze: force_x=800.439, force_y=-989.576
# Posizione: x=0.061, y=-0.027
# Velocità: x_vel=0.150, y_vel=-0.185
# Forze: force_x=803.067, force_y=-994.951
# Posizione: x=0.063, y=-0.029
# Velocità: x_vel=0.150, y_vel=-0.186
# Forze: force_x=805.680, force_y=-998.402
# Posizione: x=0.064, y=-0.031
# Velocità: x_vel=0.151, y_vel=-0.186
# Forze: force_x=808.278, force_y=-999.921
# Posizione: x=0.066, y=-0.032
# Velocità: x_vel=0.151, y_vel=-0.186
# Forze: force_x=810.860, force_y=-999.507
# Posizione: x=0.067, y=-0.034
# Velocità: x_vel=0.152, y_vel=-0.186
# Forze: force_x=813.426, force_y=-997.159
# Posizione: x=0.069, y=-0.036
# Velocità: x_vel=0.152, y_vel=-0.185
# Forze: force_x=815.976, force_y=-992.883
# Posizione: x=0.070, y=-0.038
# Velocità: x_vel=0.153, y_vel=-0.184
# Forze: force_x=818.511, force_y=-986.686
# Posizione: x=0.072, y=-0.040
# Velocità: x_vel=0.101, y_vel=-0.116
# Forze: force_x=821.030, force_y=-978.581
# Posizione: x=0.073, y=-0.041
# Velocità: x_vel=0.155, y_vel=-0.182
# Forze: force_x=823.533, force_y=-968.583
# Posizione: x=0.074, y=-0.043
# Velocità: x_vel=0.154, y_vel=-0.178
# Forze: force_x=826.020, force_y=-956.712
# Posizione: x=0.076, y=-0.045
# Velocità: x_vel=0.155, y_vel=-0.176
# Forze: force_x=828.491, force_y=-942.991
# Posizione: x=0.077, y=-0.046
# Velocità: x_vel=0.119, y_vel=-0.129
# Forze: force_x=830.946, force_y=-927.445
# Posizione: x=0.079, y=-0.048
# Velocità: x_vel=0.156, y_vel=-0.170
# Forze: force_x=833.385, force_y=-910.106
# Posizione: x=0.080, y=-0.049
# Velocità: x_vel=0.156, y_vel=-0.166
# Forze: force_x=835.807, force_y=-891.007
# Posizione: x=0.082, y=-0.051
# Velocità: x_vel=0.119, y_vel=-0.121
# Forze: force_x=838.214, force_y=-870.184
# Posizione: x=0.083, y=-0.052
# Velocità: x_vel=0.157, y_vel=-0.159
# Forze: force_x=840.604, force_y=-847.678
# Posizione: x=0.085, y=-0.054
# Velocità: x_vel=0.157, y_vel=-0.153
# Forze: force_x=842.979, force_y=-823.533
# Posizione: x=0.086, y=-0.055
# Velocità: x_vel=0.158, y_vel=-0.149
# Forze: force_x=845.336, force_y=-797.794
# Posizione: x=0.088, y=-0.057
# Velocità: x_vel=0.121, y_vel=-0.107
# Forze: force_x=847.678, force_y=-770.513
# Posizione: x=0.089, y=-0.058
# Velocità: x_vel=0.159, y_vel=-0.139
# Forze: force_x=850.003, force_y=-741.742
# Posizione: x=0.090, y=-0.059
# Velocità: x_vel=0.102, y_vel=-0.083
# Forze: force_x=852.312, force_y=-711.536
# Posizione: x=0.092, y=-0.060
# Velocità: x_vel=0.160, y_vel=-0.127
# Forze: force_x=854.604, force_y=-679.953
# Posizione: x=0.093, y=-0.061
# Velocità: x_vel=0.160, y_vel=-0.120
# Forze: force_x=856.880, force_y=-647.056
# Posizione: x=0.095, y=-0.063
# Velocità: x_vel=0.160, y_vel=-0.114
# Forze: force_x=859.139, force_y=-612.907
# Posizione: x=0.096, y=-0.064
# Velocità: x_vel=0.122, y_vel=-0.080
# Forze: force_x=861.381, force_y=-577.573
# Posizione: x=0.098, y=-0.065
# Velocità: x_vel=0.162, y_vel=-0.101
# Forze: force_x=863.607, force_y=-541.121
# Posizione: x=0.099, y=-0.066
# Velocità: x_vel=0.162, y_vel=-0.094
# Forze: force_x=865.816, force_y=-503.623
# Posizione: x=0.101, y=-0.066
# Velocità: x_vel=0.162, y_vel=-0.087
# Forze: force_x=868.008, force_y=-465.151
# Posizione: x=0.102, y=-0.067
# Velocità: x_vel=0.162, y_vel=-0.079
# Forze: force_x=870.184, force_y=-425.779
# Posizione: x=0.104, y=-0.068
# Velocità: x_vel=0.163, y_vel=-0.072
# Forze: force_x=872.342, force_y=-385.584
# Posizione: x=0.106, y=-0.069
# Velocità: x_vel=0.163, y_vel=-0.064
# Forze: force_x=874.484, force_y=-344.643
# Posizione: x=0.107, y=-0.069
# Velocità: x_vel=0.125, y_vel=-0.042
# Forze: force_x=876.609, force_y=-303.035
# Posizione: x=0.109, y=-0.070
# Velocità: x_vel=0.165, y_vel=-0.049
# Forze: force_x=878.717, force_y=-260.842
# Posizione: x=0.110, y=-0.070
# Velocità: x_vel=0.164, y_vel=-0.041
# Forze: force_x=880.808, force_y=-218.143
# Posizione: x=0.112, y=-0.071
# Velocità: x_vel=0.125, y_vel=-0.024
# Forze: force_x=882.882, force_y=-175.023
# Posizione: x=0.113, y=-0.071
# Velocità: x_vel=0.166, y_vel=-0.025
# Forze: force_x=884.939, force_y=-131.564
# Posizione: x=0.115, y=-0.071
# Velocità: x_vel=0.125, y_vel=-0.012
# Forze: force_x=886.979, force_y=-87.851
# Posizione: x=0.116, y=-0.071
# Velocità: x_vel=0.127, y_vel=-0.006
# Forze: force_x=889.001, force_y=-43.968
# Posizione: x=0.117, y=-0.071
# Velocità: x_vel=0.167, y_vel=0.000
# Forze: force_x=891.007, force_y=-0.000
# Posizione: x=0.119, y=-0.071
# Velocità: x_vel=0.126, y_vel=0.006
# Forze: force_x=892.995, force_y=43.968
# Posizione: x=0.120, y=-0.071
# Velocità: x_vel=0.168, y_vel=0.017
# Forze: force_x=894.966, force_y=87.851
# Posizione: x=0.122, y=-0.071
# Velocità: x_vel=0.127, y_vel=0.018
# Forze: force_x=896.919, force_y=131.564
# Posizione: x=0.123, y=-0.071
# Velocità: x_vel=0.168, y_vel=0.033
# Forze: force_x=898.855, force_y=175.023
# Posizione: x=0.125, y=-0.071
# Velocità: x_vel=0.127, y_vel=0.030
# Forze: force_x=900.774, force_y=218.143
# Posizione: x=0.126, y=-0.070
# Velocità: x_vel=0.169, y_vel=0.049
# Forze: force_x=902.675, force_y=260.842
# Posizione: x=0.128, y=-0.070
# Velocità: x_vel=0.169, y_vel=0.057
# Forze: force_x=904.559, force_y=303.035
# Posizione: x=0.129, y=-0.069
# Velocità: x_vel=0.128, y_vel=0.048
# Forze: force_x=906.426, force_y=344.643
# Posizione: x=0.131, y=-0.069
# Velocità: x_vel=0.170, y_vel=0.072
# Forze: force_x=908.275, force_y=385.584
# Posizione: x=0.132, y=-0.068
# Velocità: x_vel=0.129, y_vel=0.059
# Forze: force_x=910.106, force_y=425.779
# Posizione: x=0.134, y=-0.068
# Velocità: x_vel=0.171, y_vel=0.087
# Forze: force_x=911.920, force_y=465.151
# Posizione: x=0.135, y=-0.067
# Velocità: x_vel=0.170, y_vel=0.094
# Forze: force_x=913.716, force_y=503.623
# Posizione: x=0.137, y=-0.066
# Velocità: x_vel=0.130, y_vel=0.075
# Forze: force_x=915.494, force_y=541.121
# Posizione: x=0.138, y=-0.065
# Velocità: x_vel=0.172, y_vel=0.108
# Forze: force_x=917.255, force_y=577.573
# Posizione: x=0.140, y=-0.064
# Velocità: x_vel=0.130, y_vel=0.085
# Forze: force_x=918.998, force_y=612.907
# Posizione: x=0.141, y=-0.063
# Velocità: x_vel=0.172, y_vel=0.121
# Forze: force_x=920.723, force_y=647.056
# Posizione: x=0.143, y=-0.062
# Velocità: x_vel=0.172, y_vel=0.127
# Forze: force_x=922.430, force_y=679.953
# Posizione: x=0.145, y=-0.061
# Velocità: x_vel=0.172, y_vel=0.133
# Forze: force_x=924.120, force_y=711.536
# Posizione: x=0.147, y=-0.059
# Velocità: x_vel=0.139, y_vel=0.111
# Forze: force_x=925.791, force_y=741.742
# Posizione: x=0.148, y=-0.058
# Velocità: x_vel=0.174, y_vel=0.144
# Forze: force_x=927.445, force_y=770.513
# Posizione: x=0.150, y=-0.057
# Velocità: x_vel=0.173, y_vel=0.149
# Forze: force_x=929.081, force_y=797.794
# Posizione: x=0.151, y=-0.055
# Velocità: x_vel=0.174, y_vel=0.154
# Forze: force_x=930.699, force_y=823.533
# Posizione: x=0.153, y=-0.054
# Velocità: x_vel=0.174, y_vel=0.158
# Forze: force_x=932.299, force_y=847.678
# Posizione: x=0.155, y=-0.052
# Velocità: x_vel=0.174, y_vel=0.162
# Forze: force_x=933.880, force_y=870.184
# Posizione: x=0.157, y=-0.051
# Velocità: x_vel=0.174, y_vel=0.166
# Forze: force_x=935.444, force_y=891.007
# Posizione: x=0.158, y=-0.049
# Velocità: x_vel=0.113, y_vel=0.107
# Forze: force_x=936.990, force_y=910.106
# Posizione: x=0.160, y=-0.048
# Velocità: x_vel=0.176, y_vel=0.174
# Forze: force_x=938.517, force_y=927.445
# Posizione: x=0.161, y=-0.046
# Velocità: x_vel=0.175, y_vel=0.176
# Forze: force_x=940.026, force_y=942.991
# Posizione: x=0.163, y=-0.044
# Velocità: x_vel=0.176, y_vel=0.178
# Forze: force_x=941.518, force_y=956.712
# Posizione: x=0.165, y=-0.042
# Velocità: x_vel=0.176, y_vel=0.181
# Forze: force_x=942.991, force_y=968.583
# Posizione: x=0.167, y=-0.041
# Velocità: x_vel=0.176, y_vel=0.182
# Forze: force_x=944.445, force_y=978.581
# Posizione: x=0.168, y=-0.039
# Velocità: x_vel=0.176, y_vel=0.184
# Forze: force_x=945.882, force_y=986.686
# Posizione: x=0.170, y=-0.037
# Velocità: x_vel=0.177, y_vel=0.185
# Forze: force_x=947.300, force_y=992.883
# Posizione: x=0.172, y=-0.035
# Velocità: x_vel=0.177, y_vel=0.186
# Forze: force_x=948.700, force_y=997.159
# Posizione: x=0.174, y=-0.033
# Velocità: x_vel=0.177, y_vel=0.186
# Forze: force_x=950.081, force_y=999.507
# Posizione: x=0.175, y=-0.031
# Velocità: x_vel=0.136, y_vel=0.141
# Forze: force_x=951.444, force_y=999.921
# Posizione: x=0.177, y=-0.030
# Velocità: x_vel=0.178, y_vel=0.187
# Forze: force_x=952.789, force_y=998.402
# Posizione: x=0.179, y=-0.028
# Velocità: x_vel=0.178, y_vel=0.185
# Forze: force_x=954.115, force_y=994.951
# Posizione: x=0.180, y=-0.026
# Velocità: x_vel=0.178, y_vel=0.184
# Forze: force_x=955.423, force_y=989.576
# Posizione: x=0.182, y=-0.024
# Velocità: x_vel=0.178, y_vel=0.183
# Forze: force_x=956.712, force_y=982.287
# Posizione: x=0.184, y=-0.023
# Velocità: x_vel=0.179, y_vel=0.181
# Forze: force_x=957.983, force_y=973.099
# Posizione: x=0.186, y=-0.021
# Velocità: x_vel=0.136, y_vel=0.136
# Forze: force_x=959.235, force_y=962.028
# Posizione: x=0.187, y=-0.019
# Velocità: x_vel=0.180, y_vel=0.178
# Forze: force_x=960.469, force_y=949.096
# Posizione: x=0.189, y=-0.018
# Velocità: x_vel=0.179, y_vel=0.174
# Forze: force_x=961.684, force_y=934.329
# Posizione: x=0.191, y=-0.016
# Velocità: x_vel=0.180, y_vel=0.171
# Forze: force_x=962.880, force_y=917.755
# Posizione: x=0.192, y=-0.014
# Velocità: x_vel=0.136, y_vel=0.127
# Forze: force_x=964.058, force_y=899.405
# Posizione: x=0.194, y=-0.013
# Velocità: x_vel=0.181, y_vel=0.165
# Forze: force_x=965.218, force_y=879.316
# Posizione: x=0.196, y=-0.011
# Velocità: x_vel=0.180, y_vel=0.160
# Forze: force_x=966.358, force_y=857.527
# Posizione: x=0.197, y=-0.010
# Velocità: x_vel=0.180, y_vel=0.155
# Forze: force_x=967.480, force_y=834.078
# Posizione: x=0.199, y=-0.008
# Velocità: x_vel=0.181, y_vel=0.151
# Forze: force_x=968.583, force_y=809.017
# Posizione: x=0.201, y=-0.007
# Velocità: x_vel=0.137, y_vel=0.111
# Forze: force_x=969.668, force_y=782.391
# Posizione: x=0.202, y=-0.006
# Velocità: x_vel=0.182, y_vel=0.141
# Forze: force_x=970.733, force_y=754.251
# Posizione: x=0.204, y=-0.004
# Velocità: x_vel=0.181, y_vel=0.135
# Forze: force_x=971.780, force_y=724.653
# Posizione: x=0.206, y=-0.003
# Velocità: x_vel=0.137, y_vel=0.099
# Forze: force_x=972.808, force_y=693.653
# Posizione: x=0.207, y=-0.002
# Velocità: x_vel=0.138, y_vel=0.095
# Forze: force_x=973.817, force_y=661.312
# Steps: 142
# Dataset delle posizioni target salvato in: /Users/edoardozappia/Desktop/Tesi_Magistrale/target_positions_sinus.npy
