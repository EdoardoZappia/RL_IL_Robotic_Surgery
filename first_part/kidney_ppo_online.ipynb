# %%
import mujoco
import glfw
import numpy as np
import time
from gymnasium import Env, spaces

class ForceMatchingEnv(Env):
    def __init__(self, model_path, max_distance=0.01):
        super(ForceMatchingEnv, self).__init__()

        self.model = mujoco.MjModel.from_xml_path(model_path)
        self.data = mujoco.MjData(self.model)

        # Definizione dello stato (x, y, vel_x, vel_y)
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(4,), dtype=np.float32)

        # Azioni: (forza_x, forza_y)
        self.action_space = spaces.Box(low=-1000, high=1000, shape=(2,), dtype=np.float32)

        self.step_count = 0
        self.max_steps = 600
        self.max_distance = max_distance  # Distanza massima oltre la quale l'episodio termina
        self.alpha_x = 1.0
        self.alpha_y = 1.0
        self.half_side = 0.3

        self.episode_count = 0


        # Inizializza GLFW per la visualizzazione
        if not glfw.init():
            raise Exception("Impossibile inizializzare GLFW")

        glfw.window_hint(glfw.VISIBLE, glfw.TRUE)
        self.window = glfw.create_window(800, 800, "MuJoCo Viewer", None, None)
        if not self.window:
            glfw.terminate()
            raise Exception("Errore nella creazione della finestra GLFW")

        glfw.make_context_current(self.window)

        # Configura la telecamera
        self.camera = mujoco.MjvCamera()
        self.camera.type = mujoco.mjtCamera.mjCAMERA_FREE
        self.camera.lookat = np.array([0, 0, 0])
        self.camera.distance = 2.0
        self.camera.azimuth = 90
        self.camera.elevation = -90

        # Renderer
        self.scene = mujoco.MjvScene(self.model, maxgeom=1000)
        self.context = mujoco.MjrContext(self.model, mujoco.mjtFontScale.mjFONTSCALE_150)

    def reset(self):
        """Resetta sia il target che il punto agent e restituisce stato e target"""
        #**Reset del punto AGENT**

        self.data.qpos[self.model.joint("agent_slide_x").qposadr] = 0.0
        self.data.qpos[self.model.joint("agent_slide_y").qposadr] = 0.0
        self.data.qvel[self.model.joint("agent_slide_x").dofadr] = 0.0
        self.data.qvel[self.model.joint("agent_slide_y").dofadr] = 0.0

        #**Reset del TARGET**
        self.data.qpos[self.model.joint("target_slide_x").qposadr] = 0.0
        self.data.qpos[self.model.joint("target_slide_y").qposadr] = 0.0
        self.data.qvel[self.model.joint("target_slide_x").dofadr] = 0.0
        self.data.qvel[self.model.joint("target_slide_y").dofadr] = 0.0

        # **Randomizza la direzione iniziale del target**
        #if self.episode_count % 1000 == 0:
        #    self.alpha_x = np.random.choice([-1, 1])
        #    self.alpha_y = np.random.choice([-1, 1])

        #    print(f"Nuovo episodio: direzione iniziale target X={self.alpha_x}, Y={self.alpha_y}")

        self.episode_count += 1

        self.step_count = 0

        # **Restituisci lo stato iniziale per PPO (solo posizione & velocità dell'agent)**
        agent_state = np.array([
            self.data.qpos[self.model.joint("agent_slide_x").qposadr],  # Posizione X
            self.data.qpos[self.model.joint("agent_slide_y").qposadr],  # Posizione Y
            self.data.qvel[self.model.joint("agent_slide_x").dofadr],  # Velocità X
            self.data.qvel[self.model.joint("agent_slide_y").dofadr],  # Velocità Y
        ])

        
        # 📌 **Restituisci anche il target per calcolare il reward**
        target_state = np.array([
            self.data.qpos[self.model.joint("target_slide_x").qposadr],
            self.data.qpos[self.model.joint("target_slide_y").qposadr],
        ])

        #print(f"posizione target reset: {self.data.qpos[self.model.joint('target_slide_x').qposadr]}, {self.data.qpos[self.model.joint('target_slide_y').qposadr]}")
        #print(f"posizione agente reset: {self.data.qpos[self.model.joint('agent_slide_x').qposadr]}, {self.data.qpos[self.model.joint('agent_slide_y').qposadr]}")

        return agent_state, target_state


    def step(self, action):
        """Applica l'azione all'agent e aggiorna la dinamica del target"""

        action = np.array(action, dtype=np.float32)

        #applica l'azione del PPO all'agent**
        self.data.qfrc_applied[0] = action[0] * 150
        self.data.qfrc_applied[1] = action[1] * 150

        #print(f"azioni: {action[0]}, {action[1]}")

        #aggiorna la dinamica del target (come discusso prima)**
        x = self.data.qpos[3]  # Posizione X del target
        y = self.data.qpos[4]  # Posizione Y del target

        # Mantiene la direzione fino al rimbalzo
        if x >= self.half_side or x <= -self.half_side:
            self.alpha_x *= np.random.choice([-1, 1])
    
        if y >= self.half_side or y <= -self.half_side:
            self.alpha_y *= np.random.choice([-1, 1])

        #calcola le forze per il target
        force_x = self.alpha_x * 75
        force_y = self.alpha_y * 75

        dof_x = self.model.joint("target_slide_x").dofadr
        dof_y = self.model.joint("target_slide_y").dofadr

        #applica le forze al target
        self.data.qfrc_applied[dof_x] = force_x
        self.data.qfrc_applied[dof_y] = force_y

        #avanza la simulazione**
        mujoco.mj_step(self.model, self.data)

        #osservazione (stato per PPO)**
        obs = np.array([
            self.data.qpos[0],  # Posizione X agent
            self.data.qpos[1],  # Posizione Y agent
            self.data.qvel[0],  # Velocità X agent
            self.data.qvel[1],  # Velocità Y agent
        ])

        #print(f"posizione target: {self.data.qpos[3]}, {self.data.qpos[4]}")
        #print(f"posizione agente: {obs[0]}, {obs[1]}, velocità agente: {obs[2]}, {obs[3]}")

        #reward basato sulla distanza agent-target**
        target_pos = np.array([self.data.qpos[2], self.data.qpos[3]])  # Posizione target
        #dist_x = np.abs(obs[0] - target_pos[0])
        #dist_y = np.abs(obs[1] - target_pos[1])
        dist_x = np.abs(np.round(obs[0], 3) - np.round(target_pos[0], 3))
        dist_y = np.abs(np.round(obs[1], 3) - np.round(target_pos[1], 3))

        #print(f"dist_x: {dist_x}, dist_y: {dist_y}")

        flag = dist_x <= self.max_distance and dist_y <= self.max_distance

        #reward discreto
        reward = +1 if flag else 0

        #controllo di terminazione**
        done = (not flag) or self.step_count >= self.max_steps

        self.step_count += 1
        return obs, reward, done, False, {}


    def render(self):
        if glfw.window_should_close(self.window):
            glfw.destroy_window(self.window)
            glfw.terminate()
            return

        mujoco.mjv_updateScene(self.model, self.data, mujoco.MjvOption(), None, self.camera, mujoco.mjtCatBit.mjCAT_ALL, self.scene)
        viewport_width, viewport_height = glfw.get_framebuffer_size(self.window)
        viewport = mujoco.MjrRect(0, 0, viewport_width, viewport_height)
        mujoco.mjr_render(viewport, self.scene, self.context)

        glfw.swap_buffers(self.window)
        glfw.poll_events()

    def close(self):
        glfw.destroy_window(self.window)
        glfw.terminate()

# %%
import gymnasium as gym
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.distributions import Normal
import matplotlib.pyplot as plt

SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

MAX_MEMORY = 600
NUM_NEURONS = 128
LR_CRITIC = 0.0005
LR_ACTOR = 0.001
GAMMA = 0.99
LAMBDA = 0.95
CLIP_EPS = 0.2
K_EPOCH = 10
EARLY_STOP_THRESHOLD = 580
EPISODES_EARLY_STOP = 30
MAX_EPISODES = 2000000

def compute_advantages(rewards, values, dones, gamma=GAMMA, lam=LAMBDA):
    advantages = []
    gae = 0
    values = values + [0]  # Append a 0 for the last state
    for t in reversed(range(len(rewards))):
        delta = rewards[t] + gamma * values[t + 1] * (1 - dones[t]) - values[t]
        gae = delta + gamma * lam * (1 - dones[t]) * gae
        advantages.insert(0, gae)
    return torch.tensor(advantages, dtype=torch.float32)

def compute_returns(rewards, dones, gamma=0.99):
    returns = []
    G = 0
    for reward, done in zip(reversed(rewards), reversed(dones)):
        G = reward + gamma * G * (1 - done)  # Reset if episode ended
        returns.insert(0, G)
    return torch.tensor(returns, dtype=torch.float32)

class PolicyNet(nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(PolicyNet, self).__init__()
        
        self.dense=nn.Sequential(
            nn.Linear(num_inputs, NUM_NEURONS),
            nn.ReLU(),
            nn.Linear(NUM_NEURONS, NUM_NEURONS),
            nn.ReLU(),
        )

        # Output della media delle azioni
        self.mean_layer = nn.Linear(NUM_NEURONS, num_actions)
        
        # Output della deviazione standard (log std per stabilità numerica)
        self.log_std_layer = nn.Linear(NUM_NEURONS, num_actions)

    def forward(self, x):
        x = self.dense(x)
        mean = self.mean_layer(x)
        
        # Il log_std viene trasformato in std con exp() per garantire valori positivi
        log_std = self.log_std_layer(x)
        std = torch.exp(log_std)
        
        return mean, std

class ValueNet(nn.Module):
    def __init__(self, num_inputs):
        super(ValueNet, self).__init__()
        self.fc1 = nn.Linear(num_inputs, NUM_NEURONS)
        self.fc2 = nn.Linear(NUM_NEURONS, NUM_NEURONS)
        self.fc3 = nn.Linear(NUM_NEURONS, 1)
        
    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        return self.fc3(x)

class PPOAgent(nn.Module):
    def __init__(self, num_inputs, num_actions):
        super(PPOAgent, self).__init__()
        self.actor = PolicyNet(num_inputs, num_actions)
        self.critic = ValueNet(num_inputs)
        self.optimizer_actor = optim.Adam(self.actor.parameters(), lr=LR_ACTOR)
        self.optimizer_critic = optim.Adam(self.critic.parameters(), lr=LR_CRITIC)
        self.buffer = []
    
    def get_action(self, state):
        state = torch.tensor(state, dtype=torch.float32)#.view(-1)
        mu, sigma = self.actor(state)
        dist = Normal(mu, sigma)
        action = dist.sample()
        log_prob = dist.log_prob(action).sum()
        return action.detach().numpy(), log_prob

    def store_transition(self, transition):
        self.buffer.append(transition)
    
    def update(self):
        states, actions, rewards, dones, old_log_probs = zip(*self.buffer)
        old_log_probs = torch.stack(old_log_probs)
        states = torch.tensor(states, dtype=torch.float32)
        #print(f"state shpae in update {states.shape}")
        actions = torch.tensor(actions, dtype=torch.float32)  # Azioni continue
        rewards = torch.tensor(rewards, dtype=torch.float32)
        dones = torch.tensor(dones, dtype=torch.float32)
        values = self.critic(states).squeeze()
        advantages = compute_advantages(rewards.tolist(), values.tolist(), dones.tolist())
        returns = compute_returns(rewards.tolist(), dones.tolist())

        for _ in range(K_EPOCH):
            mu, sigma = self.actor(states)
            new_dist = Normal(mu, sigma)
            new_log_probs = new_dist.log_prob(actions).sum(dim=1)

            ratio = torch.exp(new_log_probs - old_log_probs.detach())
            surr1 = ratio * advantages
            surr2 = torch.clamp(ratio, 1 - CLIP_EPS, 1 + CLIP_EPS) * advantages
            policy_loss = -torch.min(surr1, surr2).mean()
            entropy_loss = -0.01 * new_dist.entropy().mean()  # Il valore 0.01 regola l'importanza dell'esplorazione
            policy_loss += entropy_loss
            value_loss = F.mse_loss(self.critic(states).squeeze(), returns)

            self.optimizer_actor.zero_grad()
            self.optimizer_critic.zero_grad()
            policy_loss.backward()
            value_loss.backward()
            self.optimizer_actor.step()
            self.optimizer_critic.step()

        self.buffer.clear()

def train_ppo(num_episodes=MAX_EPISODES):
    env = ForceMatchingEnv("/Users/edoardozappia/Desktop/Tesi_Magistrale/irregular_shape_2D_online.xml")
    #print(f"obs space shape {env.observation_space.shape[0]}")
    num_inputs = env.observation_space.shape[0]
    num_actions = env.action_space.shape[0]  # Ora è continuo
    agent = PPOAgent(num_inputs, num_actions)
    reward_history = []
    
    for episode in range(num_episodes):
        #print(f"Episode: {episode}")
        actor_state, _ = env.reset()
        actor_state = actor_state.reshape(-1)
        #print(f"actor_state shape: {actor_state.shape}")
        done = False
        early_stop = False
        total_reward = 0
        
        while not done:
            action, log_prob = agent.get_action(actor_state)
            #print(action)
            next_actor_state, reward, terminated, truncated, _ = env.step(action)
            #print(f"Reward: {reward}")
            done = terminated or truncated
            #print(f"done: {done}")
            agent.store_transition((actor_state, action, reward, done, log_prob))
            actor_state = next_actor_state
            total_reward += reward

        reward_history.append(total_reward)

        if len(reward_history) >= 50 and np.mean(reward_history[-EPISODES_EARLY_STOP:]) > EARLY_STOP_THRESHOLD:
            print(f"Early stopping at episode {episode}, average reward: {np.mean(reward_history[-30:])}")
            early_stop = True
            break
        
        if early_stop:
            break

        if len(agent.buffer) >= MAX_MEMORY:
            agent.update()
        
        if episode % 10 == 0:
            print(f"Episode {episode}, Total Reward: {total_reward}")
    
    env.close()

    plt.plot(reward_history)
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.title('Training Progress')
    plt.show()

    return agent

if __name__ == "__main__":
    trained_agent = train_ppo()
# Out:
# Episode 0, Total Reward: 0
# Episode 10, Total Reward: 0
# Episode 20, Total Reward: 0
# Episode 30, Total Reward: 0
# Episode 40, Total Reward: 0
# Episode 50, Total Reward: 0
# Episode 60, Total Reward: 0
# Episode 70, Total Reward: 0
# Episode 80, Total Reward: 0
# Episode 90, Total Reward: 0
# Episode 100, Total Reward: 0
# Episode 110, Total Reward: 0
# Episode 120, Total Reward: 1
# Episode 130, Total Reward: 0
# Episode 140, Total Reward: 0
# Episode 150, Total Reward: 0
# Episode 160, Total Reward: 1
# Episode 170, Total Reward: 0
# Episode 180, Total Reward: 1
# Episode 190, Total Reward: 0
# Episode 200, Total Reward: 0
# Episode 210, Total Reward: 0
# Episode 220, Total Reward: 1
# Episode 230, Total Reward: 0
# Episode 240, Total Reward: 0
# Episode 250, Total Reward: 1
# Episode 260, Total Reward: 0
# Episode 270, Total Reward: 1
# Episode 280, Total Reward: 0
# Episode 290, Total Reward: 1
# Episode 300, Total Reward: 0
# Episode 310, Total Reward: 0
# Episode 320, Total Reward: 0
# Episode 330, Total Reward: 0
# Episode 340, Total Reward: 0
# Episode 350, Total Reward: 0
# Episode 360, Total Reward: 0
# Episode 370, Total Reward: 2
# Episode 380, Total Reward: 0
# Episode 390, Total Reward: 0
# Episode 400, Total Reward: 1
# Episode 410, Total Reward: 0
# Episode 420, Total Reward: 0
# Episode 430, Total Reward: 1
# Episode 440, Total Reward: 0
# Episode 450, Total Reward: 0
# /var/folders/72/24j7jy9s6sb2xm_dc84kdhm00000gn/T/ipykernel_17502/2439325324.py:106: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:278.)
#   states = torch.tensor(states, dtype=torch.float32)
# Episode 460, Total Reward: 0
# Episode 470, Total Reward: 1
# Episode 480, Total Reward: 0
# Episode 490, Total Reward: 0
# Episode 500, Total Reward: 0
# Episode 510, Total Reward: 0
# Episode 520, Total Reward: 0
# Episode 530, Total Reward: 0
# Episode 540, Total Reward: 0
# Episode 550, Total Reward: 0
# Episode 560, Total Reward: 1
# Episode 570, Total Reward: 0
# Episode 580, Total Reward: 0
# Episode 590, Total Reward: 0
# Episode 600, Total Reward: 1
# Episode 610, Total Reward: 1
# Episode 620, Total Reward: 0
# Episode 630, Total Reward: 0
# Episode 640, Total Reward: 0
# Episode 650, Total Reward: 0
# Episode 660, Total Reward: 0
# Episode 670, Total Reward: 1
# Episode 680, Total Reward: 0
# Episode 690, Total Reward: 0
# Episode 700, Total Reward: 1
# Episode 710, Total Reward: 0
# Episode 720, Total Reward: 0
# Episode 730, Total Reward: 0
# Episode 740, Total Reward: 1
# Episode 750, Total Reward: 0
# Episode 760, Total Reward: 0
# Episode 770, Total Reward: 1
# Episode 780, Total Reward: 0
# Episode 790, Total Reward: 0
# Episode 800, Total Reward: 0
# Episode 810, Total Reward: 0
# Episode 820, Total Reward: 0
# Episode 830, Total Reward: 0
# Episode 840, Total Reward: 0
# Episode 850, Total Reward: 0
# Episode 860, Total Reward: 1
# Episode 870, Total Reward: 2
# Episode 880, Total Reward: 0
# Episode 890, Total Reward: 0
# Episode 900, Total Reward: 2
# Episode 910, Total Reward: 1
# Episode 920, Total Reward: 0
# Episode 930, Total Reward: 1
# Episode 940, Total Reward: 0
# Episode 950, Total Reward: 1
# Episode 960, Total Reward: 2
# Episode 970, Total Reward: 1
# Episode 980, Total Reward: 0
# Episode 990, Total Reward: 1
# Episode 1000, Total Reward: 1
# Episode 1010, Total Reward: 0
# Episode 1020, Total Reward: 2
# Episode 1030, Total Reward: 3
# Episode 1040, Total Reward: 1
# Episode 1050, Total Reward: 0
# Episode 1060, Total Reward: 2
# Episode 1070, Total Reward: 1
# Episode 1080, Total Reward: 1
# Episode 1090, Total Reward: 0
# Episode 1100, Total Reward: 1
# Episode 1110, Total Reward: 0
# Episode 1120, Total Reward: 0
# Episode 1130, Total Reward: 2
# Episode 1140, Total Reward: 1
# Episode 1150, Total Reward: 6
# Episode 1160, Total Reward: 5
# Episode 1170, Total Reward: 0
# Episode 1180, Total Reward: 0
# Episode 1190, Total Reward: 4
# Episode 1200, Total Reward: 1
# Episode 1210, Total Reward: 1
# Episode 1220, Total Reward: 1
# Episode 1230, Total Reward: 4
# Episode 1240, Total Reward: 1
# Episode 1250, Total Reward: 3
# Episode 1260, Total Reward: 2
# Episode 1270, Total Reward: 1
# Episode 1280, Total Reward: 1
# Episode 1290, Total Reward: 1
# Episode 1300, Total Reward: 4
# Episode 1310, Total Reward: 1
# Episode 1320, Total Reward: 1
# Episode 1330, Total Reward: 0
# Episode 1340, Total Reward: 6
# Episode 1350, Total Reward: 2
# Episode 1360, Total Reward: 10
# Episode 1370, Total Reward: 2
# Episode 1380, Total Reward: 2
# Episode 1390, Total Reward: 10
# Episode 1400, Total Reward: 4
# Episode 1410, Total Reward: 7
# Episode 1420, Total Reward: 2
# Episode 1430, Total Reward: 3
# Episode 1440, Total Reward: 2
# Episode 1450, Total Reward: 15
# Episode 1460, Total Reward: 7
# Episode 1470, Total Reward: 3
# Episode 1480, Total Reward: 6
# Episode 1490, Total Reward: 3
# Episode 1500, Total Reward: 4
# Episode 1510, Total Reward: 15
# Episode 1520, Total Reward: 1
# Episode 1530, Total Reward: 13
# Episode 1540, Total Reward: 0
# Episode 1550, Total Reward: 7
# Episode 1560, Total Reward: 1
# Episode 1570, Total Reward: 6
# Episode 1580, Total Reward: 17
# Episode 1590, Total Reward: 2
# Episode 1600, Total Reward: 27
# Episode 1610, Total Reward: 4
# Episode 1620, Total Reward: 6
# Episode 1630, Total Reward: 17
# Episode 1640, Total Reward: 8
# Episode 1650, Total Reward: 11
# Episode 1660, Total Reward: 3
# Episode 1670, Total Reward: 59
# Episode 1680, Total Reward: 3
# Episode 1690, Total Reward: 13
# Episode 1700, Total Reward: 78
# Episode 1710, Total Reward: 26
# Episode 1720, Total Reward: 32
# Episode 1730, Total Reward: 26
# Episode 1740, Total Reward: 18
# Episode 1750, Total Reward: 42
# Episode 1760, Total Reward: 35
# Episode 1770, Total Reward: 48
# Episode 1780, Total Reward: 26
# Episode 1790, Total Reward: 49
# Episode 1800, Total Reward: 56
# Episode 1810, Total Reward: 44
# Episode 1820, Total Reward: 26
# Episode 1830, Total Reward: 48
# Episode 1840, Total Reward: 23
# Episode 1850, Total Reward: 135
# Episode 1860, Total Reward: 72
# Episode 1870, Total Reward: 27
# Episode 1880, Total Reward: 189
# Episode 1890, Total Reward: 56
# Episode 1900, Total Reward: 27
# Episode 1910, Total Reward: 19
# Episode 1920, Total Reward: 26
# Episode 1930, Total Reward: 81
# Episode 1940, Total Reward: 90
# Episode 1950, Total Reward: 64
# Episode 1960, Total Reward: 104
# Episode 1970, Total Reward: 41
# Episode 1980, Total Reward: 162
# Episode 1990, Total Reward: 32
# Episode 2000, Total Reward: 188
# Episode 2010, Total Reward: 211
# Episode 2020, Total Reward: 64
# Episode 2030, Total Reward: 22
# Episode 2040, Total Reward: 16
# Episode 2050, Total Reward: 6
# Episode 2060, Total Reward: 8
# Episode 2070, Total Reward: 14
# Episode 2080, Total Reward: 8
# Episode 2090, Total Reward: 12
# Episode 2100, Total Reward: 15
# Episode 2110, Total Reward: 25
# Episode 2120, Total Reward: 17
# Episode 2130, Total Reward: 16
# Episode 2140, Total Reward: 23
# Episode 2150, Total Reward: 36
# Episode 2160, Total Reward: 12
# Episode 2170, Total Reward: 74
# Episode 2180, Total Reward: 39
# Episode 2190, Total Reward: 38
# Episode 2200, Total Reward: 151
# Episode 2210, Total Reward: 197
# Episode 2220, Total Reward: 189
# Episode 2230, Total Reward: 21
# Episode 2240, Total Reward: 25
# Episode 2250, Total Reward: 170
# Episode 2260, Total Reward: 109
# Episode 2270, Total Reward: 59
# Episode 2280, Total Reward: 67
# Episode 2290, Total Reward: 62
# Episode 2300, Total Reward: 70
# Episode 2310, Total Reward: 66
# Episode 2320, Total Reward: 73
# Episode 2330, Total Reward: 82
# Episode 2340, Total Reward: 102
# Episode 2350, Total Reward: 219
# Episode 2360, Total Reward: 36
# Episode 2370, Total Reward: 181
# Episode 2380, Total Reward: 182
# Episode 2390, Total Reward: 122
# Episode 2400, Total Reward: 133
# Episode 2410, Total Reward: 220
# Episode 2420, Total Reward: 231
# Episode 2430, Total Reward: 44
# Episode 2440, Total Reward: 178
# Episode 2450, Total Reward: 72
# Episode 2460, Total Reward: 24
# Episode 2470, Total Reward: 190
# Episode 2480, Total Reward: 186
# Episode 2490, Total Reward: 44
# Episode 2500, Total Reward: 171
# Episode 2510, Total Reward: 271
# Episode 2520, Total Reward: 229
# Episode 2530, Total Reward: 59
# Episode 2540, Total Reward: 245
# Episode 2550, Total Reward: 193
# Episode 2560, Total Reward: 125
# Episode 2570, Total Reward: 329
# Episode 2580, Total Reward: 321
# Episode 2590, Total Reward: 32
# Episode 2600, Total Reward: 2
# Episode 2610, Total Reward: 2
# Episode 2620, Total Reward: 2
# Episode 2630, Total Reward: 2
# Episode 2640, Total Reward: 2
# Episode 2650, Total Reward: 2
# Episode 2660, Total Reward: 2
# Episode 2670, Total Reward: 2
# Episode 2680, Total Reward: 2
# Episode 2690, Total Reward: 2
# Episode 2700, Total Reward: 2
# Episode 2710, Total Reward: 2
# Episode 2720, Total Reward: 2
# Episode 2730, Total Reward: 2
# Episode 2740, Total Reward: 2
# Episode 2750, Total Reward: 2
# Episode 2760, Total Reward: 2
# Episode 2770, Total Reward: 2
# Episode 2780, Total Reward: 2
# Episode 2790, Total Reward: 2
# Episode 2800, Total Reward: 0
# Episode 2810, Total Reward: 0
# Episode 2820, Total Reward: 0
# Episode 2830, Total Reward: 0
# Episode 2840, Total Reward: 0
# Episode 2850, Total Reward: 0
# Episode 2860, Total Reward: 0
# Episode 2870, Total Reward: 0
# Episode 2880, Total Reward: 0
# Episode 2890, Total Reward: 0
# Episode 2900, Total Reward: 0
# Episode 2910, Total Reward: 0
# Episode 2920, Total Reward: 0
# Episode 2930, Total Reward: 0
# Episode 2940, Total Reward: 0
# Episode 2950, Total Reward: 0
# Episode 2960, Total Reward: 0
# Episode 2970, Total Reward: 0
# Episode 2980, Total Reward: 0
# Episode 2990, Total Reward: 0
# Episode 3000, Total Reward: 0
# Episode 3010, Total Reward: 0
# Episode 3020, Total Reward: 0
# Episode 3030, Total Reward: 0
# Episode 3040, Total Reward: 0
# Episode 3050, Total Reward: 0
# Episode 3060, Total Reward: 0
# Episode 3070, Total Reward: 0
# Episode 3080, Total Reward: 0
# Episode 3090, Total Reward: 0
# Episode 3100, Total Reward: 0
# Episode 3110, Total Reward: 0
# Episode 3120, Total Reward: 0
# Episode 3130, Total Reward: 0
# Episode 3140, Total Reward: 0
# Episode 3150, Total Reward: 0
# Episode 3160, Total Reward: 0
# Episode 3170, Total Reward: 0
# Episode 3180, Total Reward: 0
# Episode 3190, Total Reward: 0
# Episode 3200, Total Reward: 0
# Episode 3210, Total Reward: 0
# Episode 3220, Total Reward: 0
# Episode 3230, Total Reward: 0
# Episode 3240, Total Reward: 0
# Episode 3250, Total Reward: 0
# Episode 3260, Total Reward: 0
# Episode 3270, Total Reward: 0
# Episode 3280, Total Reward: 0
# Episode 3290, Total Reward: 0
# Episode 3300, Total Reward: 0
# Episode 3310, Total Reward: 0
# Episode 3320, Total Reward: 0
# Episode 3330, Total Reward: 0
# Episode 3340, Total Reward: 0
# Episode 3350, Total Reward: 0
# Episode 3360, Total Reward: 0
# Episode 3370, Total Reward: 0
# Episode 3380, Total Reward: 0
# Episode 3390, Total Reward: 0
# Episode 3400, Total Reward: 0
# Episode 3410, Total Reward: 0
# Episode 3420, Total Reward: 0
# Episode 3430, Total Reward: 0
# Episode 3440, Total Reward: 0
# Episode 3450, Total Reward: 0
# Episode 3460, Total Reward: 0
# Episode 3470, Total Reward: 0
# Episode 3480, Total Reward: 0
# Episode 3490, Total Reward: 0
# Episode 3500, Total Reward: 0
# Episode 3510, Total Reward: 0
# Episode 3520, Total Reward: 0
# Episode 3530, Total Reward: 0
# Episode 3540, Total Reward: 0
# Episode 3550, Total Reward: 0
# Episode 3560, Total Reward: 0
# Episode 3570, Total Reward: 0
# Episode 3580, Total Reward: 0
# Episode 3590, Total Reward: 0
# Episode 3600, Total Reward: 0
# Episode 3610, Total Reward: 0
# Episode 3620, Total Reward: 0
# Episode 3630, Total Reward: 0
# Episode 3640, Total Reward: 0
# Episode 3650, Total Reward: 0
# Episode 3660, Total Reward: 0
# Episode 3670, Total Reward: 0
# Episode 3680, Total Reward: 0
# Episode 3690, Total Reward: 0
# Episode 3700, Total Reward: 0
# Episode 3710, Total Reward: 0
# Episode 3720, Total Reward: 1
# Episode 3730, Total Reward: 0
# Episode 3740, Total Reward: 0
# Episode 3750, Total Reward: 0
# Episode 3760, Total Reward: 0
# Episode 3770, Total Reward: 0
# Episode 3780, Total Reward: 1
# Episode 3790, Total Reward: 0
# Episode 3800, Total Reward: 0
# Episode 3810, Total Reward: 0
# Episode 3820, Total Reward: 0
# Episode 3830, Total Reward: 0
# Episode 3840, Total Reward: 0
# Episode 3850, Total Reward: 0
# Episode 3860, Total Reward: 0
# Episode 3870, Total Reward: 0
# Episode 3880, Total Reward: 0
# Episode 3890, Total Reward: 0
# Episode 3900, Total Reward: 0
# Episode 3910, Total Reward: 0
# Episode 3920, Total Reward: 0
# Episode 3930, Total Reward: 0
# Episode 3940, Total Reward: 0
# Episode 3950, Total Reward: 0
# Episode 3960, Total Reward: 0
# Episode 3970, Total Reward: 0
# Episode 3980, Total Reward: 0
# Episode 3990, Total Reward: 0
# Episode 4000, Total Reward: 0
# Episode 4010, Total Reward: 0
# Episode 4020, Total Reward: 0
# Episode 4030, Total Reward: 0
# Episode 4040, Total Reward: 0
# Episode 4050, Total Reward: 0
# Episode 4060, Total Reward: 1
# Episode 4070, Total Reward: 0
# Episode 4080, Total Reward: 0
# Episode 4090, Total Reward: 0
# Episode 4100, Total Reward: 0
# Episode 4110, Total Reward: 0
# Episode 4120, Total Reward: 0
# Episode 4130, Total Reward: 0
# Episode 4140, Total Reward: 0
# Episode 4150, Total Reward: 0
# Episode 4160, Total Reward: 0
# Episode 4170, Total Reward: 0
# Episode 4180, Total Reward: 0
# Episode 4190, Total Reward: 0
# Episode 4200, Total Reward: 0
# Episode 4210, Total Reward: 1
# Episode 4220, Total Reward: 0
# Episode 4230, Total Reward: 0
# Episode 4240, Total Reward: 0
# Episode 4250, Total Reward: 0
# Episode 4260, Total Reward: 0
# Episode 4270, Total Reward: 0
# Episode 4280, Total Reward: 0
# Episode 4290, Total Reward: 0
# Episode 4300, Total Reward: 0
# Episode 4310, Total Reward: 0
# Episode 4320, Total Reward: 0
# Episode 4330, Total Reward: 0
# Episode 4340, Total Reward: 0
# Episode 4350, Total Reward: 0
# Episode 4360, Total Reward: 0
# Episode 4370, Total Reward: 0
# Episode 4380, Total Reward: 0
# Episode 4390, Total Reward: 0
# Episode 4400, Total Reward: 0
# Episode 4410, Total Reward: 0
# Episode 4420, Total Reward: 0
# Episode 4430, Total Reward: 0
# Episode 4440, Total Reward: 0
# Episode 4450, Total Reward: 0
# Episode 4460, Total Reward: 0
# Episode 4470, Total Reward: 0
# Episode 4480, Total Reward: 0
# Episode 4490, Total Reward: 0
# Episode 4500, Total Reward: 0
# Episode 4510, Total Reward: 0
# Episode 4520, Total Reward: 0
# Episode 4530, Total Reward: 0
# Episode 4540, Total Reward: 0
# Episode 4550, Total Reward: 0
# Episode 4560, Total Reward: 1
# Episode 4570, Total Reward: 0
# Episode 4580, Total Reward: 0
# Episode 4590, Total Reward: 0
# Episode 4600, Total Reward: 0
# Episode 4610, Total Reward: 0
# Episode 4620, Total Reward: 0
# Episode 4630, Total Reward: 0
# Episode 4640, Total Reward: 0
# Episode 4650, Total Reward: 0
# Episode 4660, Total Reward: 0
# Episode 4670, Total Reward: 0
# Episode 4680, Total Reward: 0
# Episode 4690, Total Reward: 0
# Episode 4700, Total Reward: 0
# Episode 4710, Total Reward: 0
# Episode 4720, Total Reward: 0
# Episode 4730, Total Reward: 0
# Episode 4740, Total Reward: 0
# Episode 4750, Total Reward: 0
# Episode 4760, Total Reward: 0
# Episode 4770, Total Reward: 0
# Episode 4780, Total Reward: 0
# Episode 4790, Total Reward: 0
# Episode 4800, Total Reward: 1
# Episode 4810, Total Reward: 0
# Episode 4820, Total Reward: 0
# Episode 4830, Total Reward: 0
# Episode 4840, Total Reward: 0
# Episode 4850, Total Reward: 0
# Episode 4860, Total Reward: 0
# Episode 4870, Total Reward: 0
# Episode 4880, Total Reward: 0
# Episode 4890, Total Reward: 0
# Episode 4900, Total Reward: 0
# Episode 4910, Total Reward: 0
# Episode 4920, Total Reward: 0
# Episode 4930, Total Reward: 0
# Episode 4940, Total Reward: 0
# Episode 4950, Total Reward: 0
# Episode 4960, Total Reward: 0
# Episode 4970, Total Reward: 0
# Episode 4980, Total Reward: 1
# Episode 4990, Total Reward: 0
# Episode 5000, Total Reward: 0
# Episode 5010, Total Reward: 0
# Episode 5020, Total Reward: 1
# Episode 5030, Total Reward: 0
# Episode 5040, Total Reward: 0
# Episode 5050, Total Reward: 0
# Episode 5060, Total Reward: 0
# Episode 5070, Total Reward: 0
# Episode 5080, Total Reward: 0
# Episode 5090, Total Reward: 0
# Episode 5100, Total Reward: 0
# Episode 5110, Total Reward: 0
# Episode 5120, Total Reward: 0
# Episode 5130, Total Reward: 0
# Episode 5140, Total Reward: 0
# Episode 5150, Total Reward: 0
# Episode 5160, Total Reward: 0
# Episode 5170, Total Reward: 0
# Episode 5180, Total Reward: 0
# Episode 5190, Total Reward: 0
# Episode 5200, Total Reward: 0
# Episode 5210, Total Reward: 0
# Episode 5220, Total Reward: 0
# Episode 5230, Total Reward: 0
# Episode 5240, Total Reward: 0
# Episode 5250, Total Reward: 0
# Episode 5260, Total Reward: 0
# Episode 5270, Total Reward: 0
# Episode 5280, Total Reward: 0
# Episode 5290, Total Reward: 0
# Episode 5300, Total Reward: 0
# Episode 5310, Total Reward: 0
# Episode 5320, Total Reward: 0
# Episode 5330, Total Reward: 0
# Episode 5340, Total Reward: 0
# Episode 5350, Total Reward: 0
# Episode 5360, Total Reward: 0
# Episode 5370, Total Reward: 0
# Episode 5380, Total Reward: 0
# Episode 5390, Total Reward: 0
# Episode 5400, Total Reward: 1
# Episode 5410, Total Reward: 0
# Episode 5420, Total Reward: 0
# Episode 5430, Total Reward: 0
# Episode 5440, Total Reward: 0
# Episode 5450, Total Reward: 0
# Episode 5460, Total Reward: 0
# Episode 5470, Total Reward: 0
# Episode 5480, Total Reward: 1
# Episode 5490, Total Reward: 0
# Episode 5500, Total Reward: 0
# Episode 5510, Total Reward: 0
# Episode 5520, Total Reward: 0
# Episode 5530, Total Reward: 0
# Episode 5540, Total Reward: 0
# Episode 5550, Total Reward: 0
# Episode 5560, Total Reward: 0
# Episode 5570, Total Reward: 0
# Episode 5580, Total Reward: 0
# Episode 5590, Total Reward: 0
# Episode 5600, Total Reward: 0
# Episode 5610, Total Reward: 0
# Episode 5620, Total Reward: 0
# Episode 5630, Total Reward: 0
# Episode 5640, Total Reward: 0
# Episode 5650, Total Reward: 0
# Episode 5660, Total Reward: 0
# Episode 5670, Total Reward: 0
# Episode 5680, Total Reward: 0
# Episode 5690, Total Reward: 0
# Episode 5700, Total Reward: 0
# Episode 5710, Total Reward: 0
# Episode 5720, Total Reward: 1
# Episode 5730, Total Reward: 0
# Episode 5740, Total Reward: 0
# Episode 5750, Total Reward: 1
# Episode 5760, Total Reward: 0
# Episode 5770, Total Reward: 0
# Episode 5780, Total Reward: 0
# Episode 5790, Total Reward: 0
# Episode 5800, Total Reward: 0
# Episode 5810, Total Reward: 0
# Episode 5820, Total Reward: 0
# Episode 5830, Total Reward: 0
# Episode 5840, Total Reward: 0
# Episode 5850, Total Reward: 0
# Episode 5860, Total Reward: 0
# Episode 5870, Total Reward: 1
# Episode 5880, Total Reward: 0
# Episode 5890, Total Reward: 0
# Episode 5900, Total Reward: 0
# Episode 5910, Total Reward: 0
# Episode 5920, Total Reward: 0
# Episode 5930, Total Reward: 0
# Episode 5940, Total Reward: 0
# Episode 5950, Total Reward: 0
# Episode 5960, Total Reward: 0
# Episode 5970, Total Reward: 0
# Episode 5980, Total Reward: 0
# Episode 5990, Total Reward: 0
# Episode 6000, Total Reward: 0
# Episode 6010, Total Reward: 1
# Episode 6020, Total Reward: 0
# Episode 6030, Total Reward: 0
# Episode 6040, Total Reward: 0
# Episode 6050, Total Reward: 0
# Episode 6060, Total Reward: 0
# Episode 6070, Total Reward: 0
# Episode 6080, Total Reward: 0
# Episode 6090, Total Reward: 0
# Episode 6100, Total Reward: 1
# Episode 6110, Total Reward: 0
# Episode 6120, Total Reward: 0
# Episode 6130, Total Reward: 1
# Episode 6140, Total Reward: 1
# Episode 6150, Total Reward: 0
# Episode 6160, Total Reward: 0
# Episode 6170, Total Reward: 0
# Episode 6180, Total Reward: 0
# Episode 6190, Total Reward: 1
# Episode 6200, Total Reward: 1
# Episode 6210, Total Reward: 0
# Episode 6220, Total Reward: 0
# Episode 6230, Total Reward: 0
# Episode 6240, Total Reward: 0
# Episode 6250, Total Reward: 0
# Episode 6260, Total Reward: 1
# Episode 6270, Total Reward: 0
# Episode 6280, Total Reward: 0
# Episode 6290, Total Reward: 0
# Episode 6300, Total Reward: 0
# Episode 6310, Total Reward: 0
# Episode 6320, Total Reward: 0
# Episode 6330, Total Reward: 0
# Episode 6340, Total Reward: 0
# Episode 6350, Total Reward: 0
# Episode 6360, Total Reward: 0
# Episode 6370, Total Reward: 0
# Episode 6380, Total Reward: 0
# Episode 6390, Total Reward: 0
# Episode 6400, Total Reward: 0
# Episode 6410, Total Reward: 0
# Episode 6420, Total Reward: 1
# Episode 6430, Total Reward: 0
# Episode 6440, Total Reward: 0
# Episode 6450, Total Reward: 0
# Episode 6460, Total Reward: 0
# Episode 6470, Total Reward: 1
# Episode 6480, Total Reward: 0
# Episode 6490, Total Reward: 0
# Episode 6500, Total Reward: 0
# Episode 6510, Total Reward: 0
# Episode 6520, Total Reward: 0
# Episode 6530, Total Reward: 0
# Episode 6540, Total Reward: 0
# Episode 6550, Total Reward: 0
# Episode 6560, Total Reward: 0
# Episode 6570, Total Reward: 0
# Episode 6580, Total Reward: 0
# Episode 6590, Total Reward: 0
# Episode 6600, Total Reward: 0
# Episode 6610, Total Reward: 0
# Episode 6620, Total Reward: 0
# Episode 6630, Total Reward: 0
# Episode 6640, Total Reward: 0
# Episode 6650, Total Reward: 0
# Episode 6660, Total Reward: 0
# Episode 6670, Total Reward: 0
# Episode 6680, Total Reward: 0
# Episode 6690, Total Reward: 0
# Episode 6700, Total Reward: 0
# Episode 6710, Total Reward: 0
# Episode 6720, Total Reward: 0
# Episode 6730, Total Reward: 1
# Episode 6740, Total Reward: 0
# Episode 6750, Total Reward: 1
# Episode 6760, Total Reward: 0
# Episode 6770, Total Reward: 0
# Episode 6780, Total Reward: 0
# Episode 6790, Total Reward: 0
# Episode 6800, Total Reward: 0
# Episode 6810, Total Reward: 0
# Episode 6820, Total Reward: 0
# Episode 6830, Total Reward: 1
# Episode 6840, Total Reward: 1
# Episode 6850, Total Reward: 0
# Episode 6860, Total Reward: 0
# Episode 6870, Total Reward: 0
# Episode 6880, Total Reward: 1
# Episode 6890, Total Reward: 0
# Episode 6900, Total Reward: 0
# Episode 6910, Total Reward: 0
# Episode 6920, Total Reward: 0
# Episode 6930, Total Reward: 0
# Episode 6940, Total Reward: 1
# Episode 6950, Total Reward: 0
# Episode 6960, Total Reward: 0
# Episode 6970, Total Reward: 0
# Episode 6980, Total Reward: 0
# Episode 6990, Total Reward: 1
# Episode 7000, Total Reward: 0
# Episode 7010, Total Reward: 1
# Episode 7020, Total Reward: 0
# Episode 7030, Total Reward: 1
# Episode 7040, Total Reward: 0
# Episode 7050, Total Reward: 0
# Episode 7060, Total Reward: 0
# Episode 7070, Total Reward: 0
# Episode 7080, Total Reward: 1
# Episode 7090, Total Reward: 0
# Episode 7100, Total Reward: 0
# Episode 7110, Total Reward: 1
# Episode 7120, Total Reward: 0
# Episode 7130, Total Reward: 0
# Episode 7140, Total Reward: 0
# Episode 7150, Total Reward: 0
# Episode 7160, Total Reward: 0
# Episode 7170, Total Reward: 1
# Episode 7180, Total Reward: 0
# Episode 7190, Total Reward: 0
# Episode 7200, Total Reward: 0
# Episode 7210, Total Reward: 0
# Episode 7220, Total Reward: 0
# Episode 7230, Total Reward: 0
# Episode 7240, Total Reward: 0
# Episode 7250, Total Reward: 0
# Episode 7260, Total Reward: 0
# Episode 7270, Total Reward: 0
# Episode 7280, Total Reward: 0
# Episode 7290, Total Reward: 0
# Episode 7300, Total Reward: 0
# Episode 7310, Total Reward: 0
# Episode 7320, Total Reward: 0
# Episode 7330, Total Reward: 1
# Episode 7340, Total Reward: 0
# Episode 7350, Total Reward: 0
# Episode 7360, Total Reward: 0
# Episode 7370, Total Reward: 0
# Episode 7380, Total Reward: 0
# Episode 7390, Total Reward: 0
# Episode 7400, Total Reward: 0
# Episode 7410, Total Reward: 0
# Episode 7420, Total Reward: 0
# Episode 7430, Total Reward: 0
# Episode 7440, Total Reward: 0
# Episode 7450, Total Reward: 0
# Episode 7460, Total Reward: 0
# Episode 7470, Total Reward: 0
# Episode 7480, Total Reward: 0
# Episode 7490, Total Reward: 0
# Episode 7500, Total Reward: 0
# Episode 7510, Total Reward: 0
# Episode 7520, Total Reward: 0
# Episode 7530, Total Reward: 0
# Episode 7540, Total Reward: 0
# Episode 7550, Total Reward: 0
# Episode 7560, Total Reward: 0
# Episode 7570, Total Reward: 1
# Episode 7580, Total Reward: 0
# Episode 7590, Total Reward: 1
# Episode 7600, Total Reward: 1
# Episode 7610, Total Reward: 0
# Episode 7620, Total Reward: 0
# Episode 7630, Total Reward: 0
# Episode 7640, Total Reward: 0
# Episode 7650, Total Reward: 0
# Episode 7660, Total Reward: 0
# Episode 7670, Total Reward: 0
# Episode 7680, Total Reward: 1
# Episode 7690, Total Reward: 1
# Episode 7700, Total Reward: 0
# Episode 7710, Total Reward: 0
# Episode 7720, Total Reward: 1
# Episode 7730, Total Reward: 0
# Episode 7740, Total Reward: 1
# Episode 7750, Total Reward: 0
# Episode 7760, Total Reward: 1
# Episode 7770, Total Reward: 0
# Episode 7780, Total Reward: 1
# Episode 7790, Total Reward: 0
# Episode 7800, Total Reward: 1
# Episode 7810, Total Reward: 0
# Episode 7820, Total Reward: 0
# Episode 7830, Total Reward: 0
# Episode 7840, Total Reward: 0
# Episode 7850, Total Reward: 0
# Episode 7860, Total Reward: 0
# Episode 7870, Total Reward: 0
# Episode 7880, Total Reward: 0
# Episode 7890, Total Reward: 0
# Episode 7900, Total Reward: 0
# Episode 7910, Total Reward: 1
# Episode 7920, Total Reward: 0
# Episode 7930, Total Reward: 1
# Episode 7940, Total Reward: 0
# Episode 7950, Total Reward: 1
# Episode 7960, Total Reward: 0
# Episode 7970, Total Reward: 1
# Episode 7980, Total Reward: 1
# Episode 7990, Total Reward: 0
# Episode 8000, Total Reward: 0
# Episode 8010, Total Reward: 0
# Episode 8020, Total Reward: 0
# Episode 8030, Total Reward: 0
# Episode 8040, Total Reward: 0
# Episode 8050, Total Reward: 1
# Episode 8060, Total Reward: 0
# Episode 8070, Total Reward: 0
# Episode 8080, Total Reward: 0
# Episode 8090, Total Reward: 0
# Episode 8100, Total Reward: 0
# Episode 8110, Total Reward: 0
# Episode 8120, Total Reward: 0
# Episode 8130, Total Reward: 1
# Episode 8140, Total Reward: 1
# Episode 8150, Total Reward: 1
# Episode 8160, Total Reward: 0
# Episode 8170, Total Reward: 0
# Episode 8180, Total Reward: 0
# Episode 8190, Total Reward: 0
# Episode 8200, Total Reward: 1
# Episode 8210, Total Reward: 0
# Episode 8220, Total Reward: 0
# Episode 8230, Total Reward: 1
# Episode 8240, Total Reward: 0
# Episode 8250, Total Reward: 0
# Episode 8260, Total Reward: 1
# Episode 8270, Total Reward: 0
# Episode 8280, Total Reward: 0
# Episode 8290, Total Reward: 1
# Episode 8300, Total Reward: 1
# Episode 8310, Total Reward: 0
# Episode 8320, Total Reward: 0
# Episode 8330, Total Reward: 0
# Episode 8340, Total Reward: 0
# Episode 8350, Total Reward: 0
# Episode 8360, Total Reward: 0
# Episode 8370, Total Reward: 0
# Episode 8380, Total Reward: 0
# Episode 8390, Total Reward: 0
# Episode 8400, Total Reward: 0
# Episode 8410, Total Reward: 0
# Episode 8420, Total Reward: 0
# Episode 8430, Total Reward: 1
# Episode 8440, Total Reward: 1
# Episode 8450, Total Reward: 0
# Episode 8460, Total Reward: 1
# Episode 8470, Total Reward: 0
# Episode 8480, Total Reward: 1
# Episode 8490, Total Reward: 1
# Episode 8500, Total Reward: 0
# Episode 8510, Total Reward: 0
# Episode 8520, Total Reward: 0
# Episode 8530, Total Reward: 1
# Episode 8540, Total Reward: 0
# Episode 8550, Total Reward: 0
# Episode 8560, Total Reward: 0
# Episode 8570, Total Reward: 1
# Episode 8580, Total Reward: 0
# Episode 8590, Total Reward: 0
# Episode 8600, Total Reward: 1
# Episode 8610, Total Reward: 1
# Episode 8620, Total Reward: 0
# Episode 8630, Total Reward: 0
# Episode 8640, Total Reward: 0
# Episode 8650, Total Reward: 0
# Episode 8660, Total Reward: 0
# Episode 8670, Total Reward: 1
# Episode 8680, Total Reward: 0
# Episode 8690, Total Reward: 0
# Episode 8700, Total Reward: 0
# Episode 8710, Total Reward: 0
# Episode 8720, Total Reward: 0
# Episode 8730, Total Reward: 1
# Episode 8740, Total Reward: 0
# Episode 8750, Total Reward: 1
# Episode 8760, Total Reward: 0
# Episode 8770, Total Reward: 0
# Episode 8780, Total Reward: 0
# Episode 8790, Total Reward: 0
# Episode 8800, Total Reward: 0
# Episode 8810, Total Reward: 0
# Episode 8820, Total Reward: 0
# Episode 8830, Total Reward: 0
# Episode 8840, Total Reward: 1
# Episode 8850, Total Reward: 1
# Episode 8860, Total Reward: 0
# Episode 8870, Total Reward: 0
# Episode 8880, Total Reward: 0
# Episode 8890, Total Reward: 0
# Episode 8900, Total Reward: 0
# Episode 8910, Total Reward: 0
# Episode 8920, Total Reward: 0
# Episode 8930, Total Reward: 0
# Episode 8940, Total Reward: 0
# Episode 8950, Total Reward: 0
# Episode 8960, Total Reward: 0
# Episode 8970, Total Reward: 1
# Episode 8980, Total Reward: 0
# Episode 8990, Total Reward: 0
# Episode 9000, Total Reward: 0
# Episode 9010, Total Reward: 0
# Episode 9020, Total Reward: 0
# Episode 9030, Total Reward: 1
# Episode 9040, Total Reward: 0
# Episode 9050, Total Reward: 1
# Episode 9060, Total Reward: 0
# Episode 9070, Total Reward: 0
# Episode 9080, Total Reward: 1
# Episode 9090, Total Reward: 0
# Episode 9100, Total Reward: 0
# Episode 9110, Total Reward: 0
# Episode 9120, Total Reward: 1
# Episode 9130, Total Reward: 1
# Episode 9140, Total Reward: 0
# Episode 9150, Total Reward: 0
# Episode 9160, Total Reward: 0
# Episode 9170, Total Reward: 0
# Episode 9180, Total Reward: 1
# Episode 9190, Total Reward: 0
# Episode 9200, Total Reward: 0
# Episode 9210, Total Reward: 1
# Episode 9220, Total Reward: 0
# Episode 9230, Total Reward: 0
# Episode 9240, Total Reward: 0
# Episode 9250, Total Reward: 0
# Episode 9260, Total Reward: 1
# Episode 9270, Total Reward: 0
# Episode 9280, Total Reward: 0
# Episode 9290, Total Reward: 0
# Episode 9300, Total Reward: 0
# Episode 9310, Total Reward: 1
# Episode 9320, Total Reward: 0
# Episode 9330, Total Reward: 0
# Episode 9340, Total Reward: 0
# Episode 9350, Total Reward: 0
# Episode 9360, Total Reward: 0
# Episode 9370, Total Reward: 0
# Episode 9380, Total Reward: 1
# Episode 9390, Total Reward: 0
# Episode 9400, Total Reward: 0
# Episode 9410, Total Reward: 0
# Episode 9420, Total Reward: 1
# Episode 9430, Total Reward: 1
# Episode 9440, Total Reward: 0
# Episode 9450, Total Reward: 0
# Episode 9460, Total Reward: 1
# Episode 9470, Total Reward: 0
# Episode 9480, Total Reward: 0
# Episode 9490, Total Reward: 1
# Episode 9500, Total Reward: 0
# Episode 9510, Total Reward: 0
# Episode 9520, Total Reward: 0
# Episode 9530, Total Reward: 0
# Episode 9540, Total Reward: 0
# Episode 9550, Total Reward: 0
# Episode 9560, Total Reward: 1
# Episode 9570, Total Reward: 0
# Episode 9580, Total Reward: 0
# Episode 9590, Total Reward: 0
# Episode 9600, Total Reward: 1
# Episode 9610, Total Reward: 0
# Episode 9620, Total Reward: 0
# Episode 9630, Total Reward: 0
# Episode 9640, Total Reward: 0
# Episode 9650, Total Reward: 0
# Episode 9660, Total Reward: 0
# Episode 9670, Total Reward: 0
# Episode 9680, Total Reward: 0
# Episode 9690, Total Reward: 1
# Episode 9700, Total Reward: 1
# Episode 9710, Total Reward: 0
# Episode 9720, Total Reward: 0
# Episode 9730, Total Reward: 0
# Episode 9740, Total Reward: 0
# Episode 9750, Total Reward: 0
# Episode 9760, Total Reward: 0
# Episode 9770, Total Reward: 1
# Episode 9780, Total Reward: 0
# Episode 9790, Total Reward: 0
# Episode 9800, Total Reward: 0
# Episode 9810, Total Reward: 0
# Episode 9820, Total Reward: 0
# Episode 9830, Total Reward: 0
# Episode 9840, Total Reward: 0
# Episode 9850, Total Reward: 1
# Episode 9860, Total Reward: 0
# Episode 9870, Total Reward: 1
# Episode 9880, Total Reward: 1
# Episode 9890, Total Reward: 0
# Episode 9900, Total Reward: 0
# Episode 9910, Total Reward: 0
# Episode 9920, Total Reward: 0
# Episode 9930, Total Reward: 0
# Episode 9940, Total Reward: 0
# Episode 9950, Total Reward: 0
# Episode 9960, Total Reward: 0
# Episode 9970, Total Reward: 1
# Episode 9980, Total Reward: 1
# Episode 9990, Total Reward: 0
# Episode 10000, Total Reward: 0
# Episode 10010, Total Reward: 0
# Episode 10020, Total Reward: 1
# Episode 10030, Total Reward: 0
# Episode 10040, Total Reward: 1
# Episode 10050, Total Reward: 0
# Episode 10060, Total Reward: 0
# Episode 10070, Total Reward: 1
# Episode 10080, Total Reward: 0
# Episode 10090, Total Reward: 1
# Episode 10100, Total Reward: 0
# Episode 10110, Total Reward: 0
# Episode 10120, Total Reward: 0
# Episode 10130, Total Reward: 1
# Episode 10140, Total Reward: 1
# Episode 10150, Total Reward: 0
# Episode 10160, Total Reward: 0
# Episode 10170, Total Reward: 0
# Episode 10180, Total Reward: 0
# Episode 10190, Total Reward: 1
# Episode 10200, Total Reward: 1
# Episode 10210, Total Reward: 0
# Episode 10220, Total Reward: 0
# Episode 10230, Total Reward: 0
# Episode 10240, Total Reward: 0
# Episode 10250, Total Reward: 0
# Episode 10260, Total Reward: 0
# Episode 10270, Total Reward: 1
# Episode 10280, Total Reward: 0
# Episode 10290, Total Reward: 0
# Episode 10300, Total Reward: 1
# Episode 10310, Total Reward: 1
# Episode 10320, Total Reward: 0
# Episode 10330, Total Reward: 0
# Episode 10340, Total Reward: 1
# Episode 10350, Total Reward: 0
# Episode 10360, Total Reward: 0
# Episode 10370, Total Reward: 0
# Episode 10380, Total Reward: 0
# Episode 10390, Total Reward: 0
# Episode 10400, Total Reward: 1
# Episode 10410, Total Reward: 0
# Episode 10420, Total Reward: 0
# Episode 10430, Total Reward: 1
# Episode 10440, Total Reward: 0
# Episode 10450, Total Reward: 1
# Episode 10460, Total Reward: 0
# Episode 10470, Total Reward: 0
# Episode 10480, Total Reward: 0
# Episode 10490, Total Reward: 0
# Episode 10500, Total Reward: 0
# Episode 10510, Total Reward: 0
# Episode 10520, Total Reward: 0
# Episode 10530, Total Reward: 0
# Episode 10540, Total Reward: 1
# Episode 10550, Total Reward: 1
# Episode 10560, Total Reward: 0
# Episode 10570, Total Reward: 0
# Episode 10580, Total Reward: 0
# Episode 10590, Total Reward: 1
# Episode 10600, Total Reward: 1
# Episode 10610, Total Reward: 0
# Episode 10620, Total Reward: 1
# Episode 10630, Total Reward: 0
# Episode 10640, Total Reward: 1
# Episode 10650, Total Reward: 1
# Episode 10660, Total Reward: 1
# Episode 10670, Total Reward: 0
# Episode 10680, Total Reward: 1
# Episode 10690, Total Reward: 1
# Episode 10700, Total Reward: 0
# Episode 10710, Total Reward: 1
# Episode 10720, Total Reward: 0
# Episode 10730, Total Reward: 0
# Episode 10740, Total Reward: 0
# Episode 10750, Total Reward: 0
# Episode 10760, Total Reward: 0
# Episode 10770, Total Reward: 1
# Episode 10780, Total Reward: 1
# Episode 10790, Total Reward: 2
# Episode 10800, Total Reward: 0
# Episode 10810, Total Reward: 0
# Episode 10820, Total Reward: 1
# Episode 10830, Total Reward: 1
# Episode 10840, Total Reward: 0
# Episode 10850, Total Reward: 1
# Episode 10860, Total Reward: 0
# Episode 10870, Total Reward: 1
# Episode 10880, Total Reward: 0
# Episode 10890, Total Reward: 1
# Episode 10900, Total Reward: 1
# Episode 10910, Total Reward: 1
# Episode 10920, Total Reward: 1
# Episode 10930, Total Reward: 1
# Episode 10940, Total Reward: 1
# Episode 10950, Total Reward: 1
# Episode 10960, Total Reward: 1
# Episode 10970, Total Reward: 1
# Episode 10980, Total Reward: 0
# Episode 10990, Total Reward: 0
# Episode 11000, Total Reward: 0
# Episode 11010, Total Reward: 0
# Episode 11020, Total Reward: 0
# Episode 11030, Total Reward: 1
# Episode 11040, Total Reward: 1
# Episode 11050, Total Reward: 1
# Episode 11060, Total Reward: 1
# Episode 11070, Total Reward: 0
# Episode 11080, Total Reward: 0
# Episode 11090, Total Reward: 0
# Episode 11100, Total Reward: 1
# Episode 11110, Total Reward: 0
# Episode 11120, Total Reward: 1
# Episode 11130, Total Reward: 1
# Episode 11140, Total Reward: 0
# Episode 11150, Total Reward: 1
# Episode 11160, Total Reward: 1
# Episode 11170, Total Reward: 1
# Episode 11180, Total Reward: 0
# Episode 11190, Total Reward: 1
# Episode 11200, Total Reward: 0
# Episode 11210, Total Reward: 1
# Episode 11220, Total Reward: 1
# Episode 11230, Total Reward: 1
# Episode 11240, Total Reward: 0
# Episode 11250, Total Reward: 1
# Episode 11260, Total Reward: 0
# Episode 11270, Total Reward: 1
# Episode 11280, Total Reward: 1
# Episode 11290, Total Reward: 1
# Episode 11300, Total Reward: 0
# Episode 11310, Total Reward: 1
# Episode 11320, Total Reward: 1
# Episode 11330, Total Reward: 1
# Episode 11340, Total Reward: 0
# Episode 11350, Total Reward: 1
# Episode 11360, Total Reward: 0
# Episode 11370, Total Reward: 0
# Episode 11380, Total Reward: 1
# Episode 11390, Total Reward: 0
# Episode 11400, Total Reward: 1
# Episode 11410, Total Reward: 1
# Episode 11420, Total Reward: 1
# Episode 11430, Total Reward: 1
# Episode 11440, Total Reward: 1
# Episode 11450, Total Reward: 0
# Episode 11460, Total Reward: 0
# Episode 11470, Total Reward: 1
# Episode 11480, Total Reward: 1
# Episode 11490, Total Reward: 1
# Episode 11500, Total Reward: 1
# Episode 11510, Total Reward: 1
# Episode 11520, Total Reward: 0
# Episode 11530, Total Reward: 1
# Episode 11540, Total Reward: 1
# Episode 11550, Total Reward: 0
# Episode 11560, Total Reward: 0
# Episode 11570, Total Reward: 0
# Episode 11580, Total Reward: 1
# Episode 11590, Total Reward: 1
# Episode 11600, Total Reward: 0
# Episode 11610, Total Reward: 1
# Episode 11620, Total Reward: 0
# Episode 11630, Total Reward: 0
# Episode 11640, Total Reward: 1
# Episode 11650, Total Reward: 1
# Episode 11660, Total Reward: 0
# Episode 11670, Total Reward: 1
# Episode 11680, Total Reward: 1
# Episode 11690, Total Reward: 1
# Episode 11700, Total Reward: 1
# Episode 11710, Total Reward: 0
# Episode 11720, Total Reward: 0
# Episode 11730, Total Reward: 1
# Episode 11740, Total Reward: 0
# Episode 11750, Total Reward: 1
# Episode 11760, Total Reward: 0
# Episode 11770, Total Reward: 0
# Episode 11780, Total Reward: 0
# Episode 11790, Total Reward: 1
# Episode 11800, Total Reward: 1
# Episode 11810, Total Reward: 1
# Episode 11820, Total Reward: 1
# Episode 11830, Total Reward: 0
# Episode 11840, Total Reward: 0
# Episode 11850, Total Reward: 1
# Episode 11860, Total Reward: 1
# Episode 11870, Total Reward: 0
# Episode 11880, Total Reward: 1
# Episode 11890, Total Reward: 1
# Episode 11900, Total Reward: 0
# Episode 11910, Total Reward: 1
# Episode 11920, Total Reward: 1
# Episode 11930, Total Reward: 1
# Episode 11940, Total Reward: 1
# Episode 11950, Total Reward: 1
# Episode 11960, Total Reward: 0
# Episode 11970, Total Reward: 1
# Episode 11980, Total Reward: 1
# Episode 11990, Total Reward: 0
# Episode 12000, Total Reward: 1
# Episode 12010, Total Reward: 1
# Episode 12020, Total Reward: 0
# Episode 12030, Total Reward: 0
# Episode 12040, Total Reward: 0
# Episode 12050, Total Reward: 0
# Episode 12060, Total Reward: 0
# Episode 12070, Total Reward: 0
# Episode 12080, Total Reward: 0
# Episode 12090, Total Reward: 0
# Episode 12100, Total Reward: 1
# Episode 12110, Total Reward: 1
# Episode 12120, Total Reward: 0
# Episode 12130, Total Reward: 0
# Episode 12140, Total Reward: 1
# Episode 12150, Total Reward: 2
# Episode 12160, Total Reward: 0
# Episode 12170, Total Reward: 0
# Episode 12180, Total Reward: 1
# Episode 12190, Total Reward: 1
# Episode 12200, Total Reward: 1
# Episode 12210, Total Reward: 1
# Episode 12220, Total Reward: 0
# Episode 12230, Total Reward: 1
# Episode 12240, Total Reward: 0
# Episode 12250, Total Reward: 1
# Episode 12260, Total Reward: 0
# Episode 12270, Total Reward: 1
# Episode 12280, Total Reward: 0
# Episode 12290, Total Reward: 1
# Episode 12300, Total Reward: 0
# Episode 12310, Total Reward: 0
# Episode 12320, Total Reward: 0
# Episode 12330, Total Reward: 0
# Episode 12340, Total Reward: 0
# Episode 12350, Total Reward: 0
# Episode 12360, Total Reward: 1
# Episode 12370, Total Reward: 0
# Episode 12380, Total Reward: 1
# Episode 12390, Total Reward: 0
# Episode 12400, Total Reward: 0
# Episode 12410, Total Reward: 1
# Episode 12420, Total Reward: 1
# Episode 12430, Total Reward: 1
# Episode 12440, Total Reward: 0
# Episode 12450, Total Reward: 1
# Episode 12460, Total Reward: 1
# Episode 12470, Total Reward: 0
# Episode 12480, Total Reward: 1
# Episode 12490, Total Reward: 2
# Episode 12500, Total Reward: 0
# Episode 12510, Total Reward: 0
# Episode 12520, Total Reward: 1
# Episode 12530, Total Reward: 1
# Episode 12540, Total Reward: 0
# Episode 12550, Total Reward: 1
# Episode 12560, Total Reward: 0
# Episode 12570, Total Reward: 1
# Episode 12580, Total Reward: 1
# Episode 12590, Total Reward: 0
# Episode 12600, Total Reward: 1
# Episode 12610, Total Reward: 1
# Episode 12620, Total Reward: 1
# Episode 12630, Total Reward: 1
# Episode 12640, Total Reward: 0
# Episode 12650, Total Reward: 0
# Episode 12660, Total Reward: 1
# Episode 12670, Total Reward: 0
# Episode 12680, Total Reward: 0
# Episode 12690, Total Reward: 1
# Episode 12700, Total Reward: 1
# Episode 12710, Total Reward: 0
# Episode 12720, Total Reward: 0
# Episode 12730, Total Reward: 0
# Episode 12740, Total Reward: 1
# Episode 12750, Total Reward: 1
# Episode 12760, Total Reward: 1
# Episode 12770, Total Reward: 1
# Episode 12780, Total Reward: 0
# Episode 12790, Total Reward: 1
# Episode 12800, Total Reward: 0
# Episode 12810, Total Reward: 1
# Episode 12820, Total Reward: 1
# Episode 12830, Total Reward: 1
# Episode 12840, Total Reward: 1
# Episode 12850, Total Reward: 1
# Episode 12860, Total Reward: 1
# Episode 12870, Total Reward: 1
# Episode 12880, Total Reward: 1
# Episode 12890, Total Reward: 1
# Episode 12900, Total Reward: 1
# Episode 12910, Total Reward: 0
# Episode 12920, Total Reward: 0
# Episode 12930, Total Reward: 1
# Episode 12940, Total Reward: 0
# Episode 12950, Total Reward: 1
# Episode 12960, Total Reward: 0
# Episode 12970, Total Reward: 2
# Episode 12980, Total Reward: 0
# Episode 12990, Total Reward: 1
# Episode 13000, Total Reward: 1
# Episode 13010, Total Reward: 1
# Episode 13020, Total Reward: 1
# Episode 13030, Total Reward: 0
# Episode 13040, Total Reward: 1
# Episode 13050, Total Reward: 1
# Episode 13060, Total Reward: 0
# Episode 13070, Total Reward: 1
# Episode 13080, Total Reward: 1
# Episode 13090, Total Reward: 1
# Episode 13100, Total Reward: 1
# Episode 13110, Total Reward: 1
# Episode 13120, Total Reward: 0
# Episode 13130, Total Reward: 1
# Episode 13140, Total Reward: 0
# Episode 13150, Total Reward: 1
# Episode 13160, Total Reward: 1
# Episode 13170, Total Reward: 0
# Episode 13180, Total Reward: 1
# Episode 13190, Total Reward: 1
# Episode 13200, Total Reward: 1
# Episode 13210, Total Reward: 1
# Episode 13220, Total Reward: 1
# Episode 13230, Total Reward: 1
# Episode 13240, Total Reward: 1
# Episode 13250, Total Reward: 1
# Episode 13260, Total Reward: 1
# Episode 13270, Total Reward: 1
# Episode 13280, Total Reward: 1
# Episode 13290, Total Reward: 1
# Episode 13300, Total Reward: 0
# Episode 13310, Total Reward: 2
# Episode 13320, Total Reward: 1
# Episode 13330, Total Reward: 1
# Episode 13340, Total Reward: 0
# Episode 13350, Total Reward: 1
# Episode 13360, Total Reward: 1
# Episode 13370, Total Reward: 1
# Episode 13380, Total Reward: 1
# Episode 13390, Total Reward: 1
# Episode 13400, Total Reward: 0
# Episode 13410, Total Reward: 1
# Episode 13420, Total Reward: 2
# Episode 13430, Total Reward: 0
# Episode 13440, Total Reward: 0
# Episode 13450, Total Reward: 0
# Episode 13460, Total Reward: 1
# Episode 13470, Total Reward: 0
# Episode 13480, Total Reward: 0
# Episode 13490, Total Reward: 1
# Episode 13500, Total Reward: 1
# Episode 13510, Total Reward: 2
# Episode 13520, Total Reward: 0
# Episode 13530, Total Reward: 1
# Episode 13540, Total Reward: 1
# Episode 13550, Total Reward: 1
# Episode 13560, Total Reward: 1
# Episode 13570, Total Reward: 0
# Episode 13580, Total Reward: 0
# Episode 13590, Total Reward: 1
# Episode 13600, Total Reward: 1
# Episode 13610, Total Reward: 1
# Episode 13620, Total Reward: 1
# Episode 13630, Total Reward: 1
# Episode 13640, Total Reward: 1
# Episode 13650, Total Reward: 1
# Episode 13660, Total Reward: 0
# Episode 13670, Total Reward: 0
# Episode 13680, Total Reward: 0
# Episode 13690, Total Reward: 0
# Episode 13700, Total Reward: 1
# Episode 13710, Total Reward: 1
# Episode 13720, Total Reward: 1
# Episode 13730, Total Reward: 0
# Episode 13740, Total Reward: 1
# Episode 13750, Total Reward: 1
# Episode 13760, Total Reward: 1
# Episode 13770, Total Reward: 1
# Episode 13780, Total Reward: 2
# Episode 13790, Total Reward: 1
# Episode 13800, Total Reward: 1
# Episode 13810, Total Reward: 0
# Episode 13820, Total Reward: 1
# Episode 13830, Total Reward: 1
# Episode 13840, Total Reward: 1
# Episode 13850, Total Reward: 0
# Episode 13860, Total Reward: 1
# Episode 13870, Total Reward: 0
# Episode 13880, Total Reward: 1
# Episode 13890, Total Reward: 1
# Episode 13900, Total Reward: 1
# Episode 13910, Total Reward: 1
# Episode 13920, Total Reward: 1
# Episode 13930, Total Reward: 1
# Episode 13940, Total Reward: 0
# Episode 13950, Total Reward: 1
# Episode 13960, Total Reward: 1
# Episode 13970, Total Reward: 1
# Episode 13980, Total Reward: 0
# Episode 13990, Total Reward: 1
# Episode 14000, Total Reward: 0
# Episode 14010, Total Reward: 2
# Episode 14020, Total Reward: 2
# Episode 14030, Total Reward: 1
# Episode 14040, Total Reward: 2
# Episode 14050, Total Reward: 1
# Episode 14060, Total Reward: 2
# Episode 14070, Total Reward: 1
# Episode 14080, Total Reward: 1
# Episode 14090, Total Reward: 0
# Episode 14100, Total Reward: 0
# Episode 14110, Total Reward: 1
# Episode 14120, Total Reward: 0
# Episode 14130, Total Reward: 0
# Episode 14140, Total Reward: 1
# Episode 14150, Total Reward: 1
# Episode 14160, Total Reward: 0
# Episode 14170, Total Reward: 1
# Episode 14180, Total Reward: 0
# Episode 14190, Total Reward: 1
# Episode 14200, Total Reward: 1
# Episode 14210, Total Reward: 0
# Episode 14220, Total Reward: 1
# Episode 14230, Total Reward: 0
# Episode 14240, Total Reward: 1
# Episode 14250, Total Reward: 0
# Episode 14260, Total Reward: 1
# Episode 14270, Total Reward: 0
# Episode 14280, Total Reward: 1
# Episode 14290, Total Reward: 1
# Episode 14300, Total Reward: 0
# Episode 14310, Total Reward: 1
# Episode 14320, Total Reward: 0
# Episode 14330, Total Reward: 1
# Episode 14340, Total Reward: 1
# Episode 14350, Total Reward: 1
# Episode 14360, Total Reward: 1
# Episode 14370, Total Reward: 1
# Episode 14380, Total Reward: 0
# Episode 14390, Total Reward: 0
# Episode 14400, Total Reward: 0
# Episode 14410, Total Reward: 1
# Episode 14420, Total Reward: 2
# Episode 14430, Total Reward: 0
# Episode 14440, Total Reward: 0
# Episode 14450, Total Reward: 1
# Episode 14460, Total Reward: 1
# Episode 14470, Total Reward: 1
# Episode 14480, Total Reward: 0
# Episode 14490, Total Reward: 1
# Episode 14500, Total Reward: 1
# Episode 14510, Total Reward: 0
# Episode 14520, Total Reward: 1
# Episode 14530, Total Reward: 1
# Episode 14540, Total Reward: 0
# Episode 14550, Total Reward: 0
# Episode 14560, Total Reward: 1
# Episode 14570, Total Reward: 0
# Episode 14580, Total Reward: 1
# Episode 14590, Total Reward: 1
# Episode 14600, Total Reward: 1
# Episode 14610, Total Reward: 1
# Episode 14620, Total Reward: 1
# Episode 14630, Total Reward: 0
# Episode 14640, Total Reward: 0
# Episode 14650, Total Reward: 0
# Episode 14660, Total Reward: 1
# Episode 14670, Total Reward: 1
# Episode 14680, Total Reward: 0
# Episode 14690, Total Reward: 1
# Episode 14700, Total Reward: 1
# Episode 14710, Total Reward: 1
# Episode 14720, Total Reward: 1
# Episode 14730, Total Reward: 0
# Episode 14740, Total Reward: 0
# Episode 14750, Total Reward: 1
# Episode 14760, Total Reward: 0
# Episode 14770, Total Reward: 1
# Episode 14780, Total Reward: 1
# Episode 14790, Total Reward: 2
# Episode 14800, Total Reward: 1
# Episode 14810, Total Reward: 1
# Episode 14820, Total Reward: 1
# Episode 14830, Total Reward: 1
# Episode 14840, Total Reward: 1
# Episode 14850, Total Reward: 0
# Episode 14860, Total Reward: 0
# Episode 14870, Total Reward: 1
# Episode 14880, Total Reward: 1
# Episode 14890, Total Reward: 1
# Episode 14900, Total Reward: 1
# Episode 14910, Total Reward: 0
# Episode 14920, Total Reward: 1
# Episode 14930, Total Reward: 2
# Episode 14940, Total Reward: 0
# Episode 14950, Total Reward: 1
# Episode 14960, Total Reward: 1
# Episode 14970, Total Reward: 1
# Episode 14980, Total Reward: 0
# Episode 14990, Total Reward: 1
# Episode 15000, Total Reward: 1
# Episode 15010, Total Reward: 1
# Episode 15020, Total Reward: 0
# Episode 15030, Total Reward: 1
# Episode 15040, Total Reward: 0
# Episode 15050, Total Reward: 0
# Episode 15060, Total Reward: 0
# Episode 15070, Total Reward: 1
# Episode 15080, Total Reward: 0
# Episode 15090, Total Reward: 0
# Episode 15100, Total Reward: 1
# Episode 15110, Total Reward: 0
# Episode 15120, Total Reward: 0
# Episode 15130, Total Reward: 0
# Episode 15140, Total Reward: 1
# Episode 15150, Total Reward: 1
# Episode 15160, Total Reward: 2
# Episode 15170, Total Reward: 1
# Episode 15180, Total Reward: 1
# Episode 15190, Total Reward: 1
# Episode 15200, Total Reward: 1
# Episode 15210, Total Reward: 1
# Episode 15220, Total Reward: 1
# Episode 15230, Total Reward: 1
# Episode 15240, Total Reward: 0
# Episode 15250, Total Reward: 1
# Episode 15260, Total Reward: 0
# Episode 15270, Total Reward: 0
# Episode 15280, Total Reward: 1
# Episode 15290, Total Reward: 0
# Episode 15300, Total Reward: 2
# Episode 15310, Total Reward: 1
# Episode 15320, Total Reward: 0
# Episode 15330, Total Reward: 1
# Episode 15340, Total Reward: 2
# Episode 15350, Total Reward: 1
# Episode 15360, Total Reward: 2
# Episode 15370, Total Reward: 1
# Episode 15380, Total Reward: 0
# Episode 15390, Total Reward: 1
# Episode 15400, Total Reward: 1
# Episode 15410, Total Reward: 0
# Episode 15420, Total Reward: 1
# Episode 15430, Total Reward: 2
# Episode 15440, Total Reward: 1
# Episode 15450, Total Reward: 1
# Episode 15460, Total Reward: 1
# Episode 15470, Total Reward: 1
# Episode 15480, Total Reward: 1
# Episode 15490, Total Reward: 1
# Episode 15500, Total Reward: 0
# Episode 15510, Total Reward: 0
# Episode 15520, Total Reward: 1
# Episode 15530, Total Reward: 1
# Episode 15540, Total Reward: 1
# Episode 15550, Total Reward: 1
# Episode 15560, Total Reward: 0
# Episode 15570, Total Reward: 1
# Episode 15580, Total Reward: 1
# Episode 15590, Total Reward: 0
# Episode 15600, Total Reward: 1
# Episode 15610, Total Reward: 2
# Episode 15620, Total Reward: 1
# Episode 15630, Total Reward: 1
# Episode 15640, Total Reward: 1
# Episode 15650, Total Reward: 0
# Episode 15660, Total Reward: 1
# Episode 15670, Total Reward: 1
# Episode 15680, Total Reward: 1
# Episode 15690, Total Reward: 1
# Episode 15700, Total Reward: 1
# Episode 15710, Total Reward: 0
# Episode 15720, Total Reward: 2
# Episode 15730, Total Reward: 1
# Episode 15740, Total Reward: 1
# Episode 15750, Total Reward: 1
# Episode 15760, Total Reward: 1
# Episode 15770, Total Reward: 1
# Episode 15780, Total Reward: 1
# Episode 15790, Total Reward: 1
# Episode 15800, Total Reward: 1
# Episode 15810, Total Reward: 1
# Episode 15820, Total Reward: 0
# Episode 15830, Total Reward: 1
# Episode 15840, Total Reward: 1
# Episode 15850, Total Reward: 1
# Episode 15860, Total Reward: 1
# Episode 15870, Total Reward: 0
# Episode 15880, Total Reward: 0
# Episode 15890, Total Reward: 1
# Episode 15900, Total Reward: 1
# Episode 15910, Total Reward: 2
# Episode 15920, Total Reward: 1
# Episode 15930, Total Reward: 0
# Episode 15940, Total Reward: 1
# Episode 15950, Total Reward: 1
# Episode 15960, Total Reward: 1
# Episode 15970, Total Reward: 1
# Episode 15980, Total Reward: 0
# Episode 15990, Total Reward: 2
# Episode 16000, Total Reward: 2
# Episode 16010, Total Reward: 1
# Episode 16020, Total Reward: 1
# Episode 16030, Total Reward: 2
# Episode 16040, Total Reward: 2
# Episode 16050, Total Reward: 1
# Episode 16060, Total Reward: 1
# Episode 16070, Total Reward: 1
# Episode 16080, Total Reward: 1
# Episode 16090, Total Reward: 0
# Episode 16100, Total Reward: 0
# Episode 16110, Total Reward: 0
# Episode 16120, Total Reward: 1
# Episode 16130, Total Reward: 1
# Episode 16140, Total Reward: 1
# Episode 16150, Total Reward: 1
# Episode 16160, Total Reward: 1
# Episode 16170, Total Reward: 2
# Episode 16180, Total Reward: 1
# Episode 16190, Total Reward: 1
# Episode 16200, Total Reward: 1
# Episode 16210, Total Reward: 1
# Episode 16220, Total Reward: 1
# Episode 16230, Total Reward: 1
# Episode 16240, Total Reward: 1
# Episode 16250, Total Reward: 1
# Episode 16260, Total Reward: 1
# Episode 16270, Total Reward: 1
# Episode 16280, Total Reward: 1
# Episode 16290, Total Reward: 1
# Episode 16300, Total Reward: 2
# Episode 16310, Total Reward: 1
# Episode 16320, Total Reward: 1
# Episode 16330, Total Reward: 1
# Episode 16340, Total Reward: 1
# Episode 16350, Total Reward: 1
# Episode 16360, Total Reward: 1
# Episode 16370, Total Reward: 1
# Episode 16380, Total Reward: 1
# Episode 16390, Total Reward: 1
# Episode 16400, Total Reward: 1
# Episode 16410, Total Reward: 0
# Episode 16420, Total Reward: 1
# Episode 16430, Total Reward: 1
# Episode 16440, Total Reward: 1
# Episode 16450, Total Reward: 1
# Episode 16460, Total Reward: 1
# Episode 16470, Total Reward: 0
# Episode 16480, Total Reward: 1
# Episode 16490, Total Reward: 0
# Episode 16500, Total Reward: 2
# Episode 16510, Total Reward: 1
# Episode 16520, Total Reward: 1
# Episode 16530, Total Reward: 2
# Episode 16540, Total Reward: 0
# Episode 16550, Total Reward: 1
# Episode 16560, Total Reward: 1
# Episode 16570, Total Reward: 1
# Episode 16580, Total Reward: 0
# Episode 16590, Total Reward: 1
# Episode 16600, Total Reward: 1
# Episode 16610, Total Reward: 0
# Episode 16620, Total Reward: 1
# Episode 16630, Total Reward: 1
# Episode 16640, Total Reward: 2
# Episode 16650, Total Reward: 1
# Episode 16660, Total Reward: 1
# Episode 16670, Total Reward: 2
# Episode 16680, Total Reward: 1
# Episode 16690, Total Reward: 1
# Episode 16700, Total Reward: 1
# Episode 16710, Total Reward: 1
# Episode 16720, Total Reward: 1
# Episode 16730, Total Reward: 2
# Episode 16740, Total Reward: 1
# Episode 16750, Total Reward: 1
# Episode 16760, Total Reward: 1
# Episode 16770, Total Reward: 0
# Episode 16780, Total Reward: 1
# Episode 16790, Total Reward: 2
# Episode 16800, Total Reward: 0
# Episode 16810, Total Reward: 1
# Episode 16820, Total Reward: 1
# Episode 16830, Total Reward: 0
# Episode 16840, Total Reward: 3
# Episode 16850, Total Reward: 1
# Episode 16860, Total Reward: 1
# Episode 16870, Total Reward: 1
# Episode 16880, Total Reward: 1
# Episode 16890, Total Reward: 1
# Episode 16900, Total Reward: 1
# Episode 16910, Total Reward: 1
# Episode 16920, Total Reward: 2
# Episode 16930, Total Reward: 1
# Episode 16940, Total Reward: 1
# Episode 16950, Total Reward: 3
# Episode 16960, Total Reward: 1
# Episode 16970, Total Reward: 1
# Episode 16980, Total Reward: 1
# Episode 16990, Total Reward: 1
# Episode 17000, Total Reward: 2
# Episode 17010, Total Reward: 1
# Episode 17020, Total Reward: 1
# Episode 17030, Total Reward: 1
# Episode 17040, Total Reward: 1
# Episode 17050, Total Reward: 2
# Episode 17060, Total Reward: 1
# Episode 17070, Total Reward: 1
# Episode 17080, Total Reward: 1
# Episode 17090, Total Reward: 2
# Episode 17100, Total Reward: 2
# Episode 17110, Total Reward: 1
# Episode 17120, Total Reward: 1
# Episode 17130, Total Reward: 2
# Episode 17140, Total Reward: 0
# Episode 17150, Total Reward: 0
# Episode 17160, Total Reward: 1
# Episode 17170, Total Reward: 2
# Episode 17180, Total Reward: 1
# Episode 17190, Total Reward: 2
# Episode 17200, Total Reward: 2
# Episode 17210, Total Reward: 2
# Episode 17220, Total Reward: 0
# Episode 17230, Total Reward: 1
# Episode 17240, Total Reward: 1
# Episode 17250, Total Reward: 1
# Episode 17260, Total Reward: 3
# Episode 17270, Total Reward: 1
# Episode 17280, Total Reward: 1
# Episode 17290, Total Reward: 3
# Episode 17300, Total Reward: 1
# Episode 17310, Total Reward: 1
# Episode 17320, Total Reward: 1
# Episode 17330, Total Reward: 2
# Episode 17340, Total Reward: 0
# Episode 17350, Total Reward: 0
# Episode 17360, Total Reward: 1
# Episode 17370, Total Reward: 3
# Episode 17380, Total Reward: 0
# Episode 17390, Total Reward: 2
# Episode 17400, Total Reward: 1
# Episode 17410, Total Reward: 2
# Episode 17420, Total Reward: 1
# Episode 17430, Total Reward: 2
# Episode 17440, Total Reward: 1
# Episode 17450, Total Reward: 1
# Episode 17460, Total Reward: 1
# Episode 17470, Total Reward: 1
# Episode 17480, Total Reward: 2
# Episode 17490, Total Reward: 1
# Episode 17500, Total Reward: 1
# Episode 17510, Total Reward: 1
# Episode 17520, Total Reward: 2
# Episode 17530, Total Reward: 1
# Episode 17540, Total Reward: 1
# Episode 17550, Total Reward: 1
# Episode 17560, Total Reward: 1
# Episode 17570, Total Reward: 1
# Episode 17580, Total Reward: 3
# Episode 17590, Total Reward: 2
# Episode 17600, Total Reward: 1
# Episode 17610, Total Reward: 2
# Episode 17620, Total Reward: 1
# Episode 17630, Total Reward: 0
# Episode 17640, Total Reward: 1
# Episode 17650, Total Reward: 2
# Episode 17660, Total Reward: 1
# Episode 17670, Total Reward: 1
# Episode 17680, Total Reward: 4
# Episode 17690, Total Reward: 1
# Episode 17700, Total Reward: 3
# Episode 17710, Total Reward: 0
# Episode 17720, Total Reward: 0
# Episode 17730, Total Reward: 1
# Episode 17740, Total Reward: 1
# Episode 17750, Total Reward: 1
# Episode 17760, Total Reward: 1
# Episode 17770, Total Reward: 3
# Episode 17780, Total Reward: 1
# Episode 17790, Total Reward: 2
# Episode 17800, Total Reward: 1
# Episode 17810, Total Reward: 3
# Episode 17820, Total Reward: 2
# Episode 17830, Total Reward: 4
# Episode 17840, Total Reward: 0
# Episode 17850, Total Reward: 2
# Episode 17860, Total Reward: 1
# Episode 17870, Total Reward: 3
# Episode 17880, Total Reward: 2
# Episode 17890, Total Reward: 1
# Episode 17900, Total Reward: 2
# Episode 17910, Total Reward: 2
# Episode 17920, Total Reward: 2
# Episode 17930, Total Reward: 1
# Episode 17940, Total Reward: 1
# Episode 17950, Total Reward: 2
# Episode 17960, Total Reward: 1
# Episode 17970, Total Reward: 1
# Episode 17980, Total Reward: 4
# Episode 17990, Total Reward: 1
# Episode 18000, Total Reward: 2
# Episode 18010, Total Reward: 3
# Episode 18020, Total Reward: 1
# Episode 18030, Total Reward: 2
# Episode 18040, Total Reward: 3
# Episode 18050, Total Reward: 1
# Episode 18060, Total Reward: 2
# Episode 18070, Total Reward: 1
# Episode 18080, Total Reward: 1
# Episode 18090, Total Reward: 1
# Episode 18100, Total Reward: 1
# Episode 18110, Total Reward: 1
# Episode 18120, Total Reward: 2
# Episode 18130, Total Reward: 1
# Episode 18140, Total Reward: 2
# Episode 18150, Total Reward: 1
# Episode 18160, Total Reward: 3
# Episode 18170, Total Reward: 2
# Episode 18180, Total Reward: 1
# Episode 18190, Total Reward: 2
# Episode 18200, Total Reward: 3
# Episode 18210, Total Reward: 2
# Episode 18220, Total Reward: 0
# Episode 18230, Total Reward: 3
# Episode 18240, Total Reward: 1
# Episode 18250, Total Reward: 2
# Episode 18260, Total Reward: 2
# Episode 18270, Total Reward: 1
# Episode 18280, Total Reward: 1
# Episode 18290, Total Reward: 0
# Episode 18300, Total Reward: 1
# Episode 18310, Total Reward: 2
# Episode 18320, Total Reward: 1
# Episode 18330, Total Reward: 2
# Episode 18340, Total Reward: 1
# Episode 18350, Total Reward: 3
# Episode 18360, Total Reward: 3
# Episode 18370, Total Reward: 1
# Episode 18380, Total Reward: 1
# Episode 18390, Total Reward: 1
# Episode 18400, Total Reward: 1
# Episode 18410, Total Reward: 5
# Episode 18420, Total Reward: 0
# Episode 18430, Total Reward: 1
# Episode 18440, Total Reward: 0
# Episode 18450, Total Reward: 6
# Episode 18460, Total Reward: 2
# Episode 18470, Total Reward: 1
# Episode 18480, Total Reward: 1
# Episode 18490, Total Reward: 1
# Episode 18500, Total Reward: 1
# Episode 18510, Total Reward: 1
# Episode 18520, Total Reward: 4
# Episode 18530, Total Reward: 1
# Episode 18540, Total Reward: 1
# Episode 18550, Total Reward: 1
# Episode 18560, Total Reward: 1
# Episode 18570, Total Reward: 3
# Episode 18580, Total Reward: 4
# Episode 18590, Total Reward: 1
# Episode 18600, Total Reward: 1
# Episode 18610, Total Reward: 2
# Episode 18620, Total Reward: 1
# Episode 18630, Total Reward: 3
# Episode 18640, Total Reward: 4
# Episode 18650, Total Reward: 1
# Episode 18660, Total Reward: 1
# Episode 18670, Total Reward: 4
# Episode 18680, Total Reward: 4
# Episode 18690, Total Reward: 1
# Episode 18700, Total Reward: 2
# Episode 18710, Total Reward: 1
# Episode 18720, Total Reward: 2
# Episode 18730, Total Reward: 4
# Episode 18740, Total Reward: 1
# Episode 18750, Total Reward: 1
# Episode 18760, Total Reward: 3
# Episode 18770, Total Reward: 1
# Episode 18780, Total Reward: 2
# Episode 18790, Total Reward: 1
# Episode 18800, Total Reward: 2
# Episode 18810, Total Reward: 1
# Episode 18820, Total Reward: 1
# Episode 18830, Total Reward: 2
# Episode 18840, Total Reward: 8
# Episode 18850, Total Reward: 1
# Episode 18860, Total Reward: 2
# Episode 18870, Total Reward: 1
# Episode 18880, Total Reward: 1
# Episode 18890, Total Reward: 5
# Episode 18900, Total Reward: 1
# Episode 18910, Total Reward: 2
# Episode 18920, Total Reward: 3
# Episode 18930, Total Reward: 3
# Episode 18940, Total Reward: 0
# Episode 18950, Total Reward: 2
# Episode 18960, Total Reward: 2
# Episode 18970, Total Reward: 11
# Episode 18980, Total Reward: 2
# Episode 18990, Total Reward: 3
# Episode 19000, Total Reward: 0
# Episode 19010, Total Reward: 3
# Episode 19020, Total Reward: 1
# Episode 19030, Total Reward: 2
# Episode 19040, Total Reward: 1
# Episode 19050, Total Reward: 1
# Episode 19060, Total Reward: 0
# Episode 19070, Total Reward: 1
# Episode 19080, Total Reward: 2
# Episode 19090, Total Reward: 2
# Episode 19100, Total Reward: 2
# Episode 19110, Total Reward: 1
# Episode 19120, Total Reward: 2
# Episode 19130, Total Reward: 5
# Episode 19140, Total Reward: 10
# Episode 19150, Total Reward: 6
# Episode 19160, Total Reward: 2
# Episode 19170, Total Reward: 3
# Episode 19180, Total Reward: 5
# Episode 19190, Total Reward: 1
# Episode 19200, Total Reward: 3
# Episode 19210, Total Reward: 2
# Episode 19220, Total Reward: 3
# Episode 19230, Total Reward: 6
# Episode 19240, Total Reward: 4
# Episode 19250, Total Reward: 1
# Episode 19260, Total Reward: 1
# Episode 19270, Total Reward: 9
# Episode 19280, Total Reward: 6
# Episode 19290, Total Reward: 5
# Episode 19300, Total Reward: 1
# Episode 19310, Total Reward: 4
# Episode 19320, Total Reward: 10
# Episode 19330, Total Reward: 3
# Episode 19340, Total Reward: 14
# Episode 19350, Total Reward: 4
# Episode 19360, Total Reward: 7
# Episode 19370, Total Reward: 4
# Episode 19380, Total Reward: 5
# Episode 19390, Total Reward: 7
# Episode 19400, Total Reward: 2
# Episode 19410, Total Reward: 11
# Episode 19420, Total Reward: 8
# Episode 19430, Total Reward: 5
# Episode 19440, Total Reward: 5
# Episode 19450, Total Reward: 11
# Episode 19460, Total Reward: 7
# Episode 19470, Total Reward: 13
# Episode 19480, Total Reward: 10
# Episode 19490, Total Reward: 4
# Episode 19500, Total Reward: 6
# Episode 19510, Total Reward: 18
# Episode 19520, Total Reward: 3
# Episode 19530, Total Reward: 11
# Episode 19540, Total Reward: 5
# Episode 19550, Total Reward: 124
# Episode 19560, Total Reward: 37
# Episode 19570, Total Reward: 41
# Episode 19580, Total Reward: 35
# Episode 19590, Total Reward: 25
# Episode 19600, Total Reward: 27
# Episode 19610, Total Reward: 22
# Episode 19620, Total Reward: 38
# Episode 19630, Total Reward: 31
# Episode 19640, Total Reward: 20
# Episode 19650, Total Reward: 67
# Episode 19660, Total Reward: 24
# Episode 19670, Total Reward: 61
# Episode 19680, Total Reward: 145
# Episode 19690, Total Reward: 57
# Episode 19700, Total Reward: 144
# Episode 19710, Total Reward: 117
# Episode 19720, Total Reward: 184
# Episode 19730, Total Reward: 70
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 192
#     189     return agent
#     191 if __name__ == "__main__":
# --> 192     trained_agent = train_ppo()
#
# Cell In[2], line 176, in train_ppo(num_episodes)
#     173     break
#     175 if len(agent.buffer) >= MAX_MEMORY:
# --> 176     agent.update()
#     178 if episode % 10 == 0:
#     179     print(f"Episode {episode}, Total Reward: {total_reward}")
#
# Cell In[2], line 132, in PPOAgent.update(self)
#     130     policy_loss.backward()
#     131     value_loss.backward()
# --> 132     self.optimizer_actor.step()
#     133     self.optimizer_critic.step()
#     135 self.buffer.clear()
#
# File ~/opt/anaconda3/envs/mujoco-env/lib/python3.9/site-packages/torch/optim/optimizer.py:385, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     380         else:
#     381             raise RuntimeError(
#     382                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     383             )
# --> 385 out = func(*args, **kwargs)
#     386 self._optimizer_step_code()
#     388 # call optimizer step post hooks
#
# File ~/opt/anaconda3/envs/mujoco-env/lib/python3.9/site-packages/torch/optim/optimizer.py:75, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      61 try:
#      62     # Note on graph break below:
#      63     # we need to graph break to ensure that aot respects the no_grad annotation.
#    (...)
#      72     # graph break to allow the fully fused fwd-bwd-optimizer graph to be compiled.
#      73     # see https://github.com/pytorch/pytorch/issues/104053
#      74     torch.set_grad_enabled(self.defaults['differentiable'])
# ---> 75     torch._dynamo.graph_break()
#      76     ret = func(self, *args, **kwargs)
#      77 finally:
#
# KeyboardInterrupt:
# Si è verificato un arresto anomalo del Kernel durante l'esecuzione del codice nella cella attiva o in una cella precedente.
#
# Esaminare il codice nelle celle per identificare una possibile causa dell'errore.
#
# Per altre informazioni, fare clic<a href='https://aka.ms/vscodeJupyterKernelCrash'>qui</a>.
#
# Per ulteriori dettagli, visualizzare Jupyter <a href='command:jupyter.viewOutput'>log</a>.

# %%
import numpy as np
import torch
import mujoco
import time
import matplotlib.pyplot as plt

# Inizializza l'ambiente
env = ForceMatchingEnv("/Users/edoardozappia/Desktop/Tesi_Magistrale/irregular_shape_2D.xml", "/Users/edoardozappia/Desktop/Tesi_Magistrale/target_positions.npy")
target_positions = np.load("/Users/edoardozappia/Desktop/Tesi_Magistrale/target_positions.npy")
# Assumi che il modello PPO sia già stato allenato e in memoria
agent = trained_agent
agent.eval()  # Metti il modello in modalità valutazione

# Reset dell'ambiente
state, _ = env.reset()
done = False

# Liste per il logging
episode_rewards = []
positions = []
actions_list = []

print("▶️ Test della policy appresa...")
i = 1

while not done:
    # Ottieni l'azione dalla policy senza esplorazione
    with torch.no_grad():
        action, _ = agent.get_action(state)

    # Esegui l'azione nell'ambiente
    next_state, reward, terminated, truncated, _ = env.step(action)
    done = terminated or truncated

    # Salva i dati
    episode_rewards.append(reward)
    positions.append((env.data.qpos[0], env.data.qpos[1]))
    actions_list.append(action)

    # Stampa informazioni
    print(f"Posizione: x={env.data.qpos[0]:.3f}, y={env.data.qpos[1]:.3f} | Posizione target: x={target_positions[i][0]:.3f}, y={target_positions[i][1]:.3f} Azione: {action} | Reward: {reward:.3f}")

    i += 1

    # Aggiorna lo stato
    state = next_state

    # Visualizza l'ambiente (solo se sei su una macchina con GUI)
    env.render()
    time.sleep(0.05)  # Piccola pausa per visualizzazione fluida

env.close()

# ▶️ **Plotta le azioni nel tempo**
actions_list = np.array(actions_list)
plt.figure(figsize=(12, 5))
plt.plot(actions_list[:, 0], label="Forza X")
plt.plot(actions_list[:, 1], label="Forza Y")
plt.xlabel("Step")
plt.ylabel("Forza Applicata")
plt.title("Evoluzione delle Azioni della Policy Appresa")
plt.legend()
plt.show()

# ▶️ **Plotta la traiettoria seguita**
positions = np.array(positions)
plt.figure(figsize=(6, 6))
plt.plot(positions[:, 0], positions[:, 1], marker="o", linestyle="-", markersize=3, label="Traiettoria")
plt.scatter([positions[0, 0]], [positions[0, 1]], color="red", label="Start", marker="o", s=100)
plt.scatter([positions[-1, 0]], [positions[-1, 1]], color="green", label="End", marker="x", s=100)
plt.xlabel("X")
plt.ylabel("Y")
plt.title("Traiettoria della Policy Appresa")
plt.legend()
plt.grid()
plt.show()

# ▶️ **Plotta l'andamento della ricompensa**
plt.figure(figsize=(10, 4))
plt.plot(episode_rewards, label="Reward")
plt.xlabel("Step")
plt.ylabel("Reward")
plt.title("Andamento della Ricompensa")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 15
#      12 agent.eval()  # Metti il modello in modalità valutazione
#      14 # Reset dell'ambiente
# ---> 15 state, _ = env.reset()
#      16 done = False
#      18 # Liste per il logging
#
# Cell In[1], line 58, in ForceMatchingEnv.reset(self)
#      55 """Resetta sia il target che il punto agent e restituisce stato e target"""
#      56 #**Reset del punto AGENT**
# ---> 58 self.data.qpos[self.model.joint("agent_slide_x").qposadr] = 0.0
#      59 self.data.qpos[self.model.joint("agent_slide_y").qposadr] = 0.0
#      60 self.data.qvel[self.model.joint("agent_slide_x").dofadr] = 0.0
#
# KeyError: "Invalid name 'agent_slide_x'. Valid names: ['rotation_z', 'slide_x', 'slide_y']"
